# %% [markdown]
# <a href="https://colab.research.google.com/github/EziamaUgonna/Bayesian_analysis-/blob/master/Dissertation_work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip show tensorflow
# Out:
# Name: tensorflow
# Version: 1.14.0rc1
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /usr/local/lib/python3.6/dist-packages
# Requires: google-pasta, tensorboard, keras-applications, keras-preprocessing, astor, wrapt, protobuf, tensorflow-estimator, wheel, numpy, grpcio, gast, absl-py, termcolor, six
# Required-by: stable-baselines, magenta, fancyimpute

# %%
# !pip show tensorflow_probability
# Out:
# Name: tensorflow-probability
# Version: 0.7.0rc0
# Summary: Probabilistic modeling and statistical inference in TensorFlow
# Home-page: http://github.com/tensorflow/probability
# Author: Google LLC
# Author-email: no-reply@google.com
# License: Apache 2.0
# Location: /usr/local/lib/python3.6/dist-packages
# Requires: cloudpickle, six, decorator, numpy
# Required-by: tensor2tensor, magenta, dm-sonnet

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

# %%
# Dependencies
import os 
import warnings 
#from absl import flags 
import matplotlib 
import numpy as np 
import tensorflow as tf 
import tensorflow_probability as tfp
import math
import pandas as pd
tfd = tfp.distributions
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
#from hyperopt import fmin, tpe, hp, STATUS_OK, STATUS_FAIL, Trials
#import python_utils

# %%
flags = tf.app.flags
FLAGS = tf.app.flags.FLAGS
flags.DEFINE_float("learning_rate", default = 0.0001, help = "Initial learning rate.")
flags.DEFINE_integer("epochs", default = 700, help = "Number of epochs to train for")
flags.DEFINE_integer("batch_size", default =128, help = "Batch size.")
flags.DEFINE_integer("eval_freq", default = 400, help =" Frequency at which to validate the model.")
flags.DEFINE_float("kernel_posterior_scale_mean", default = -0.9, help = "Initial kernel posterior mean of the scale (log var) for q(w)")
flags.DEFINE_float("kernel_posterior_scale_constraint", default = 0.2, help = "Posterior kernel constraint for the scale (log var) for q(w)")
flags.DEFINE_float("kl_annealing", default = 50, help = "Epochs to anneal the KL term (anneals from 0 to 1)")
flags.DEFINE_integer("num_hidden_layers", default = 4, help = "Number of hidden layers")
flags.DEFINE_integer("num_monte_carlo",

                     default=50,

                     help="Network draws to compute predictive probabilities.")
tf.app.flags.DEFINE_string('f', '', 'kernel')
#initialize flags 
#FLAGS = flags.FLAGS
print(FLAGS.learning_rate)
print(FLAGS.epochs)
print(FLAGS.num_monte_carlo)
# Out:
# 0.0001
# 700
# 50

# %%
def build_input_pipeline(X_train,X_val,X_test,y_train,y_val,y_test, batch_size, valid_size):
  #Build an iterator over training batches 
  training_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
  #Shuffle the dataset (note shuffle argument much larger than training size)
  # and form batches of size batch_size
  training_batches = training_dataset.shuffle(20000, reshuffle_each_iteration =True).repeat().batch(batch_size)
  training_iterator = tf.data.make_one_shot_iterator(training_batches)
  
  #Building iterator over the heldout set with batch_size = heldout_size,
  # i.e., return the entire heldout set as a constant.
  heldout_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val))
  heldout_batches = heldout_dataset.repeat().batch(valid_size)
  heldout_iterator = tf.data.make_one_shot_iterator(heldout_batches)
  
  test_dataset = tf.data.Dataset.from_tensor_slices((X_test,y_test))
  test_dataset = test_dataset.batch(batch_size)
  test_iterator = test_dataset.make_one_shot_iterator()
  
  
  
  
  #Combine these into a feasible iterator that can switch between training 
  # and validation inputs.
  # Here should be minibatch increment be defined 
  handle = tf.placeholder(tf.string, shape = [])
  feedable_iterator = tf.data.Iterator.from_string_handle(handle, training_batches.output_types, training_batches.output_shapes)
  features_final, labels_final = feedable_iterator.get_next()
  
  return features_final, labels_final, handle, training_iterator, heldout_iterator,test_iterator

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !ls "/content/gdrive/My Drive/"

# %%
# Read in the dataset
df = pd.read_csv('/content/gdrive/My Drive/work2.csv').astype(np.float32)
change = df.query('Speed>0').sample(frac = .1).index
df.loc[change, 'Speed'] = 0
df.loc[change, 'Class'] = 0
df.to_csv('work2.csv', header = True, index =False)
df.shape
# Out:
# (1048575, 20)

# %%
X = df.iloc[:,:-1].values
y = df.iloc[:,-1].values

# %%
X.dtype
# Out:
# dtype('float32')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1)

# %%
# Standardize the dataset 
scalar_x_train = StandardScaler().fit(X_train)
scalar_x_test = StandardScaler().fit(X_test)
scalar_x_val  = StandardScaler().fit(X_val)
X_train = scalar_x_train.transform(X_train)
X_test  = scalar_x_test.transform(X_test)
X_val   = scalar_x_val.transform(X_val)

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 4637219751792465797, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 12685886454450531409
#  physical_device_desc: "device: XLA_CPU device"]

# %%
def main(argv):
  # extract the activation function from the hyperopt spec as an attribute from the tf.nn module 
  #activation = getattr(tf.nn, FLAGS.activation_function)
  # define the graph 
  #with tf.Graph().as_default():
  (features_final, labels_final, handle, training_iterator, heldout_iterator,test_iterator) = build_input_pipeline(X_train,X_val,X_test,y_train,y_val,y_test, FLAGS.batch_size, 500)
  
  
  # Building the Bayesian Neural Network 
  # we are Gaussian Reparametrization Trick 
  # to compute the stochastic gradients as described in the paper 
  with tf.compat.v1.name_scope("bayesian_neural_net", values =[features_final]):
    neural_net = tf.keras.Sequential()
    for i in range(FLAGS.num_hidden_layers):
      layer = tfp.layers.DenseReparameterization(
          units = 10,
          activation = tf.nn.relu,
          trainable = True,
          kernel_prior_fn=tfp.layers.default_multivariate_normal_fn, # NormalDiag
          kernel_posterior_fn=tfp.layers.default_mean_field_normal_fn(),
          #kernel_posterior_fn=tfp_layers_util.default_mean_field_normal_fn(), # softplus(sigma)
          kernel_posterior_tensor_fn=lambda x: x.sample(),
          bias_prior_fn=tfp.layers.default_multivariate_normal_fn, # NormalDiag
          bias_posterior_fn=tfp.layers.default_mean_field_normal_fn(), # softplus(sigma)
          bias_posterior_tensor_fn=lambda x: x.sample()
          )
      neural_net.add(layer)
  neural_net.add(tfp.layers.DenseReparameterization(
      units=2, # one dimensional output
      activation= tf.nn.softmax, # since regression (outcome not bounded)
      trainable=True, # i.e subject to optimization
      kernel_prior_fn=tfp.layers.default_multivariate_normal_fn, # NormalDiag with hyperopt sigma
      kernel_posterior_fn=tfp.layers.default_mean_field_normal_fn(), # softplus(sigma)
      kernel_posterior_tensor_fn=lambda x: x.sample(),
      bias_prior_fn =tfp.layers.default_multivariate_normal_fn, # NormalDiag with hyperopt sigma
      bias_posterior_fn=tfp.layers.default_mean_field_normal_fn(), # softplus(sigma)
      bias_posterior_tensor_fn=lambda x: x.sample()
      ))
  logits = neural_net(features_final)
  #labels_distribution = tfd.Bernoulli(logits=logits)
  labels_distribution = tfd.Categorical(logits=logits)
  #labels_distribution = tfd.Bernoulli(logits=logits)
  
  # Perform KL annealing. The optimal number of annealing steps 
  # depends on the dataset and architecture.
  t = tf.Variable(0.0)
  kl_regularizer = t / (FLAGS.kl_annealing * len(X_train) / FLAGS.batch_size)
  
  #Compute the -ELBO as the loss. The kl term is annealed from 1 to 1 over 
  # the epochs specified by the kl_annealing flag.
  log_likelihood = labels_distribution.log_prob(labels_final)
  #neg_log_likelihood = tf.reduce_mean(tf.squared_difference(logits,labels_final))
  neg_log_likelihood = -tf.reduce_mean(input_tensor = log_likelihood)
  kl = sum(neural_net.losses)/len(X_train) * tf.minimum(1.0, kl_regularizer)
  elbo_loss = neg_log_likelihood + kl
  
  # Build metrics for evaluation. Predictions are formed from single forward 
  # pass of the probablisitic layers . They are cheap but noisy predictions
  predictions = tf.argmax(input = logits, axis=1)
  predictions = tf.cast(predictions, tf.float32)
  # TP, TN, FP, FN
  TP = tf.count_nonzero(predictions * labels_final)
  TN = tf.count_nonzero((predictions - 1) * (labels_final - 1))
  FP = tf.count_nonzero(predictions * (labels_final - 1))
  FN = tf.count_nonzero((predictions - 1) * labels_final)
  # precision, recall, f1
  precision = TP / (TP + FP)
  recall = TP / (TP + FN)
  f1 = 2 * precision * recall / (precision + recall)
  
  tpr = TP/(TP+FN)
  fpr = FP/(TP+FN)
  with tf.compat.v1.name_scope("train"):
    train_accuracy, train_accuracy_update_op = tf.metrics.accuracy(labels=labels_final,predictions =predictions)
    opt = tf.train.AdamOptimizer(FLAGS.learning_rate)
    train_op = opt.minimize(elbo_loss)
    update_step_op = tf.assign(t, t+1)
  
  with tf.compat.v1.name_scope("valid"):
    valid_accuracy, validation_accuracy_update_op = tf.metrics.accuracy(labels= labels_final,predictions = predictions)
  with tf.compat.v1.name_scope("test"):
    test_accuracy, test_accuracy_update_op = tf.metrics.accuracy(labels = labels_final,predictions = predictions)
  
  init_op = tf.group(tf.global_variables_initializer(),
                     tf.local_variables_initializer())
  saver = tf.train.Saver()
  
  stream_vars_valid = [ v for v in tf.local_variables() if "valid" in v.name]
  
  reset_valid_op = tf.variables_initializer(stream_vars_valid)
  
  valid_accuracy_summary = []
  stop_early =0
  with tf.compat.v1.Session() as sess:
    sess.run(init_op)
    
    # Run the training loop

    train_handle = sess.run(training_iterator.string_handle())
    heldout_handle = sess.run(  heldout_iterator.string_handle())
      
    test_handle = sess.run(test_iterator.string_handle())

    training_steps = int(round(FLAGS.epochs * (len(X_train) / FLAGS.batch_size)))

    for step in range(training_steps):
      

      _ = sess.run([train_op,train_accuracy_update_op, update_step_op],feed_dict={handle: train_handle})
      
      # Manually print the frequency 
      if step % 100 == 0:
        save_path = saver.save(sess, "/tmp/my_model.ckpt")
        loss_value, accuracy_value, kl_value = sess.run([elbo_loss, train_accuracy, kl], feed_dict= {handle:train_handle})
        print("Step:{:>3d} loss : {:.3f} KL: {:.3f}" .format(step , loss_value, accuracy_value, kl_value))
        
        
      if (step +1) % FLAGS.eval_freq ==0: 
        # Compute log prob of heldout set by averaging draws from the model:
        # p(heldout | train) = int_model p(heldout|model) p(model|train) ~= 1/n * sum_{i=1}^n p(heldout | model_i)
        # where model_i is a draw from the posterior 
        #p(model|train)
        probs = np.asarray([sess.run((labels_distribution.probs), 
                                     feed_dict ={handle: heldout_handle})
      
                            for _ in range(FLAGS.num_monte_carlo)])
        mean_probs = np.mean(probs, axis =0).astype(np.int32)
        print(mean_probs.dtype)
        
        _, label_vals = sess.run((features_final, labels_final), feed_dict = {handle: heldout_handle})
        label_vals = (label_vals).astype(np.int32)
      
        heldout_lp = np.mean(np.log(mean_probs[np.arange(mean_probs.shape[0]), label_vals]))
        
        
        print(" ...Held_out nats: {:.3f}".format(heldout_lp))
        
       # Calculate validation accuracy

        for step in range(10):

          sess.run(validation_accuracy_update_op, feed_dict={handle: heldout_handle})

        valid_value = sess.run(valid_accuracy, feed_dict={handle: heldout_handle})
        
        valid_accuracy_summary.append(valid_value)
        if valid_value < max(valid_accuracy_summary) and step > 100:
          stop_early += 1
          if stop_early == 15:
            break
        else:
          stop_early = 0
        print("Validation Accuracy: {:.3f}".format(valid_value))
        sess.run(reset_valid_op)
          
        test_value = sess.run(test_accuracy, feed_dict={handle: test_handle})
        
        loss_value,test_value, precision_value, recall_value, fpr_value, tpr_value,f1 = sess.run([elbo_loss,test_accuracy, precision, recall, fpr, tpr,f1],feed_dict={handle: test_handle})
        
        print("Step: {:>3d} Loss: {:.3f}  test Accuracy: {:.3f} Precision: {:.3f} Recall: {:.3f} ".format(step, loss_value, test_value, precision_value, recall_value))
        
        print("Step: {:>3d} fpr: {:.3f} tpr: {:.3f} f1_1: {:.3f}".format( step, fpr_value, tpr_value,f1))
        
        
        
        
if __name__ == "__main__":
  tf.compat.v1.app.run()

# %%
# create the training datasets
dx_train = tf.data.Dataset.from_tensor_slices(X_train)
# apply a one-hot transformation to each label for use in the neural network
dy_train = tf.data.Dataset.from_tensor_slices(y_train)
# zip the x and y training data together and shuffle, batch etc.
train_dataset = tf.data.Dataset.zip((dx_train, dy_train)).shuffle(500).repeat().batch(8)

# %%
# do the same operations for the validation set
dx_valid = tf.data.Dataset.from_tensor_slices(X_test)
dy_valid = tf.data.Dataset.from_tensor_slices(y_test)
valid_dataset = tf.data.Dataset.zip((dx_valid, dy_valid)).shuffle(500).repeat().batch(30)

# %%
# create general iterator
iterator = tf.data.Iterator.from_structure(train_dataset.output_types,
                                               train_dataset.output_shapes)
next_element = iterator.get_next()

# %%
# make datasets that we can initialize separately, but using the same structure via the common iterator
training_init_op = iterator.make_initializer(train_dataset)
validation_init_op = iterator.make_initializer(valid_dataset)

# %%
def nn_model(in_data):
    bn = tf.layers.batch_normalization(in_data)
    fc1 = tf.layers.dense(bn, 19)
    fc2 = tf.layers.dense(fc1, 8)
    fc3 = tf.layers.dense(fc2, 2)
    return fc3

# %%
# create the neural network model
logits = nn_model(next_element[0])

# %%
# add the optimizer and loss
loss = tf.reduce_sum(tf.nn.softmax_cross_entropy_with_logits_v2(labels=next_element[1], logits=logits))
optimizer = tf.train.AdamOptimizer(1e-8).minimize(loss)
# get accuracy
predictions = tf.argmax(logits, 1)
equality = tf.equal(predictions, tf.argmax(next_element[1], 1))
accuracy = tf.reduce_mean(tf.cast(equality, tf.float32))


#TP, TN, FP, FN
TP = tf.count_nonzero(predictions * y_test, dtype=tf.float32)
TN = tf.count_nonzero((predictions-1)*(y_test-1), dtype=tf.float32)
FP = tf.count_nonzero(predictions*(y_test-1), dtype=tf.float32)
FN = tf.count_nonzero((predictions-1)*y_test, dtype=tf.float32)
#precision, recall, f1
precision = TP / (TP + FP)
recall = TP / (TP + FN)
f1 = 2 * precision * precision * recall / (precision + recall)
tpr = TP/(TP+FN)
fpr = FP/(TP+FN)

init_op = tf.global_variables_initializer()

# %%
# run the training
epochs = 600
with tf.Session() as sess:
    sess.run(init_op)
    sess.run(training_init_op)
    for i in range(epochs):
        l, _, acc = sess.run([loss, optimizer, accuracy])
        if i % 50 == 0:
            print("Epoch: {}, loss: {:.3f}, training accuracy: {:.2f}%".format(i, l, acc * 100))
    # now setup the validation run
    valid_iters = 1000
    # re-initialize the iterator, but this time with validation data
    sess.run(validation_init_op)
    avg_acc = 0
    for i in range(valid_iters):
        
        loss_value, valid_accuracy, precision_value, recall_value, fpr_value, tpr_value,f1_value = sess.run([loss, accuracy, precision, recall, fpr, tpr,f1])
        print("Step: {:>3d} loss: {:.3f} Validation Accuracy: {:.3f} Precision: {:.3f} Recall: {:.3f} fpr:{:.3f} tpr:{:.3f} f1:{:.3f} ".format(
            i, loss_value, valid_accuracy, precision_value, recall_value, fpr_value, tpr_value, f1_value))
        
        
        
        
        acc = sess.run([accuracy])
        avg_acc += acc[0]
        print("Average validation set accuracy over {} iterations is {:.2f}%".format(valid_iters,(avg_acc ) ))
# Out:
# Epoch: 0, loss: 10.852, training accuracy: 50.00%
# Epoch: 50, loss: 15.389, training accuracy: 75.00%
# Epoch: 100, loss: 14.924, training accuracy: 50.00%
# Epoch: 150, loss: 12.437, training accuracy: 62.50%
# Epoch: 200, loss: 16.327, training accuracy: 50.00%
# Epoch: 250, loss: 9.967, training accuracy: 75.00%
# Epoch: 300, loss: 17.246, training accuracy: 50.00%
# Epoch: 350, loss: 19.734, training accuracy: 50.00%
# Epoch: 400, loss: 16.516, training accuracy: 12.50%
# Epoch: 450, loss: 11.342, training accuracy: 50.00%
# Epoch: 500, loss: 13.287, training accuracy: 62.50%
# Epoch: 550, loss: 15.865, training accuracy: 37.50%
# Step:   0 loss: 75.016 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 0.40%
# Step:   1 loss: 66.754 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 0.87%
# Step:   2 loss: 71.946 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 1.40%
# Step:   3 loss: 54.699 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 2.07%
# Step:   4 loss: 56.919 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 2.57%
# Step:   5 loss: 49.778 Validation Accuracy: 0.633 Precision: 0.908 Recall: 0.367 fpr:0.037 tpr:0.367 f1:0.474
# Average validation set accuracy over 1000 iterations is 3.00%
# Step:   6 loss: 63.928 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 3.67%
# Step:   7 loss: 63.723 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 4.17%
# Step:   8 loss: 61.993 Validation Accuracy: 0.433 Precision: 0.908 Recall: 0.567 fpr:0.057 tpr:0.567 f1:0.634
# Average validation set accuracy over 1000 iterations is 4.73%
# Step:   9 loss: 64.790 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 5.30%
# Step:  10 loss: 62.971 Validation Accuracy: 0.700 Precision: 0.908 Recall: 0.300 fpr:0.030 tpr:0.300 f1:0.410
# Average validation set accuracy over 1000 iterations is 5.80%
# Step:  11 loss: 65.620 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 6.30%
# Step:  12 loss: 66.887 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 6.87%
# Step:  13 loss: 48.585 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 7.47%
# Step:  14 loss: 67.351 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 7.87%
# Step:  15 loss: 58.975 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 8.37%
# Step:  16 loss: 62.463 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 8.77%
# Step:  17 loss: 47.384 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 9.17%
# Step:  18 loss: 65.488 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 9.67%
# Step:  19 loss: 66.165 Validation Accuracy: 0.400 Precision: 0.908 Recall: 0.600 fpr:0.061 tpr:0.600 f1:0.656
# Average validation set accuracy over 1000 iterations is 10.13%
# Step:  20 loss: 53.094 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 10.70%
# Step:  21 loss: 60.134 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 11.10%
# Step:  22 loss: 49.538 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 11.73%
# Step:  23 loss: 51.032 Validation Accuracy: 0.667 Precision: 0.908 Recall: 0.333 fpr:0.034 tpr:0.333 f1:0.443
# Average validation set accuracy over 1000 iterations is 12.33%
# Step:  24 loss: 59.962 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 12.77%
# Step:  25 loss: 66.728 Validation Accuracy: 0.433 Precision: 0.908 Recall: 0.567 fpr:0.057 tpr:0.567 f1:0.634
# Average validation set accuracy over 1000 iterations is 13.20%
# Step:  26 loss: 58.865 Validation Accuracy: 0.400 Precision: 0.908 Recall: 0.600 fpr:0.061 tpr:0.600 f1:0.656
# Average validation set accuracy over 1000 iterations is 13.63%
# Step:  27 loss: 70.443 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 14.03%
# Step:  28 loss: 61.898 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 14.67%
# Step:  29 loss: 51.474 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 15.27%
# Step:  30 loss: 68.454 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 15.77%
# Step:  31 loss: 56.478 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 16.20%
# Step:  32 loss: 54.101 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 16.70%
# Step:  33 loss: 63.572 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 17.33%
# Step:  34 loss: 58.049 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 17.77%
# Step:  35 loss: 54.776 Validation Accuracy: 0.400 Precision: 0.908 Recall: 0.600 fpr:0.061 tpr:0.600 f1:0.656
# Average validation set accuracy over 1000 iterations is 18.30%
# Step:  36 loss: 55.940 Validation Accuracy: 0.667 Precision: 0.908 Recall: 0.333 fpr:0.034 tpr:0.333 f1:0.443
# Average validation set accuracy over 1000 iterations is 18.83%
# Step:  37 loss: 47.272 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 19.23%
# Step:  38 loss: 72.464 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 19.63%
# Step:  39 loss: 53.165 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 19.97%
# Step:  40 loss: 61.252 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 20.50%
# Step:  41 loss: 72.203 Validation Accuracy: 0.333 Precision: 0.908 Recall: 0.667 fpr:0.067 tpr:0.667 f1:0.698
# Average validation set accuracy over 1000 iterations is 20.87%
# Step:  42 loss: 55.647 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 21.53%
# Step:  43 loss: 68.412 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 22.10%
# Step:  44 loss: 68.491 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 22.67%
# Step:  45 loss: 55.064 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 23.13%
# Step:  46 loss: 59.908 Validation Accuracy: 0.367 Precision: 0.908 Recall: 0.633 fpr:0.064 tpr:0.633 f1:0.678
# Average validation set accuracy over 1000 iterations is 23.57%
# Step:  47 loss: 60.949 Validation Accuracy: 0.300 Precision: 0.908 Recall: 0.700 fpr:0.071 tpr:0.700 f1:0.718
# Average validation set accuracy over 1000 iterations is 24.20%
# Step:  48 loss: 56.338 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 24.77%
# Step:  49 loss: 56.189 Validation Accuracy: 0.667 Precision: 0.908 Recall: 0.333 fpr:0.034 tpr:0.333 f1:0.443
# Average validation set accuracy over 1000 iterations is 25.13%
# Step:  50 loss: 61.530 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 25.63%
# Step:  51 loss: 64.531 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 26.30%
# Step:  52 loss: 64.066 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 26.67%
# Step:  53 loss: 69.828 Validation Accuracy: 0.433 Precision: 0.908 Recall: 0.567 fpr:0.057 tpr:0.567 f1:0.634
# Average validation set accuracy over 1000 iterations is 27.43%
# Step:  54 loss: 75.265 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 27.70%
# Step:  55 loss: 65.225 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 28.43%
# Step:  56 loss: 61.789 Validation Accuracy: 0.700 Precision: 0.908 Recall: 0.300 fpr:0.030 tpr:0.300 f1:0.410
# Average validation set accuracy over 1000 iterations is 29.03%
# Step:  57 loss: 59.592 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 29.50%
# Step:  58 loss: 51.977 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 30.07%
# Step:  59 loss: 59.935 Validation Accuracy: 0.633 Precision: 0.908 Recall: 0.367 fpr:0.037 tpr:0.367 f1:0.474
# Average validation set accuracy over 1000 iterations is 30.57%
# Step:  60 loss: 56.755 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 31.10%
# Step:  61 loss: 56.536 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 31.50%
# Step:  62 loss: 63.270 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 32.17%
# Step:  63 loss: 55.163 Validation Accuracy: 0.400 Precision: 0.908 Recall: 0.600 fpr:0.061 tpr:0.600 f1:0.656
# Average validation set accuracy over 1000 iterations is 32.50%
# Step:  64 loss: 57.618 Validation Accuracy: 0.367 Precision: 0.908 Recall: 0.633 fpr:0.064 tpr:0.633 f1:0.678
# Average validation set accuracy over 1000 iterations is 33.13%
# Step:  65 loss: 59.053 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 33.77%
# Step:  66 loss: 53.309 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 34.40%
# Step:  67 loss: 55.003 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 34.90%
# Step:  68 loss: 64.660 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 35.60%
# Step:  69 loss: 63.819 Validation Accuracy: 0.400 Precision: 0.908 Recall: 0.600 fpr:0.061 tpr:0.600 f1:0.656
# Average validation set accuracy over 1000 iterations is 36.00%
# Step:  70 loss: 52.107 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 36.53%
# Step:  71 loss: 60.934 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 37.23%
# Step:  72 loss: 54.826 Validation Accuracy: 0.400 Precision: 0.908 Recall: 0.600 fpr:0.061 tpr:0.600 f1:0.656
# Average validation set accuracy over 1000 iterations is 37.73%
# Step:  73 loss: 55.860 Validation Accuracy: 0.433 Precision: 0.908 Recall: 0.567 fpr:0.057 tpr:0.567 f1:0.634
# Average validation set accuracy over 1000 iterations is 38.07%
# Step:  74 loss: 48.444 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 38.57%
# Step:  75 loss: 67.486 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 39.13%
# Step:  76 loss: 72.931 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 39.57%
# Step:  77 loss: 56.572 Validation Accuracy: 0.633 Precision: 0.908 Recall: 0.367 fpr:0.037 tpr:0.367 f1:0.474
# Average validation set accuracy over 1000 iterations is 40.10%
# Step:  78 loss: 65.612 Validation Accuracy: 0.700 Precision: 0.908 Recall: 0.300 fpr:0.030 tpr:0.300 f1:0.410
# Average validation set accuracy over 1000 iterations is 40.60%
# Step:  79 loss: 63.927 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 41.20%
# Step:  80 loss: 63.039 Validation Accuracy: 0.433 Precision: 0.908 Recall: 0.567 fpr:0.057 tpr:0.567 f1:0.634
# Average validation set accuracy over 1000 iterations is 41.57%
# Step:  81 loss: 55.094 Validation Accuracy: 0.367 Precision: 0.908 Recall: 0.633 fpr:0.064 tpr:0.633 f1:0.678
# Average validation set accuracy over 1000 iterations is 41.90%
# Step:  82 loss: 55.628 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 42.57%
# Step:  83 loss: 66.124 Validation Accuracy: 0.667 Precision: 0.908 Recall: 0.333 fpr:0.034 tpr:0.333 f1:0.443
# Average validation set accuracy over 1000 iterations is 43.13%
# Step:  84 loss: 59.402 Validation Accuracy: 0.400 Precision: 0.908 Recall: 0.600 fpr:0.061 tpr:0.600 f1:0.656
# Average validation set accuracy over 1000 iterations is 43.63%
# Step:  85 loss: 63.561 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 44.10%
# Step:  86 loss: 71.828 Validation Accuracy: 0.400 Precision: 0.908 Recall: 0.600 fpr:0.061 tpr:0.600 f1:0.656
# Average validation set accuracy over 1000 iterations is 44.57%
# Step:  87 loss: 54.719 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 45.13%
# Step:  88 loss: 59.700 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 45.63%
# Step:  89 loss: 57.039 Validation Accuracy: 0.367 Precision: 0.908 Recall: 0.633 fpr:0.064 tpr:0.633 f1:0.678
# Average validation set accuracy over 1000 iterations is 46.03%
# Step:  90 loss: 62.792 Validation Accuracy: 0.433 Precision: 0.908 Recall: 0.567 fpr:0.057 tpr:0.567 f1:0.634
# Average validation set accuracy over 1000 iterations is 46.50%
# Step:  91 loss: 58.666 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 47.03%
# Step:  92 loss: 60.655 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 47.57%
# Step:  93 loss: 67.988 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 48.10%
# Step:  94 loss: 60.023 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 48.50%
# Step:  95 loss: 61.131 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 49.00%
# Step:  96 loss: 62.190 Validation Accuracy: 0.367 Precision: 0.908 Recall: 0.633 fpr:0.064 tpr:0.633 f1:0.678
# Average validation set accuracy over 1000 iterations is 49.53%
# Step:  97 loss: 64.643 Validation Accuracy: 0.433 Precision: 0.908 Recall: 0.567 fpr:0.057 tpr:0.567 f1:0.634
# Average validation set accuracy over 1000 iterations is 50.07%
# Step:  98 loss: 53.182 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 50.60%
# Step:  99 loss: 58.999 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 51.23%
# Step: 100 loss: 57.196 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 51.73%
# Step: 101 loss: 61.983 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 52.20%
# Step: 102 loss: 62.509 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 52.73%
# Step: 103 loss: 46.513 Validation Accuracy: 0.667 Precision: 0.908 Recall: 0.333 fpr:0.034 tpr:0.333 f1:0.443
# Average validation set accuracy over 1000 iterations is 53.17%
# Step: 104 loss: 51.751 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 53.73%
# Step: 105 loss: 52.343 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 54.40%
# Step: 106 loss: 56.903 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 54.97%
# Step: 107 loss: 58.101 Validation Accuracy: 0.433 Precision: 0.908 Recall: 0.567 fpr:0.057 tpr:0.567 f1:0.634
# Average validation set accuracy over 1000 iterations is 55.43%
# Step: 108 loss: 64.123 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 55.83%
# Step: 109 loss: 55.535 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 56.40%
# Step: 110 loss: 65.029 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 56.90%
# Step: 111 loss: 57.878 Validation Accuracy: 0.667 Precision: 0.908 Recall: 0.333 fpr:0.034 tpr:0.333 f1:0.443
# Average validation set accuracy over 1000 iterations is 57.40%
# Step: 112 loss: 56.378 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 58.03%
# Step: 113 loss: 63.346 Validation Accuracy: 0.633 Precision: 0.908 Recall: 0.367 fpr:0.037 tpr:0.367 f1:0.474
# Average validation set accuracy over 1000 iterations is 58.47%
# Step: 114 loss: 48.276 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 59.00%
# Step: 115 loss: 54.882 Validation Accuracy: 0.333 Precision: 0.908 Recall: 0.667 fpr:0.067 tpr:0.667 f1:0.698
# Average validation set accuracy over 1000 iterations is 59.47%
# Step: 116 loss: 65.487 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 60.00%
# Step: 117 loss: 54.673 Validation Accuracy: 0.433 Precision: 0.908 Recall: 0.567 fpr:0.057 tpr:0.567 f1:0.634
# Average validation set accuracy over 1000 iterations is 60.50%
# Step: 118 loss: 57.100 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 60.97%
# Step: 119 loss: 60.418 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 61.40%
# Step: 120 loss: 45.128 Validation Accuracy: 0.400 Precision: 0.908 Recall: 0.600 fpr:0.061 tpr:0.600 f1:0.656
# Average validation set accuracy over 1000 iterations is 61.93%
# Step: 121 loss: 55.710 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 62.33%
# Step: 122 loss: 62.282 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 62.90%
# Step: 123 loss: 69.607 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 63.27%
# Step: 124 loss: 59.872 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 63.90%
# Step: 125 loss: 53.831 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 64.47%
# Step: 126 loss: 64.325 Validation Accuracy: 0.667 Precision: 0.908 Recall: 0.333 fpr:0.034 tpr:0.333 f1:0.443
# Average validation set accuracy over 1000 iterations is 64.97%
# Step: 127 loss: 55.980 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 65.53%
# Step: 128 loss: 50.596 Validation Accuracy: 0.400 Precision: 0.908 Recall: 0.600 fpr:0.061 tpr:0.600 f1:0.656
# Average validation set accuracy over 1000 iterations is 66.10%
# Step: 129 loss: 68.575 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 66.40%
# Step: 130 loss: 59.768 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 66.83%
# Step: 131 loss: 65.344 Validation Accuracy: 0.667 Precision: 0.908 Recall: 0.333 fpr:0.034 tpr:0.333 f1:0.443
# Average validation set accuracy over 1000 iterations is 67.37%
# Step: 132 loss: 53.217 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 67.93%
# Step: 133 loss: 63.274 Validation Accuracy: 0.433 Precision: 0.908 Recall: 0.567 fpr:0.057 tpr:0.567 f1:0.634
# Average validation set accuracy over 1000 iterations is 68.43%
# Step: 134 loss: 61.248 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 68.83%
# Step: 135 loss: 57.660 Validation Accuracy: 0.433 Precision: 0.908 Recall: 0.567 fpr:0.057 tpr:0.567 f1:0.634
# Average validation set accuracy over 1000 iterations is 69.30%
# Step: 136 loss: 71.152 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 69.97%
# Step: 137 loss: 61.268 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 70.50%
# Step: 138 loss: 54.177 Validation Accuracy: 0.700 Precision: 0.908 Recall: 0.300 fpr:0.030 tpr:0.300 f1:0.410
# Average validation set accuracy over 1000 iterations is 70.97%
# Step: 139 loss: 54.684 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 71.43%
# Step: 140 loss: 52.058 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 71.93%
# Step: 141 loss: 49.187 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 72.43%
# Step: 142 loss: 60.070 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 73.00%
# Step: 143 loss: 62.835 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 73.53%
# Step: 144 loss: 60.968 Validation Accuracy: 0.400 Precision: 0.908 Recall: 0.600 fpr:0.061 tpr:0.600 f1:0.656
# Average validation set accuracy over 1000 iterations is 74.03%
# Step: 145 loss: 63.594 Validation Accuracy: 0.367 Precision: 0.908 Recall: 0.633 fpr:0.064 tpr:0.633 f1:0.678
# Average validation set accuracy over 1000 iterations is 74.50%
# Step: 146 loss: 63.852 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 75.03%
# Step: 147 loss: 54.385 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 75.50%
# Step: 148 loss: 64.812 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 75.80%
# Step: 149 loss: 63.421 Validation Accuracy: 0.367 Precision: 0.908 Recall: 0.633 fpr:0.064 tpr:0.633 f1:0.678
# Average validation set accuracy over 1000 iterations is 76.23%
# Step: 150 loss: 54.820 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 76.63%
# Step: 151 loss: 60.829 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 77.13%
# Step: 152 loss: 53.784 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 77.70%
# Step: 153 loss: 52.295 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 78.37%
# Step: 154 loss: 67.096 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 79.03%
# Step: 155 loss: 67.546 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 79.50%
# Step: 156 loss: 55.002 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 79.87%
# Step: 157 loss: 66.549 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 80.47%
# Step: 158 loss: 62.824 Validation Accuracy: 0.633 Precision: 0.908 Recall: 0.367 fpr:0.037 tpr:0.367 f1:0.474
# Average validation set accuracy over 1000 iterations is 81.00%
# Step: 159 loss: 64.932 Validation Accuracy: 0.367 Precision: 0.908 Recall: 0.633 fpr:0.064 tpr:0.633 f1:0.678
# Average validation set accuracy over 1000 iterations is 81.47%
# Step: 160 loss: 59.471 Validation Accuracy: 0.433 Precision: 0.908 Recall: 0.567 fpr:0.057 tpr:0.567 f1:0.634
# Average validation set accuracy over 1000 iterations is 81.93%
# Step: 161 loss: 58.709 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 82.47%
# Step: 162 loss: 70.387 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 82.93%
# Step: 163 loss: 53.033 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 83.37%
# Step: 164 loss: 52.362 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 83.93%
# Step: 165 loss: 58.180 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 84.40%
# Step: 166 loss: 60.794 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 84.87%
# Step: 167 loss: 55.640 Validation Accuracy: 0.433 Precision: 0.908 Recall: 0.567 fpr:0.057 tpr:0.567 f1:0.634
# Average validation set accuracy over 1000 iterations is 85.37%
# Step: 168 loss: 60.669 Validation Accuracy: 0.367 Precision: 0.908 Recall: 0.633 fpr:0.064 tpr:0.633 f1:0.678
# Average validation set accuracy over 1000 iterations is 85.83%
# Step: 169 loss: 60.080 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 86.30%
# Step: 170 loss: 56.448 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 86.97%
# Step: 171 loss: 59.269 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 87.40%
# Step: 172 loss: 54.529 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 88.00%
# Step: 173 loss: 58.531 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 88.57%
# Step: 174 loss: 56.592 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 89.03%
# Step: 175 loss: 57.789 Validation Accuracy: 0.300 Precision: 0.908 Recall: 0.700 fpr:0.071 tpr:0.700 f1:0.718
# Average validation set accuracy over 1000 iterations is 89.53%
# Step: 176 loss: 58.509 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 90.10%
# Step: 177 loss: 61.640 Validation Accuracy: 0.333 Precision: 0.908 Recall: 0.667 fpr:0.067 tpr:0.667 f1:0.698
# Average validation set accuracy over 1000 iterations is 90.70%
# Step: 178 loss: 54.340 Validation Accuracy: 0.433 Precision: 0.908 Recall: 0.567 fpr:0.057 tpr:0.567 f1:0.634
# Average validation set accuracy over 1000 iterations is 91.20%
# Step: 179 loss: 73.811 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 91.70%
# Step: 180 loss: 57.698 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 92.17%
# Step: 181 loss: 53.830 Validation Accuracy: 0.433 Precision: 0.908 Recall: 0.567 fpr:0.057 tpr:0.567 f1:0.634
# Average validation set accuracy over 1000 iterations is 92.63%
# Step: 182 loss: 56.505 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 93.03%
# Step: 183 loss: 61.101 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 93.60%
# Step: 184 loss: 59.525 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 94.07%
# Step: 185 loss: 65.027 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 94.50%
# Step: 186 loss: 74.043 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 95.03%
# Step: 187 loss: 63.970 Validation Accuracy: 0.633 Precision: 0.908 Recall: 0.367 fpr:0.037 tpr:0.367 f1:0.474
# Average validation set accuracy over 1000 iterations is 95.63%
# Step: 188 loss: 63.019 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 96.10%
# Step: 189 loss: 56.609 Validation Accuracy: 0.400 Precision: 0.908 Recall: 0.600 fpr:0.061 tpr:0.600 f1:0.656
# Average validation set accuracy over 1000 iterations is 96.57%
# Step: 190 loss: 48.899 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 97.07%
# Step: 191 loss: 60.601 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 97.37%
# Step: 192 loss: 59.320 Validation Accuracy: 0.433 Precision: 0.908 Recall: 0.567 fpr:0.057 tpr:0.567 f1:0.634
# Average validation set accuracy over 1000 iterations is 97.93%
# Step: 193 loss: 69.388 Validation Accuracy: 0.367 Precision: 0.908 Recall: 0.633 fpr:0.064 tpr:0.633 f1:0.678
# Average validation set accuracy over 1000 iterations is 98.40%
# Step: 194 loss: 51.514 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 98.97%
# Step: 195 loss: 65.661 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 99.63%
# Step: 196 loss: 55.612 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 100.20%
# Step: 197 loss: 56.500 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 100.63%
# Step: 198 loss: 58.971 Validation Accuracy: 0.433 Precision: 0.908 Recall: 0.567 fpr:0.057 tpr:0.567 f1:0.634
# Average validation set accuracy over 1000 iterations is 101.17%
# Step: 199 loss: 59.466 Validation Accuracy: 0.433 Precision: 0.908 Recall: 0.567 fpr:0.057 tpr:0.567 f1:0.634
# Average validation set accuracy over 1000 iterations is 101.73%
# Step: 200 loss: 55.545 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 102.37%
# Step: 201 loss: 60.572 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 103.17%
# Step: 202 loss: 60.950 Validation Accuracy: 0.667 Precision: 0.908 Recall: 0.333 fpr:0.034 tpr:0.333 f1:0.443
# Average validation set accuracy over 1000 iterations is 103.70%
# Step: 203 loss: 60.965 Validation Accuracy: 0.633 Precision: 0.908 Recall: 0.367 fpr:0.037 tpr:0.367 f1:0.474
# Average validation set accuracy over 1000 iterations is 104.23%
# Step: 204 loss: 72.292 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 104.67%
# Step: 205 loss: 72.853 Validation Accuracy: 0.333 Precision: 0.908 Recall: 0.667 fpr:0.067 tpr:0.667 f1:0.698
# Average validation set accuracy over 1000 iterations is 105.10%
# Step: 206 loss: 64.063 Validation Accuracy: 0.400 Precision: 0.908 Recall: 0.600 fpr:0.061 tpr:0.600 f1:0.656
# Average validation set accuracy over 1000 iterations is 105.57%
# Step: 207 loss: 54.641 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 106.13%
# Step: 208 loss: 73.888 Validation Accuracy: 0.667 Precision: 0.908 Recall: 0.333 fpr:0.034 tpr:0.333 f1:0.443
# Average validation set accuracy over 1000 iterations is 106.67%
# Step: 209 loss: 54.755 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 107.23%
# Step: 210 loss: 68.492 Validation Accuracy: 0.733 Precision: 0.908 Recall: 0.267 fpr:0.027 tpr:0.267 f1:0.374
# Average validation set accuracy over 1000 iterations is 107.60%
# Step: 211 loss: 66.954 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 107.97%
# Step: 212 loss: 63.431 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 108.40%
# Step: 213 loss: 63.865 Validation Accuracy: 0.633 Precision: 0.908 Recall: 0.367 fpr:0.037 tpr:0.367 f1:0.474
# Average validation set accuracy over 1000 iterations is 108.87%
# Step: 214 loss: 60.390 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 109.47%
# Step: 215 loss: 63.039 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 109.90%
# Step: 216 loss: 52.149 Validation Accuracy: 0.233 Precision: 0.908 Recall: 0.767 fpr:0.078 tpr:0.767 f1:0.755
# Average validation set accuracy over 1000 iterations is 110.60%
# Step: 217 loss: 54.894 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 110.93%
# Step: 218 loss: 69.585 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 111.53%
# Step: 219 loss: 58.923 Validation Accuracy: 0.367 Precision: 0.908 Recall: 0.633 fpr:0.064 tpr:0.633 f1:0.678
# Average validation set accuracy over 1000 iterations is 112.13%
# Step: 220 loss: 64.176 Validation Accuracy: 0.367 Precision: 0.908 Recall: 0.633 fpr:0.064 tpr:0.633 f1:0.678
# Average validation set accuracy over 1000 iterations is 112.63%
# Step: 221 loss: 63.588 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 113.10%
# Step: 222 loss: 59.660 Validation Accuracy: 0.333 Precision: 0.908 Recall: 0.667 fpr:0.067 tpr:0.667 f1:0.698
# Average validation set accuracy over 1000 iterations is 113.53%
# Step: 223 loss: 57.061 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 114.10%
# Step: 224 loss: 53.245 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 114.63%
# Step: 225 loss: 53.403 Validation Accuracy: 0.633 Precision: 0.908 Recall: 0.367 fpr:0.037 tpr:0.367 f1:0.474
# Average validation set accuracy over 1000 iterations is 115.13%
# Step: 226 loss: 55.722 Validation Accuracy: 0.633 Precision: 0.908 Recall: 0.367 fpr:0.037 tpr:0.367 f1:0.474
# Average validation set accuracy over 1000 iterations is 115.70%
# Step: 227 loss: 70.054 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 116.27%
# Step: 228 loss: 66.023 Validation Accuracy: 0.700 Precision: 0.908 Recall: 0.300 fpr:0.030 tpr:0.300 f1:0.410
# Average validation set accuracy over 1000 iterations is 116.73%
# Step: 229 loss: 59.271 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 117.10%
# Step: 230 loss: 64.831 Validation Accuracy: 0.400 Precision: 0.908 Recall: 0.600 fpr:0.061 tpr:0.600 f1:0.656
# Average validation set accuracy over 1000 iterations is 117.67%
# Step: 231 loss: 71.119 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 118.20%
# Step: 232 loss: 59.828 Validation Accuracy: 0.433 Precision: 0.908 Recall: 0.567 fpr:0.057 tpr:0.567 f1:0.634
# Average validation set accuracy over 1000 iterations is 118.77%
# Step: 233 loss: 61.603 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 119.33%
# Step: 234 loss: 48.912 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 119.77%
# Step: 235 loss: 49.691 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 120.33%
# Step: 236 loss: 59.810 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 121.03%
# Step: 237 loss: 59.295 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 121.53%
# Step: 238 loss: 53.162 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 122.03%
# Step: 239 loss: 66.733 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 122.63%
# Step: 240 loss: 56.732 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 123.07%
# Step: 241 loss: 61.525 Validation Accuracy: 0.433 Precision: 0.908 Recall: 0.567 fpr:0.057 tpr:0.567 f1:0.634
# Average validation set accuracy over 1000 iterations is 123.53%
# Step: 242 loss: 54.206 Validation Accuracy: 0.433 Precision: 0.908 Recall: 0.567 fpr:0.057 tpr:0.567 f1:0.634
# Average validation set accuracy over 1000 iterations is 124.17%
# Step: 243 loss: 56.218 Validation Accuracy: 0.367 Precision: 0.908 Recall: 0.633 fpr:0.064 tpr:0.633 f1:0.678
# Average validation set accuracy over 1000 iterations is 124.57%
# Step: 244 loss: 61.418 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 125.07%
# Step: 245 loss: 59.026 Validation Accuracy: 0.367 Precision: 0.908 Recall: 0.633 fpr:0.064 tpr:0.633 f1:0.678
# Average validation set accuracy over 1000 iterations is 125.57%
# Step: 246 loss: 70.000 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 126.13%
# Step: 247 loss: 50.262 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 126.77%
# Step: 248 loss: 60.034 Validation Accuracy: 0.633 Precision: 0.908 Recall: 0.367 fpr:0.037 tpr:0.367 f1:0.474
# Average validation set accuracy over 1000 iterations is 127.13%
# Step: 249 loss: 52.634 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 127.50%
# Step: 250 loss: 62.078 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 127.97%
# Step: 251 loss: 56.481 Validation Accuracy: 0.633 Precision: 0.908 Recall: 0.367 fpr:0.037 tpr:0.367 f1:0.474
# Average validation set accuracy over 1000 iterations is 128.40%
# Step: 252 loss: 63.394 Validation Accuracy: 0.667 Precision: 0.908 Recall: 0.333 fpr:0.034 tpr:0.333 f1:0.443
# Average validation set accuracy over 1000 iterations is 128.97%
# Step: 253 loss: 53.397 Validation Accuracy: 0.433 Precision: 0.908 Recall: 0.567 fpr:0.057 tpr:0.567 f1:0.634
# Average validation set accuracy over 1000 iterations is 129.50%
# Step: 254 loss: 68.261 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 129.90%
# Step: 255 loss: 67.174 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 130.30%
# Step: 256 loss: 53.299 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 130.67%
# Step: 257 loss: 50.883 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 131.20%
# Step: 258 loss: 56.167 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 131.67%
# Step: 259 loss: 59.877 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 132.23%
# Step: 260 loss: 49.008 Validation Accuracy: 0.733 Precision: 0.908 Recall: 0.267 fpr:0.027 tpr:0.267 f1:0.374
# Average validation set accuracy over 1000 iterations is 132.83%
# Step: 261 loss: 58.180 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 133.33%
# Step: 262 loss: 58.330 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 133.97%
# Step: 263 loss: 53.357 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 134.53%
# Step: 264 loss: 59.200 Validation Accuracy: 0.400 Precision: 0.908 Recall: 0.600 fpr:0.061 tpr:0.600 f1:0.656
# Average validation set accuracy over 1000 iterations is 135.20%
# Step: 265 loss: 57.681 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 135.50%
# Step: 266 loss: 52.423 Validation Accuracy: 0.367 Precision: 0.908 Recall: 0.633 fpr:0.064 tpr:0.633 f1:0.678
# Average validation set accuracy over 1000 iterations is 136.00%
# Step: 267 loss: 60.005 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 136.27%
# Step: 268 loss: 53.417 Validation Accuracy: 0.700 Precision: 0.908 Recall: 0.300 fpr:0.030 tpr:0.300 f1:0.410
# Average validation set accuracy over 1000 iterations is 136.80%
# Step: 269 loss: 67.587 Validation Accuracy: 0.400 Precision: 0.908 Recall: 0.600 fpr:0.061 tpr:0.600 f1:0.656
# Average validation set accuracy over 1000 iterations is 137.27%
# Step: 270 loss: 58.947 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 137.60%
# Step: 271 loss: 64.271 Validation Accuracy: 0.433 Precision: 0.908 Recall: 0.567 fpr:0.057 tpr:0.567 f1:0.634
# ...
# Average validation set accuracy over 1000 iterations is 465.70%
# Step: 909 loss: 57.849 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 466.30%
# Step: 910 loss: 61.079 Validation Accuracy: 0.433 Precision: 0.908 Recall: 0.567 fpr:0.057 tpr:0.567 f1:0.634
# Average validation set accuracy over 1000 iterations is 467.03%
# Step: 911 loss: 55.102 Validation Accuracy: 0.633 Precision: 0.908 Recall: 0.367 fpr:0.037 tpr:0.367 f1:0.474
# Average validation set accuracy over 1000 iterations is 467.53%
# Step: 912 loss: 61.996 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 468.07%
# Step: 913 loss: 60.088 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 468.50%
# Step: 914 loss: 67.170 Validation Accuracy: 0.367 Precision: 0.908 Recall: 0.633 fpr:0.064 tpr:0.633 f1:0.678
# Average validation set accuracy over 1000 iterations is 469.03%
# Step: 915 loss: 63.813 Validation Accuracy: 0.667 Precision: 0.908 Recall: 0.333 fpr:0.034 tpr:0.333 f1:0.443
# Average validation set accuracy over 1000 iterations is 469.40%
# Step: 916 loss: 65.535 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 470.00%
# Step: 917 loss: 59.628 Validation Accuracy: 0.333 Precision: 0.908 Recall: 0.667 fpr:0.067 tpr:0.667 f1:0.698
# Average validation set accuracy over 1000 iterations is 470.63%
# Step: 918 loss: 54.386 Validation Accuracy: 0.700 Precision: 0.908 Recall: 0.300 fpr:0.030 tpr:0.300 f1:0.410
# Average validation set accuracy over 1000 iterations is 471.20%
# Step: 919 loss: 54.384 Validation Accuracy: 0.633 Precision: 0.908 Recall: 0.367 fpr:0.037 tpr:0.367 f1:0.474
# Average validation set accuracy over 1000 iterations is 471.73%
# Step: 920 loss: 68.659 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 472.37%
# Step: 921 loss: 60.968 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 473.03%
# Step: 922 loss: 60.307 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 473.77%
# Step: 923 loss: 61.639 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 474.47%
# Step: 924 loss: 53.189 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 474.90%
# Step: 925 loss: 58.861 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 475.40%
# Step: 926 loss: 59.681 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 475.80%
# Step: 927 loss: 73.226 Validation Accuracy: 0.400 Precision: 0.908 Recall: 0.600 fpr:0.061 tpr:0.600 f1:0.656
# Average validation set accuracy over 1000 iterations is 476.27%
# Step: 928 loss: 66.591 Validation Accuracy: 0.433 Precision: 0.908 Recall: 0.567 fpr:0.057 tpr:0.567 f1:0.634
# Average validation set accuracy over 1000 iterations is 476.87%
# Step: 929 loss: 51.808 Validation Accuracy: 0.433 Precision: 0.908 Recall: 0.567 fpr:0.057 tpr:0.567 f1:0.634
# Average validation set accuracy over 1000 iterations is 477.40%
# Step: 930 loss: 56.799 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 477.97%
# Step: 931 loss: 56.363 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 478.33%
# Step: 932 loss: 57.271 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 478.77%
# Step: 933 loss: 58.490 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 479.30%
# Step: 934 loss: 63.239 Validation Accuracy: 0.367 Precision: 0.908 Recall: 0.633 fpr:0.064 tpr:0.633 f1:0.678
# Average validation set accuracy over 1000 iterations is 479.80%
# Step: 935 loss: 61.757 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 480.50%
# Step: 936 loss: 58.357 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 481.17%
# Step: 937 loss: 55.925 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 481.53%
# Step: 938 loss: 55.874 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 482.20%
# Step: 939 loss: 66.657 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 482.77%
# Step: 940 loss: 55.635 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 483.33%
# Step: 941 loss: 64.952 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 483.90%
# Step: 942 loss: 55.755 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 484.40%
# Step: 943 loss: 52.153 Validation Accuracy: 0.633 Precision: 0.908 Recall: 0.367 fpr:0.037 tpr:0.367 f1:0.474
# Average validation set accuracy over 1000 iterations is 484.97%
# Step: 944 loss: 61.079 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 485.40%
# Step: 945 loss: 63.870 Validation Accuracy: 0.300 Precision: 0.908 Recall: 0.700 fpr:0.071 tpr:0.700 f1:0.718
# Average validation set accuracy over 1000 iterations is 485.97%
# Step: 946 loss: 57.503 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 486.33%
# Step: 947 loss: 60.788 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 486.80%
# Step: 948 loss: 56.004 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 487.20%
# Step: 949 loss: 61.664 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 487.80%
# Step: 950 loss: 54.184 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 488.30%
# Step: 951 loss: 54.460 Validation Accuracy: 0.633 Precision: 0.908 Recall: 0.367 fpr:0.037 tpr:0.367 f1:0.474
# Average validation set accuracy over 1000 iterations is 488.97%
# Step: 952 loss: 60.270 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 489.60%
# Step: 953 loss: 98.557 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 490.20%
# Step: 954 loss: 59.040 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 490.67%
# Step: 955 loss: 73.443 Validation Accuracy: 0.433 Precision: 0.908 Recall: 0.567 fpr:0.057 tpr:0.567 f1:0.634
# Average validation set accuracy over 1000 iterations is 491.20%
# Step: 956 loss: 64.428 Validation Accuracy: 0.433 Precision: 0.908 Recall: 0.567 fpr:0.057 tpr:0.567 f1:0.634
# Average validation set accuracy over 1000 iterations is 491.87%
# Step: 957 loss: 59.406 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 492.47%
# Step: 958 loss: 60.570 Validation Accuracy: 0.400 Precision: 0.908 Recall: 0.600 fpr:0.061 tpr:0.600 f1:0.656
# Average validation set accuracy over 1000 iterations is 493.00%
# Step: 959 loss: 54.826 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 493.63%
# Step: 960 loss: 54.419 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 494.20%
# Step: 961 loss: 55.281 Validation Accuracy: 0.333 Precision: 0.908 Recall: 0.667 fpr:0.067 tpr:0.667 f1:0.698
# Average validation set accuracy over 1000 iterations is 494.63%
# Step: 962 loss: 63.387 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 495.17%
# Step: 963 loss: 66.414 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 495.73%
# Step: 964 loss: 56.348 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 496.27%
# Step: 965 loss: 63.817 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 496.77%
# Step: 966 loss: 59.488 Validation Accuracy: 0.667 Precision: 0.908 Recall: 0.333 fpr:0.034 tpr:0.333 f1:0.443
# Average validation set accuracy over 1000 iterations is 497.20%
# Step: 967 loss: 66.450 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 497.87%
# Step: 968 loss: 64.365 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 498.43%
# Step: 969 loss: 59.886 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 498.97%
# Step: 970 loss: 70.717 Validation Accuracy: 0.733 Precision: 0.908 Recall: 0.267 fpr:0.027 tpr:0.267 f1:0.374
# Average validation set accuracy over 1000 iterations is 499.63%
# Step: 971 loss: 58.158 Validation Accuracy: 0.667 Precision: 0.908 Recall: 0.333 fpr:0.034 tpr:0.333 f1:0.443
# Average validation set accuracy over 1000 iterations is 500.17%
# Step: 972 loss: 67.631 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 500.70%
# Step: 973 loss: 63.856 Validation Accuracy: 0.633 Precision: 0.908 Recall: 0.367 fpr:0.037 tpr:0.367 f1:0.474
# Average validation set accuracy over 1000 iterations is 501.30%
# Step: 974 loss: 55.550 Validation Accuracy: 0.667 Precision: 0.908 Recall: 0.333 fpr:0.034 tpr:0.333 f1:0.443
# Average validation set accuracy over 1000 iterations is 501.87%
# Step: 975 loss: 57.732 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 502.23%
# Step: 976 loss: 57.692 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 502.70%
# Step: 977 loss: 59.731 Validation Accuracy: 0.433 Precision: 0.908 Recall: 0.567 fpr:0.057 tpr:0.567 f1:0.634
# Average validation set accuracy over 1000 iterations is 503.30%
# Step: 978 loss: 60.074 Validation Accuracy: 0.433 Precision: 0.908 Recall: 0.567 fpr:0.057 tpr:0.567 f1:0.634
# Average validation set accuracy over 1000 iterations is 504.03%
# Step: 979 loss: 61.688 Validation Accuracy: 0.700 Precision: 0.908 Recall: 0.300 fpr:0.030 tpr:0.300 f1:0.410
# Average validation set accuracy over 1000 iterations is 504.57%
# Step: 980 loss: 63.632 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 504.93%
# Step: 981 loss: 55.989 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 505.47%
# Step: 982 loss: 60.197 Validation Accuracy: 0.567 Precision: 0.908 Recall: 0.433 fpr:0.044 tpr:0.433 f1:0.533
# Average validation set accuracy over 1000 iterations is 505.93%
# Step: 983 loss: 65.686 Validation Accuracy: 0.367 Precision: 0.908 Recall: 0.633 fpr:0.064 tpr:0.633 f1:0.678
# Average validation set accuracy over 1000 iterations is 506.37%
# Step: 984 loss: 73.152 Validation Accuracy: 0.367 Precision: 0.908 Recall: 0.633 fpr:0.064 tpr:0.633 f1:0.678
# Average validation set accuracy over 1000 iterations is 506.93%
# Step: 985 loss: 79.577 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 507.37%
# Step: 986 loss: 59.863 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 507.83%
# Step: 987 loss: 58.368 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 508.30%
# Step: 988 loss: 51.086 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 508.73%
# Step: 989 loss: 69.600 Validation Accuracy: 0.600 Precision: 0.908 Recall: 0.400 fpr:0.040 tpr:0.400 f1:0.504
# Average validation set accuracy over 1000 iterations is 509.27%
# Step: 990 loss: 68.670 Validation Accuracy: 0.533 Precision: 0.908 Recall: 0.467 fpr:0.047 tpr:0.467 f1:0.560
# Average validation set accuracy over 1000 iterations is 509.93%
# Step: 991 loss: 61.414 Validation Accuracy: 0.633 Precision: 0.908 Recall: 0.367 fpr:0.037 tpr:0.367 f1:0.474
# Average validation set accuracy over 1000 iterations is 510.33%
# Step: 992 loss: 56.909 Validation Accuracy: 0.433 Precision: 0.908 Recall: 0.567 fpr:0.057 tpr:0.567 f1:0.634
# Average validation set accuracy over 1000 iterations is 510.83%
# Step: 993 loss: 66.824 Validation Accuracy: 0.400 Precision: 0.908 Recall: 0.600 fpr:0.061 tpr:0.600 f1:0.656
# Average validation set accuracy over 1000 iterations is 511.47%
# Step: 994 loss: 64.177 Validation Accuracy: 0.367 Precision: 0.908 Recall: 0.633 fpr:0.064 tpr:0.633 f1:0.678
# Average validation set accuracy over 1000 iterations is 511.93%
# Step: 995 loss: 60.130 Validation Accuracy: 0.500 Precision: 0.908 Recall: 0.500 fpr:0.051 tpr:0.500 f1:0.586
# Average validation set accuracy over 1000 iterations is 512.40%
# Step: 996 loss: 57.378 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 512.97%
# Step: 997 loss: 77.524 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 513.53%
# Step: 998 loss: 57.792 Validation Accuracy: 0.633 Precision: 0.908 Recall: 0.367 fpr:0.037 tpr:0.367 f1:0.474
# Average validation set accuracy over 1000 iterations is 513.97%
# Step: 999 loss: 60.597 Validation Accuracy: 0.467 Precision: 0.908 Recall: 0.533 fpr:0.054 tpr:0.533 f1:0.610
# Average validation set accuracy over 1000 iterations is 514.43%

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score,  f1_score

#clf = svm.SVC(kernel='rbf',degree=3, probability=False,tol=0.001)
#clf = RandomForestClassifier(n_estimators=100,random_state=0)
clf = LogisticRegression(C=0.1)
clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
fpr, tpr = roc_curve(y_test,y_pred)
print(confusion_matrix(y_test,y_pred))  
print(classification_report(y_test,y_pred))  
print(precision_score(y_test,y_pred))
print( recall_score(y_test,y_pred))
print( f1_score(y_test,y_pred))
print(accuracy_score(y_test, y_pred))
print(fpr, tpr)

# %% [markdown]
# <a href="https://colab.research.google.com/github/EziamaUgonna/Bayesian_analysis-/blob/master/Dissertation_work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade -q gspread
from tensorboardcolab import *
import shutil
#clean out the directory
shutil.rmtree('./Graph', ignore_errors=True)
os.mkdir('./Graph')
#tf.reset_default_graph()
#will start the tunneling and will print out a link:
tbc=TensorBoardColab()

# %%
# !pip show tensorflow

# %%
# !pip show tensorflow_probability

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

# %%
# Dependencies
import os 
import warnings 
#from absl import flags 
import matplotlib 
import numpy as np 
import tensorflow as tf 
import tensorflow_probability as tfp
import math
import pandas as pd
tfd = tfp.distributions
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
#from hyperopt import fmin, tpe, hp, STATUS_OK, STATUS_FAIL, Trials
#import python_utils

# %%
# clear graph (if any) before running 
tf.reset_default_graph()

# %%
####Delete all flags before declare#####

def del_all_flags(FLAGS):
    flags_dict = FLAGS._flags()    
    keys_list = [keys for keys in flags_dict]    
    for keys in keys_list:
        FLAGS.__delattr__(keys)

del_all_flags(tf.flags.FLAGS)

flags = tf.app.flags
FLAGS = tf.app.flags.FLAGS
flags.DEFINE_float("learning_rate", default = 0.0001, help = "Initial learning rate.")
flags.DEFINE_integer("epochs", default = 700, help = "Number of epochs to train for")
flags.DEFINE_integer("batch_size", default =128, help = "Batch size.")
flags.DEFINE_integer("eval_freq", default = 400, help =" Frequency at which to validate the model.")
flags.DEFINE_float("kernel_posterior_scale_mean", default = -0.9, help = "Initial kernel posterior mean of the scale (log var) for q(w)")
flags.DEFINE_float("kernel_posterior_scale_constraint", default = 0.2, help = "Posterior kernel constraint for the scale (log var) for q(w)")
flags.DEFINE_float("kl_annealing", default = 50, help = "Epochs to anneal the KL term (anneals from 0 to 1)")
flags.DEFINE_integer("num_hidden_layers", default = 4, help = "Number of hidden layers")
flags.DEFINE_integer("num_monte_carlo",

                     default=50,

                     help="Network draws to compute predictive probabilities.")
tf.app.flags.DEFINE_string('f', '', 'kernel')
#initialize flags 
#FLAGS = flags.FLAGS
print(FLAGS.learning_rate)
print(FLAGS.epochs)
print(FLAGS.num_monte_carlo)
# Out:
# 0.0001
# 700
# 50

# %%
def build_input_pipeline(X_train,X_test,y_train, y_test, batch_size, valid_size):
  #Build an iterator over training batches 
  training_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
  #Shuffle the dataset (note shuffle argument much larger than training size)
  # and form batches of size batch_size
  training_batches = training_dataset.shuffle(20000, reshuffle_each_iteration =True).repeat().batch(batch_size)
  training_iterator = tf.data.make_one_shot_iterator(training_batches)
  
  #Building iterator over the heldout set with batch_size = heldout_size,
  # i.e., return the entire heldout set as a constant.
  heldout_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test))
  heldout_batches = heldout_dataset.repeat().batch(valid_size)
  heldout_iterator = tf.data.make_one_shot_iterator(heldout_batches)
  
  #Combine these into a feasible iterator that can switch between training 
  # and validation inputs.
  # Here should be minibatch increment be defined 
  handle = tf.placeholder(tf.string, shape = [])
  feedable_iterator = tf.data.Iterator.from_string_handle(handle, training_batches.output_types, training_batches.output_shapes)
  features_final, labels_final = feedable_iterator.get_next()
  
  return features_final, labels_final, handle, training_iterator, heldout_iterator

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !ls "/content/gdrive/My Drive/"
# Out:
#  BNN_Work.ipynb     Untitled0.ipynb   work2.csv
# 'Colab Notebooks'   Untitled1.ipynb

# %%
# Read in the dataset
df = pd.read_csv('/content/gdrive/My Drive/work2.csv').astype(np.float32)
change = df.query('Speed>0').sample(frac = .1).index
df.loc[change, 'Speed'] = 0
df.loc[change, 'Class'] = 0
df.to_csv('work2.csv', header = True, index =False)
df.shape
# Out:
# (1048575, 20)

# %%
X = df.iloc[:,:-1].values
y = df.iloc[:,-1].values

# %%
X.dtype
# Out:
# dtype('float32')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state =1)

#reshape y-data to become column vector 
y_train = np.reshape(y_train, [-1,1])
y_test = np.reshape(y_test, [-1,1])

# %%
# Standardize the dataset 
scalar_x_train = StandardScaler().fit(X_train)
scalar_x_test = StandardScaler().fit(X_test)
X_train = scalar_x_train.transform(X_train)
X_test = scalar_x_test.transform(X_test)

# %%
def main(argv):
  # extract the activation function from the hyperopt spec as an attribute from the tf.nn module 
  #activation = getattr(tf.nn, FLAGS.activation_function)
  # define the graph 
  #with tf.Graph().as_default():
  (features_final, labels_final, handle, training_iterator, heldout_iterator) = build_input_pipeline(X_train,X_test, y_train,y_test, FLAGS.batch_size, 500)
  
  
  # Building the Bayesian Neural Network 
  # we are Gaussian Reparametrization Trick 
  # to compute the stochastic gradients as described in the paper 
  with tf.name_scope("bayesian_neural_net", values =[features_final]):
    neural_net = tf.keras.Sequential()
    for i in range(FLAGS.num_hidden_layers):
      layer = tfp.layers.DenseReparameterization(
          units = 10,
          activation = tf.nn.relu,
          trainable = True,
          kernel_prior_fn=tfp.layers.default_multivariate_normal_fn, # NormalDiag
          kernel_posterior_fn=tfp.layers.default_mean_field_normal_fn(),
          #kernel_posterior_fn=tfp_layers_util.default_mean_field_normal_fn(), # softplus(sigma)
          kernel_posterior_tensor_fn=lambda x: x.sample(),
          bias_prior_fn=tfp.layers.default_multivariate_normal_fn, # NormalDiag
          bias_posterior_fn=tfp.layers.default_mean_field_normal_fn(), # softplus(sigma)
          bias_posterior_tensor_fn=lambda x: x.sample()
          )
      neural_net.add(layer)
  neural_net.add(tfp.layers.DenseReparameterization(
      units=2, # one dimensional output
      activation= tf.nn.sigmoid, # since regression (outcome not bounded)
      trainable=True, # i.e subject to optimization
      kernel_prior_fn=tfp.layers.default_multivariate_normal_fn, # NormalDiag with hyperopt sigma
      kernel_posterior_fn=tfp.layers.default_mean_field_normal_fn(), # softplus(sigma)
      kernel_posterior_tensor_fn=lambda x: x.sample(),
      bias_prior_fn =tfp.layers.default_multivariate_normal_fn, # NormalDiag with hyperopt sigma
      bias_posterior_fn=tfp.layers.default_mean_field_normal_fn(), # softplus(sigma)
      bias_posterior_tensor_fn=lambda x: x.sample()
      ))
  logits = neural_net(features_final)
  labels_distribution = tfd.Categorical(logits=logits)
  # Perform KL annealing. The optimal number of annealing steps 
  # depends on the dataset and architecture.
  t = tf.Variable(0.0)
  kl_regularizer = t / (FLAGS.kl_annealing * len(X_train) / FLAGS.batch_size)
  
  #Compute the -ELBO as the loss. The kl term is annealed from 1 to 1 over 
  # the epochs specified by the kl_annealing flag.
  log_likelihood = labels_distribution.log_prob(labels_final)
  #neg_log_likelihood = tf.reduce_mean(tf.squared_difference(logits,labels_final))
  neg_log_likelihood = -tf.reduce_mean(input_tensor = log_likelihood)
  kl = sum(neural_net.losses)/len(X_train) * tf.minimum(1.0, kl_regularizer)
  elbo_loss = neg_log_likelihood + kl
  
  # Build metrics for evaluation. Predictions are formed from single forward 
  # pass of the probablisitic layers . They are cheap but noisy predictions
  predictions = tf.argmax(input = logits, axis=1)
  with tf.name_scope("train"):
    train_accuracy, train_accuracy_update_op = tf.metrics.accuracy(labels=labels_final,predictions =predictions)
    opt = tf.train.AdamOptimizer(FLAGS.learning_rate)
    train_op = opt.minimize(elbo_loss)
    update_step_op = tf.assign(t, t+1)
  
  with tf.name_scope("valid"):
    valid_accuracy, validation_accuracy_update_op = tf.metrics.accuracy(labels= labels_final,predictions = predictions)
    
  
  init_op = tf.group(tf.global_variables_initializer(),
                     tf.local_variables_initializer())
  
  stream_vars_valid = [ v for v in tf.local_variables() if "valid" in v.name]
  
  reset_valid_op = tf.variables_initializer(stream_vars_valid)
  
  with tf.Session() as sess:
    sess.run(init_op)
    
    # Run the training loop

    train_handle = sess.run(training_iterator.string_handle())

    heldout_handle = sess.run(heldout_iterator.string_handle())

    training_steps = int(

        round(FLAGS.epochs * (len(X_train) / FLAGS.batch_size)))

    for step in range(training_steps):

      _ = sess.run([train_op,train_accuracy_update_op, update_step_op],feed_dict={handle: train_handle})
      
      # Manually print the frequency 
      if step % 100 == 0:
        loss_value, accuracy_value, kl_value = sess.run([elbo_loss, train_accuracy, kl], feed_dict= {handle:train_handle})
        print("Step:{:>3d} loss : {:.3f} KL: {:.3f}" .format(step , loss_value, accuracy_value, kl_value))
        
      if (step +1) % FLAGS.eval_freq ==0: 
        # Compute log prob of heldout set by averaging draws from the model:
        # p(heldout | train) = int_model p(heldout|model) p(model|train) ~= 1/n * sum_{i=1}^n p(heldout | model_i)
        # where model_i is a draw from the posterior 
        #p(model|train)
        probs = np.asarray([sess.run((labels_distribution.probs), 
                                     feed_dict ={handle: heldout_handle})
      
                            for _ in range(FLAGS.num_monte_carlo)])
     
        mean_probs = np.mean(probs, axis =0).astype(np.int32)
        print(mean_probs.dtype)
        
        _, label_vals = sess.run((features_final, labels_final), feed_dict = {handle: heldout_handle})
        label_vals = (label_vals).astype(np.int32)
      
        heldout_lp = np.mean(np.log(mean_probs[np.arange(mean_probs.shape[0]), label_vals]))
        
        
        print(" ...Held_out nats: {:.3f}".format(heldout_lp))
        
       # Calculate validation accuracy

        for _ in range(20):

          sess.run(validation_accuracy_update_op, feed_dict={handle: heldout_handle})

        valid_value = sess.run(

            valid_accuracy, feed_dict={handle: heldout_handle})

        print(

            " ... Validation Accuracy: {:.3f}".format(valid_value))

        sess.run(reset_valid_op)
if __name__ == "__main__": 
  tf.app.run()
# Out:
# Step:  0 loss : 0.688 KL: 0.914
# Step:100 loss : 0.681 KL: 0.801
# Step:200 loss : 0.681 KL: 0.825
# Step:300 loss : 0.672 KL: 0.852
# int32
#  ...Held_out nats: -inf
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:112: RuntimeWarning: divide by zero encountered in log
#  ... Validation Accuracy: 0.904
# Step:400 loss : 0.669 KL: 0.866
# Step:500 loss : 0.663 KL: 0.875
# Step:600 loss : 0.658 KL: 0.880
# Step:700 loss : 0.616 KL: 0.884
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:800 loss : 0.591 KL: 0.887
# Step:900 loss : 0.551 KL: 0.889
# Step:1000 loss : 0.507 KL: 0.891
# Step:1100 loss : 0.460 KL: 0.893
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.912
# Step:1200 loss : 0.434 KL: 0.894
# Step:1300 loss : 0.481 KL: 0.895
# Step:1400 loss : 0.367 KL: 0.896
# Step:1500 loss : 0.428 KL: 0.897
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:1600 loss : 0.497 KL: 0.898
# Step:1700 loss : 0.429 KL: 0.898
# Step:1800 loss : 0.387 KL: 0.899
# Step:1900 loss : 0.418 KL: 0.899
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:2000 loss : 0.381 KL: 0.900
# Step:2100 loss : 0.409 KL: 0.900
# Step:2200 loss : 0.393 KL: 0.900
# Step:2300 loss : 0.440 KL: 0.901
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:2400 loss : 0.394 KL: 0.901
# Step:2500 loss : 0.400 KL: 0.901
# Step:2600 loss : 0.376 KL: 0.902
# Step:2700 loss : 0.368 KL: 0.902
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:2800 loss : 0.401 KL: 0.902
# Step:2900 loss : 0.400 KL: 0.902
# Step:3000 loss : 0.384 KL: 0.902
# Step:3100 loss : 0.400 KL: 0.902
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:3200 loss : 0.439 KL: 0.902
# Step:3300 loss : 0.423 KL: 0.902
# Step:3400 loss : 0.407 KL: 0.903
# Step:3500 loss : 0.423 KL: 0.903
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:3600 loss : 0.361 KL: 0.903
# Step:3700 loss : 0.392 KL: 0.903
# Step:3800 loss : 0.423 KL: 0.903
# Step:3900 loss : 0.399 KL: 0.903
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:4000 loss : 0.407 KL: 0.904
# Step:4100 loss : 0.407 KL: 0.904
# Step:4200 loss : 0.415 KL: 0.904
# Step:4300 loss : 0.376 KL: 0.904
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:4400 loss : 0.399 KL: 0.904
# Step:4500 loss : 0.415 KL: 0.904
# Step:4600 loss : 0.407 KL: 0.904
# Step:4700 loss : 0.438 KL: 0.904
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:4800 loss : 0.399 KL: 0.905
# Step:4900 loss : 0.384 KL: 0.905
# Step:5000 loss : 0.391 KL: 0.905
# Step:5100 loss : 0.430 KL: 0.905
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:5200 loss : 0.399 KL: 0.905
# Step:5300 loss : 0.462 KL: 0.905
# Step:5400 loss : 0.392 KL: 0.905
# Step:5500 loss : 0.407 KL: 0.905
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.904
# Step:5600 loss : 0.376 KL: 0.905
# Step:5700 loss : 0.407 KL: 0.905
# Step:5800 loss : 0.384 KL: 0.905
# Step:5900 loss : 0.384 KL: 0.905
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:6000 loss : 0.399 KL: 0.905
# Step:6100 loss : 0.399 KL: 0.905
# Step:6200 loss : 0.391 KL: 0.905
# Step:6300 loss : 0.407 KL: 0.905
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:6400 loss : 0.399 KL: 0.905
# Step:6500 loss : 0.430 KL: 0.906
# Step:6600 loss : 0.399 KL: 0.906
# Step:6700 loss : 0.384 KL: 0.906
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:6800 loss : 0.407 KL: 0.906
# Step:6900 loss : 0.384 KL: 0.906
# Step:7000 loss : 0.423 KL: 0.906
# Step:7100 loss : 0.399 KL: 0.906
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.899
# Step:7200 loss : 0.407 KL: 0.906
# Step:7300 loss : 0.384 KL: 0.906
# Step:7400 loss : 0.391 KL: 0.906
# Step:7500 loss : 0.430 KL: 0.906
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:7600 loss : 0.376 KL: 0.906
# Step:7700 loss : 0.407 KL: 0.906
# Step:7800 loss : 0.368 KL: 0.906
# Step:7900 loss : 0.438 KL: 0.906
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:8000 loss : 0.446 KL: 0.906
# Step:8100 loss : 0.360 KL: 0.906
# Step:8200 loss : 0.384 KL: 0.906
# Step:8300 loss : 0.423 KL: 0.906
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:8400 loss : 0.415 KL: 0.906
# Step:8500 loss : 0.399 KL: 0.906
# Step:8600 loss : 0.415 KL: 0.906
# Step:8700 loss : 0.415 KL: 0.906
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:8800 loss : 0.415 KL: 0.906
# Step:8900 loss : 0.438 KL: 0.906
# Step:9000 loss : 0.407 KL: 0.906
# Step:9100 loss : 0.407 KL: 0.906
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:9200 loss : 0.399 KL: 0.906
# Step:9300 loss : 0.407 KL: 0.906
# Step:9400 loss : 0.430 KL: 0.906
# Step:9500 loss : 0.423 KL: 0.906
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.900
# Step:9600 loss : 0.407 KL: 0.906
# Step:9700 loss : 0.446 KL: 0.906
# Step:9800 loss : 0.384 KL: 0.906
# Step:9900 loss : 0.446 KL: 0.906
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:10000 loss : 0.485 KL: 0.906
# Step:10100 loss : 0.438 KL: 0.906
# Step:10200 loss : 0.446 KL: 0.906
# Step:10300 loss : 0.391 KL: 0.906
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.910
# Step:10400 loss : 0.376 KL: 0.906
# Step:10500 loss : 0.462 KL: 0.906
# Step:10600 loss : 0.423 KL: 0.906
# Step:10700 loss : 0.407 KL: 0.906
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.911
# Step:10800 loss : 0.391 KL: 0.906
# Step:10900 loss : 0.423 KL: 0.907
# Step:11000 loss : 0.438 KL: 0.907
# Step:11100 loss : 0.415 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:11200 loss : 0.407 KL: 0.907
# Step:11300 loss : 0.407 KL: 0.907
# Step:11400 loss : 0.399 KL: 0.907
# Step:11500 loss : 0.391 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:11600 loss : 0.423 KL: 0.907
# Step:11700 loss : 0.415 KL: 0.907
# Step:11800 loss : 0.431 KL: 0.907
# Step:11900 loss : 0.415 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.901
# Step:12000 loss : 0.438 KL: 0.907
# Step:12100 loss : 0.399 KL: 0.907
# Step:12200 loss : 0.438 KL: 0.907
# Step:12300 loss : 0.407 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:12400 loss : 0.368 KL: 0.907
# Step:12500 loss : 0.384 KL: 0.907
# Step:12600 loss : 0.399 KL: 0.907
# Step:12700 loss : 0.391 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.913
# Step:12800 loss : 0.384 KL: 0.907
# Step:12900 loss : 0.399 KL: 0.907
# Step:13000 loss : 0.407 KL: 0.907
# Step:13100 loss : 0.407 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.913
# Step:13200 loss : 0.407 KL: 0.907
# Step:13300 loss : 0.438 KL: 0.907
# Step:13400 loss : 0.415 KL: 0.907
# Step:13500 loss : 0.415 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:13600 loss : 0.446 KL: 0.907
# Step:13700 loss : 0.415 KL: 0.907
# Step:13800 loss : 0.407 KL: 0.907
# Step:13900 loss : 0.376 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:14000 loss : 0.438 KL: 0.907
# Step:14100 loss : 0.384 KL: 0.907
# Step:14200 loss : 0.446 KL: 0.907
# Step:14300 loss : 0.384 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:14400 loss : 0.391 KL: 0.907
# Step:14500 loss : 0.423 KL: 0.907
# Step:14600 loss : 0.376 KL: 0.907
# Step:14700 loss : 0.454 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:14800 loss : 0.415 KL: 0.907
# Step:14900 loss : 0.391 KL: 0.907
# Step:15000 loss : 0.415 KL: 0.907
# Step:15100 loss : 0.431 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.913
# Step:15200 loss : 0.391 KL: 0.907
# Step:15300 loss : 0.407 KL: 0.907
# Step:15400 loss : 0.399 KL: 0.907
# Step:15500 loss : 0.399 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.910
# Step:15600 loss : 0.368 KL: 0.907
# Step:15700 loss : 0.470 KL: 0.907
# Step:15800 loss : 0.431 KL: 0.907
# Step:15900 loss : 0.407 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:16000 loss : 0.431 KL: 0.907
# Step:16100 loss : 0.391 KL: 0.907
# Step:16200 loss : 0.407 KL: 0.907
# Step:16300 loss : 0.462 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:16400 loss : 0.384 KL: 0.907
# Step:16500 loss : 0.384 KL: 0.907
# Step:16600 loss : 0.423 KL: 0.907
# Step:16700 loss : 0.360 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:16800 loss : 0.384 KL: 0.907
# Step:16900 loss : 0.407 KL: 0.907
# Step:17000 loss : 0.407 KL: 0.907
# Step:17100 loss : 0.431 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.911
# Step:17200 loss : 0.399 KL: 0.907
# Step:17300 loss : 0.407 KL: 0.907
# Step:17400 loss : 0.415 KL: 0.907
# Step:17500 loss : 0.376 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.911
# Step:17600 loss : 0.431 KL: 0.907
# Step:17700 loss : 0.423 KL: 0.907
# Step:17800 loss : 0.415 KL: 0.907
# Step:17900 loss : 0.438 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.913
# Step:18000 loss : 0.477 KL: 0.907
# Step:18100 loss : 0.384 KL: 0.907
# Step:18200 loss : 0.407 KL: 0.907
# Step:18300 loss : 0.415 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:18400 loss : 0.446 KL: 0.907
# Step:18500 loss : 0.415 KL: 0.907
# Step:18600 loss : 0.423 KL: 0.907
# Step:18700 loss : 0.415 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.910
# Step:18800 loss : 0.376 KL: 0.907
# Step:18900 loss : 0.399 KL: 0.907
# Step:19000 loss : 0.384 KL: 0.907
# Step:19100 loss : 0.391 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:19200 loss : 0.360 KL: 0.907
# Step:19300 loss : 0.415 KL: 0.907
# Step:19400 loss : 0.384 KL: 0.907
# Step:19500 loss : 0.431 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.911
# Step:19600 loss : 0.376 KL: 0.907
# Step:19700 loss : 0.384 KL: 0.907
# Step:19800 loss : 0.407 KL: 0.907
# Step:19900 loss : 0.399 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.911
# Step:20000 loss : 0.423 KL: 0.907
# Step:20100 loss : 0.431 KL: 0.907
# Step:20200 loss : 0.423 KL: 0.907
# Step:20300 loss : 0.415 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:20400 loss : 0.376 KL: 0.907
# Step:20500 loss : 0.399 KL: 0.907
# Step:20600 loss : 0.391 KL: 0.907
# Step:20700 loss : 0.415 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:20800 loss : 0.384 KL: 0.907
# Step:20900 loss : 0.399 KL: 0.907
# Step:21000 loss : 0.399 KL: 0.907
# Step:21100 loss : 0.376 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:21200 loss : 0.376 KL: 0.907
# Step:21300 loss : 0.415 KL: 0.907
# Step:21400 loss : 0.360 KL: 0.907
# Step:21500 loss : 0.376 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.903
# Step:21600 loss : 0.384 KL: 0.907
# Step:21700 loss : 0.384 KL: 0.907
# Step:21800 loss : 0.407 KL: 0.907
# Step:21900 loss : 0.438 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:22000 loss : 0.368 KL: 0.907
# Step:22100 loss : 0.431 KL: 0.907
# Step:22200 loss : 0.415 KL: 0.907
# Step:22300 loss : 0.407 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:22400 loss : 0.391 KL: 0.907
# Step:22500 loss : 0.431 KL: 0.907
# Step:22600 loss : 0.352 KL: 0.907
# Step:22700 loss : 0.391 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:22800 loss : 0.368 KL: 0.907
# Step:22900 loss : 0.376 KL: 0.907
# Step:23000 loss : 0.407 KL: 0.907
# Step:23100 loss : 0.399 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:23200 loss : 0.384 KL: 0.907
# Step:23300 loss : 0.407 KL: 0.907
# Step:23400 loss : 0.446 KL: 0.907
# Step:23500 loss : 0.407 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:23600 loss : 0.399 KL: 0.907
# Step:23700 loss : 0.391 KL: 0.907
# Step:23800 loss : 0.384 KL: 0.907
# Step:23900 loss : 0.454 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:24000 loss : 0.391 KL: 0.907
# Step:24100 loss : 0.384 KL: 0.907
# Step:24200 loss : 0.438 KL: 0.907
# Step:24300 loss : 0.384 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:24400 loss : 0.384 KL: 0.907
# Step:24500 loss : 0.391 KL: 0.907
# Step:24600 loss : 0.391 KL: 0.907
# Step:24700 loss : 0.384 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.912
# Step:24800 loss : 0.399 KL: 0.907
# Step:24900 loss : 0.399 KL: 0.907
# Step:25000 loss : 0.431 KL: 0.907
# Step:25100 loss : 0.407 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:25200 loss : 0.360 KL: 0.907
# Step:25300 loss : 0.360 KL: 0.907
# Step:25400 loss : 0.399 KL: 0.907
# Step:25500 loss : 0.384 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.904
# Step:25600 loss : 0.399 KL: 0.907
# Step:25700 loss : 0.391 KL: 0.907
# Step:25800 loss : 0.415 KL: 0.907
# Step:25900 loss : 0.438 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:26000 loss : 0.399 KL: 0.907
# Step:26100 loss : 0.376 KL: 0.907
# Step:26200 loss : 0.423 KL: 0.907
# Step:26300 loss : 0.438 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:26400 loss : 0.391 KL: 0.907
# Step:26500 loss : 0.368 KL: 0.907
# Step:26600 loss : 0.415 KL: 0.907
# Step:26700 loss : 0.399 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:26800 loss : 0.423 KL: 0.907
# Step:26900 loss : 0.407 KL: 0.907
# Step:27000 loss : 0.407 KL: 0.907
# Step:27100 loss : 0.391 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.912
# Step:27200 loss : 0.376 KL: 0.907
# Step:27300 loss : 0.446 KL: 0.907
# Step:27400 loss : 0.391 KL: 0.907
# Step:27500 loss : 0.399 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:27600 loss : 0.376 KL: 0.908
# Step:27700 loss : 0.376 KL: 0.907
# Step:27800 loss : 0.399 KL: 0.907
# Step:27900 loss : 0.399 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:28000 loss : 0.431 KL: 0.907
# Step:28100 loss : 0.399 KL: 0.907
# Step:28200 loss : 0.431 KL: 0.907
# Step:28300 loss : 0.454 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:28400 loss : 0.399 KL: 0.907
# Step:28500 loss : 0.423 KL: 0.907
# Step:28600 loss : 0.399 KL: 0.907
# Step:28700 loss : 0.431 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:28800 loss : 0.454 KL: 0.907
# Step:28900 loss : 0.345 KL: 0.907
# Step:29000 loss : 0.391 KL: 0.907
# Step:29100 loss : 0.423 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:29200 loss : 0.407 KL: 0.907
# Step:29300 loss : 0.415 KL: 0.907
# Step:29400 loss : 0.391 KL: 0.907
# Step:29500 loss : 0.423 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.910
# Step:29600 loss : 0.391 KL: 0.907
# Step:29700 loss : 0.360 KL: 0.907
# Step:29800 loss : 0.399 KL: 0.907
# Step:29900 loss : 0.438 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:30000 loss : 0.454 KL: 0.907
# Step:30100 loss : 0.415 KL: 0.907
# Step:30200 loss : 0.438 KL: 0.908
# Step:30300 loss : 0.407 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:30400 loss : 0.376 KL: 0.908
# Step:30500 loss : 0.423 KL: 0.908
# Step:30600 loss : 0.384 KL: 0.908
# Step:30700 loss : 0.360 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:30800 loss : 0.384 KL: 0.908
# Step:30900 loss : 0.376 KL: 0.908
# Step:31000 loss : 0.415 KL: 0.908
# Step:31100 loss : 0.399 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:31200 loss : 0.423 KL: 0.908
# Step:31300 loss : 0.423 KL: 0.908
# Step:31400 loss : 0.415 KL: 0.908
# Step:31500 loss : 0.501 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:31600 loss : 0.399 KL: 0.908
# Step:31700 loss : 0.376 KL: 0.908
# Step:31800 loss : 0.415 KL: 0.908
# Step:31900 loss : 0.391 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:32000 loss : 0.423 KL: 0.908
# Step:32100 loss : 0.431 KL: 0.908
# Step:32200 loss : 0.407 KL: 0.908
# Step:32300 loss : 0.384 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:32400 loss : 0.360 KL: 0.908
# Step:32500 loss : 0.391 KL: 0.908
# Step:32600 loss : 0.407 KL: 0.908
# Step:32700 loss : 0.391 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:32800 loss : 0.423 KL: 0.908
# Step:32900 loss : 0.438 KL: 0.908
# Step:33000 loss : 0.376 KL: 0.908
# Step:33100 loss : 0.431 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.901
# Step:33200 loss : 0.360 KL: 0.908
# Step:33300 loss : 0.415 KL: 0.908
# Step:33400 loss : 0.391 KL: 0.908
# Step:33500 loss : 0.438 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:33600 loss : 0.376 KL: 0.908
# Step:33700 loss : 0.407 KL: 0.908
# Step:33800 loss : 0.384 KL: 0.908
# Step:33900 loss : 0.399 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:34000 loss : 0.423 KL: 0.908
# Step:34100 loss : 0.431 KL: 0.908
# Step:34200 loss : 0.407 KL: 0.908
# Step:34300 loss : 0.438 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:34400 loss : 0.423 KL: 0.908
# Step:34500 loss : 0.407 KL: 0.908
# Step:34600 loss : 0.376 KL: 0.908
# Step:34700 loss : 0.376 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:34800 loss : 0.454 KL: 0.908
# Step:34900 loss : 0.376 KL: 0.908
# Step:35000 loss : 0.470 KL: 0.908
# Step:35100 loss : 0.415 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.904
# Step:35200 loss : 0.415 KL: 0.908
# Step:35300 loss : 0.423 KL: 0.908
# Step:35400 loss : 0.352 KL: 0.908
# Step:35500 loss : 0.415 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.900
# Step:35600 loss : 0.431 KL: 0.908
# Step:35700 loss : 0.423 KL: 0.908
# Step:35800 loss : 0.391 KL: 0.908
# Step:35900 loss : 0.384 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:36000 loss : 0.384 KL: 0.908
# Step:36100 loss : 0.360 KL: 0.908
# Step:36200 loss : 0.438 KL: 0.908
# Step:36300 loss : 0.391 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.911
# Step:36400 loss : 0.431 KL: 0.908
# Step:36500 loss : 0.399 KL: 0.908
# Step:36600 loss : 0.376 KL: 0.908
# Step:36700 loss : 0.423 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.911
# Step:36800 loss : 0.399 KL: 0.908
# Step:36900 loss : 0.384 KL: 0.908
# Step:37000 loss : 0.423 KL: 0.908
# Step:37100 loss : 0.407 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:37200 loss : 0.407 KL: 0.908
# Step:37300 loss : 0.407 KL: 0.908
# Step:37400 loss : 0.368 KL: 0.908
# Step:37500 loss : 0.423 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:37600 loss : 0.345 KL: 0.908
# Step:37700 loss : 0.391 KL: 0.908
# Step:37800 loss : 0.391 KL: 0.908
# Step:37900 loss : 0.415 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.902
# Step:38000 loss : 0.399 KL: 0.908
# Step:38100 loss : 0.423 KL: 0.908
# Step:38200 loss : 0.431 KL: 0.908
# Step:38300 loss : 0.454 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:38400 loss : 0.391 KL: 0.908
# Step:38500 loss : 0.399 KL: 0.908
# Step:38600 loss : 0.423 KL: 0.908
# Step:38700 loss : 0.384 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.914
# Step:38800 loss : 0.415 KL: 0.908
# Step:38900 loss : 0.407 KL: 0.908
# Step:39000 loss : 0.438 KL: 0.908
# Step:39100 loss : 0.423 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.913
# Step:39200 loss : 0.391 KL: 0.908
# Step:39300 loss : 0.384 KL: 0.908
# Step:39400 loss : 0.391 KL: 0.908
# Step:39500 loss : 0.360 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:39600 loss : 0.423 KL: 0.908
# Step:39700 loss : 0.376 KL: 0.908
# Step:39800 loss : 0.462 KL: 0.908
# Step:39900 loss : 0.399 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:40000 loss : 0.391 KL: 0.908
# Step:40100 loss : 0.407 KL: 0.908
# Step:40200 loss : 0.423 KL: 0.908
# Step:40300 loss : 0.477 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:40400 loss : 0.376 KL: 0.908
# Step:40500 loss : 0.384 KL: 0.908
# Step:40600 loss : 0.438 KL: 0.908
# Step:40700 loss : 0.391 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:40800 loss : 0.431 KL: 0.908
# Step:40900 loss : 0.438 KL: 0.908
# Step:41000 loss : 0.368 KL: 0.908
# Step:41100 loss : 0.462 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.912
# Step:41200 loss : 0.384 KL: 0.908
# Step:41300 loss : 0.407 KL: 0.908
# Step:41400 loss : 0.423 KL: 0.908
# Step:41500 loss : 0.368 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.912
# Step:41600 loss : 0.462 KL: 0.908
# Step:41700 loss : 0.415 KL: 0.908
# Step:41800 loss : 0.376 KL: 0.908
# Step:41900 loss : 0.423 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:42000 loss : 0.384 KL: 0.908
# Step:42100 loss : 0.423 KL: 0.908
# Step:42200 loss : 0.415 KL: 0.908
# Step:42300 loss : 0.376 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:42400 loss : 0.384 KL: 0.908
# Step:42500 loss : 0.423 KL: 0.908
# Step:42600 loss : 0.454 KL: 0.908
# Step:42700 loss : 0.407 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.904
# Step:42800 loss : 0.407 KL: 0.908
# Step:42900 loss : 0.415 KL: 0.908
# Step:43000 loss : 0.391 KL: 0.908
# Step:43100 loss : 0.407 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:43200 loss : 0.384 KL: 0.908
# Step:43300 loss : 0.438 KL: 0.908
# Step:43400 loss : 0.454 KL: 0.908
# Step:43500 loss : 0.391 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.910
# Step:43600 loss : 0.407 KL: 0.908
# Step:43700 loss : 0.438 KL: 0.908
# Step:43800 loss : 0.391 KL: 0.908
# Step:43900 loss : 0.431 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.912
# Step:44000 loss : 0.407 KL: 0.908
# Step:44100 loss : 0.407 KL: 0.908
# Step:44200 loss : 0.423 KL: 0.908
# Step:44300 loss : 0.462 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:44400 loss : 0.384 KL: 0.908
# Step:44500 loss : 0.391 KL: 0.908
# Step:44600 loss : 0.407 KL: 0.908
# Step:44700 loss : 0.391 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.911
# Step:44800 loss : 0.431 KL: 0.908
# Step:44900 loss : 0.399 KL: 0.908
# Step:45000 loss : 0.423 KL: 0.908
# Step:45100 loss : 0.391 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.904
# Step:45200 loss : 0.438 KL: 0.908
# Step:45300 loss : 0.391 KL: 0.908
# Step:45400 loss : 0.399 KL: 0.908
# Step:45500 loss : 0.376 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:45600 loss : 0.438 KL: 0.908
# Step:45700 loss : 0.407 KL: 0.908
# Step:45800 loss : 0.407 KL: 0.908
# Step:45900 loss : 0.399 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.911
# Step:46000 loss : 0.399 KL: 0.908
# Step:46100 loss : 0.423 KL: 0.908
# Step:46200 loss : 0.391 KL: 0.908
# Step:46300 loss : 0.391 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.910
# Step:46400 loss : 0.360 KL: 0.908
# Step:46500 loss : 0.345 KL: 0.908
# Step:46600 loss : 0.352 KL: 0.908
# Step:46700 loss : 0.368 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:46800 loss : 0.368 KL: 0.908
# Step:46900 loss : 0.431 KL: 0.908
# Step:47000 loss : 0.415 KL: 0.908
# Step:47100 loss : 0.391 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:47200 loss : 0.399 KL: 0.908
# Step:47300 loss : 0.454 KL: 0.908
# Step:47400 loss : 0.454 KL: 0.908
# Step:47500 loss : 0.462 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.904
# Step:47600 loss : 0.399 KL: 0.908
# Step:47700 loss : 0.399 KL: 0.908
# Step:47800 loss : 0.415 KL: 0.908
# Step:47900 loss : 0.360 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.910
# Step:48000 loss : 0.384 KL: 0.908
# Step:48100 loss : 0.431 KL: 0.908
# Step:48200 loss : 0.391 KL: 0.908
# Step:48300 loss : 0.399 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:48400 loss : 0.431 KL: 0.908
# Step:48500 loss : 0.431 KL: 0.908
# Step:48600 loss : 0.360 KL: 0.908
# Step:48700 loss : 0.462 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.910
# Step:48800 loss : 0.438 KL: 0.908
# Step:48900 loss : 0.438 KL: 0.908
# Step:49000 loss : 0.415 KL: 0.908
# Step:49100 loss : 0.376 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:49200 loss : 0.407 KL: 0.908
# Step:49300 loss : 0.384 KL: 0.908
# Step:49400 loss : 0.438 KL: 0.908
# Step:49500 loss : 0.391 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:49600 loss : 0.376 KL: 0.908
# Step:49700 loss : 0.384 KL: 0.908
# Step:49800 loss : 0.431 KL: 0.908
# Step:49900 loss : 0.438 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:50000 loss : 0.415 KL: 0.908
# Step:50100 loss : 0.376 KL: 0.908
# Step:50200 loss : 0.470 KL: 0.908
# Step:50300 loss : 0.376 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:50400 loss : 0.415 KL: 0.908
# Step:50500 loss : 0.470 KL: 0.908
# Step:50600 loss : 0.431 KL: 0.908
# Step:50700 loss : 0.407 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.913
# Step:50800 loss : 0.384 KL: 0.908
# Step:50900 loss : 0.407 KL: 0.908
# Step:51000 loss : 0.423 KL: 0.908
# Step:51100 loss : 0.446 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:51200 loss : 0.415 KL: 0.908
# Step:51300 loss : 0.431 KL: 0.908
# Step:51400 loss : 0.462 KL: 0.908
# Step:51500 loss : 0.423 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.904
# Step:51600 loss : 0.470 KL: 0.908
# Step:51700 loss : 0.399 KL: 0.908
# Step:51800 loss : 0.423 KL: 0.908
# Step:51900 loss : 0.438 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:52000 loss : 0.438 KL: 0.908
# Step:52100 loss : 0.391 KL: 0.908
# Step:52200 loss : 0.454 KL: 0.908
# Step:52300 loss : 0.407 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:52400 loss : 0.431 KL: 0.908
# Step:52500 loss : 0.423 KL: 0.908
# Step:52600 loss : 0.384 KL: 0.908
# Step:52700 loss : 0.384 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:52800 loss : 0.368 KL: 0.908
# Step:52900 loss : 0.321 KL: 0.908
# Step:53000 loss : 0.446 KL: 0.908
# Step:53100 loss : 0.423 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.911
# Step:53200 loss : 0.384 KL: 0.908
# Step:53300 loss : 0.368 KL: 0.908
# Step:53400 loss : 0.407 KL: 0.908
# Step:53500 loss : 0.423 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:53600 loss : 0.423 KL: 0.908
# Step:53700 loss : 0.384 KL: 0.908
# Step:53800 loss : 0.415 KL: 0.908
# Step:53900 loss : 0.376 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:54000 loss : 0.399 KL: 0.908
# Step:54100 loss : 0.376 KL: 0.908
# Step:54200 loss : 0.415 KL: 0.908
# Step:54300 loss : 0.454 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.910
# Step:54400 loss : 0.407 KL: 0.908
# Step:54500 loss : 0.423 KL: 0.908
# Step:54600 loss : 0.415 KL: 0.908
# Step:54700 loss : 0.454 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:54800 loss : 0.423 KL: 0.908
# Step:54900 loss : 0.407 KL: 0.908
# Step:55000 loss : 0.423 KL: 0.908
# Step:55100 loss : 0.407 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:55200 loss : 0.438 KL: 0.908
# Step:55300 loss : 0.407 KL: 0.908
# Step:55400 loss : 0.423 KL: 0.908
# Step:55500 loss : 0.391 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.910
# Step:55600 loss : 0.431 KL: 0.908
# Step:55700 loss : 0.391 KL: 0.908
# Step:55800 loss : 0.384 KL: 0.908
# Step:55900 loss : 0.446 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.904
# Step:56000 loss : 0.423 KL: 0.908
# Step:56100 loss : 0.407 KL: 0.908
# Step:56200 loss : 0.415 KL: 0.908
# Step:56300 loss : 0.407 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.904
# Step:56400 loss : 0.407 KL: 0.908
# Step:56500 loss : 0.423 KL: 0.908
# Step:56600 loss : 0.384 KL: 0.908
# Step:56700 loss : 0.399 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.904
# Step:56800 loss : 0.352 KL: 0.908
# Step:56900 loss : 0.423 KL: 0.908
# Step:57000 loss : 0.360 KL: 0.908
# Step:57100 loss : 0.376 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:57200 loss : 0.368 KL: 0.908
# Step:57300 loss : 0.407 KL: 0.908
# Step:57400 loss : 0.376 KL: 0.908
# Step:57500 loss : 0.376 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:57600 loss : 0.399 KL: 0.908
# Step:57700 loss : 0.407 KL: 0.908
# Step:57800 loss : 0.415 KL: 0.908
# Step:57900 loss : 0.391 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:58000 loss : 0.438 KL: 0.908
# Step:58100 loss : 0.399 KL: 0.908
# Step:58200 loss : 0.446 KL: 0.908
# Step:58300 loss : 0.391 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:58400 loss : 0.438 KL: 0.908
# Step:58500 loss : 0.352 KL: 0.908
# Step:58600 loss : 0.462 KL: 0.908
# Step:58700 loss : 0.477 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:58800 loss : 0.407 KL: 0.908
# Step:58900 loss : 0.454 KL: 0.908
# Step:59000 loss : 0.384 KL: 0.908
# Step:59100 loss : 0.391 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.901
# Step:59200 loss : 0.376 KL: 0.908
# Step:59300 loss : 0.384 KL: 0.908
# Step:59400 loss : 0.454 KL: 0.908
# Step:59500 loss : 0.352 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:59600 loss : 0.391 KL: 0.908
# Step:59700 loss : 0.399 KL: 0.908
# Step:59800 loss : 0.391 KL: 0.908
# Step:59900 loss : 0.399 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:60000 loss : 0.399 KL: 0.908
# Step:60100 loss : 0.415 KL: 0.908
# Step:60200 loss : 0.391 KL: 0.908
# Step:60300 loss : 0.438 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:60400 loss : 0.415 KL: 0.908
# Step:60500 loss : 0.407 KL: 0.908
# Step:60600 loss : 0.454 KL: 0.908
# Step:60700 loss : 0.415 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:60800 loss : 0.423 KL: 0.908
# Step:60900 loss : 0.391 KL: 0.908
# Step:61000 loss : 0.376 KL: 0.908
# Step:61100 loss : 0.462 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.904
# Step:61200 loss : 0.384 KL: 0.908
# Step:61300 loss : 0.376 KL: 0.908
# Step:61400 loss : 0.438 KL: 0.908
# Step:61500 loss : 0.360 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.899
# Step:61600 loss : 0.384 KL: 0.908
# Step:61700 loss : 0.415 KL: 0.908
# Step:61800 loss : 0.399 KL: 0.908
# Step:61900 loss : 0.407 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:62000 loss : 0.384 KL: 0.908
# Step:62100 loss : 0.376 KL: 0.908
# Step:62200 loss : 0.399 KL: 0.908
# Step:62300 loss : 0.391 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.912
# Step:62400 loss : 0.438 KL: 0.908
# Step:62500 loss : 0.423 KL: 0.908
# Step:62600 loss : 0.415 KL: 0.908
# Step:62700 loss : 0.438 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.911
# Step:62800 loss : 0.431 KL: 0.908
# Step:62900 loss : 0.360 KL: 0.908
# Step:63000 loss : 0.399 KL: 0.908
# Step:63100 loss : 0.438 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:63200 loss : 0.431 KL: 0.908
# Step:63300 loss : 0.399 KL: 0.908
# Step:63400 loss : 0.391 KL: 0.908
# Step:63500 loss : 0.454 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:63600 loss : 0.391 KL: 0.908
# Step:63700 loss : 0.399 KL: 0.908
# Step:63800 loss : 0.407 KL: 0.908
# Step:63900 loss : 0.399 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.902
# Step:64000 loss : 0.384 KL: 0.908
# Step:64100 loss : 0.415 KL: 0.908
# Step:64200 loss : 0.407 KL: 0.908
# Step:64300 loss : 0.376 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:64400 loss : 0.384 KL: 0.908
# Step:64500 loss : 0.368 KL: 0.908
# Step:64600 loss : 0.384 KL: 0.908
# Step:64700 loss : 0.454 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.914
# Step:64800 loss : 0.423 KL: 0.908
# Step:64900 loss : 0.438 KL: 0.908
# Step:65000 loss : 0.391 KL: 0.908
# Step:65100 loss : 0.368 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.910
# Step:65200 loss : 0.391 KL: 0.908
# Step:65300 loss : 0.391 KL: 0.908
# Step:65400 loss : 0.415 KL: 0.908
# Step:65500 loss : 0.391 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:65600 loss : 0.415 KL: 0.908
# Step:65700 loss : 0.423 KL: 0.908
# Step:65800 loss : 0.407 KL: 0.908
# Step:65900 loss : 0.391 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:66000 loss : 0.391 KL: 0.908
# Step:66100 loss : 0.337 KL: 0.908
# Step:66200 loss : 0.501 KL: 0.908
# Step:66300 loss : 0.407 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:66400 loss : 0.431 KL: 0.908
# Step:66500 loss : 0.352 KL: 0.908
# Step:66600 loss : 0.399 KL: 0.908
# Step:66700 loss : 0.407 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:66800 loss : 0.384 KL: 0.908
# Step:66900 loss : 0.407 KL: 0.908
# Step:67000 loss : 0.399 KL: 0.908
# Step:67100 loss : 0.423 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.912
# Step:67200 loss : 0.391 KL: 0.908
# Step:67300 loss : 0.391 KL: 0.908
# Step:67400 loss : 0.431 KL: 0.908
# Step:67500 loss : 0.368 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.912
# Step:67600 loss : 0.407 KL: 0.908
# Step:67700 loss : 0.399 KL: 0.908
# Step:67800 loss : 0.423 KL: 0.908
# Step:67900 loss : 0.438 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:68000 loss : 0.391 KL: 0.908
# Step:68100 loss : 0.399 KL: 0.908
# Step:68200 loss : 0.470 KL: 0.908
# Step:68300 loss : 0.399 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:68400 loss : 0.384 KL: 0.908
# Step:68500 loss : 0.376 KL: 0.908
# Step:68600 loss : 0.384 KL: 0.908
# Step:68700 loss : 0.407 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:68800 loss : 0.391 KL: 0.908
# Step:68900 loss : 0.431 KL: 0.908
# Step:69000 loss : 0.407 KL: 0.908
# Step:69100 loss : 0.399 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:69200 loss : 0.391 KL: 0.908
# Step:69300 loss : 0.384 KL: 0.908
# Step:69400 loss : 0.431 KL: 0.908
# Step:69500 loss : 0.399 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:69600 loss : 0.415 KL: 0.908
# Step:69700 loss : 0.407 KL: 0.908
# Step:69800 loss : 0.391 KL: 0.908
# Step:69900 loss : 0.446 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.911
# Step:70000 loss : 0.431 KL: 0.908
# Step:70100 loss : 0.368 KL: 0.908
# Step:70200 loss : 0.345 KL: 0.908
# Step:70300 loss : 0.423 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:70400 loss : 0.415 KL: 0.908
# Step:70500 loss : 0.438 KL: 0.908
# Step:70600 loss : 0.391 KL: 0.908
# Step:70700 loss : 0.415 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.910
# Step:70800 loss : 0.407 KL: 0.908
# Step:70900 loss : 0.391 KL: 0.908
# Step:71000 loss : 0.431 KL: 0.908
# Step:71100 loss : 0.391 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.904
# Step:71200 loss : 0.415 KL: 0.908
# Step:71300 loss : 0.431 KL: 0.908
# Step:71400 loss : 0.423 KL: 0.908
# Step:71500 loss : 0.438 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.910
# Step:71600 loss : 0.384 KL: 0.908
# Step:71700 loss : 0.431 KL: 0.908
# Step:71800 loss : 0.360 KL: 0.908
# Step:71900 loss : 0.376 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.912
# Step:72000 loss : 0.431 KL: 0.908
# Step:72100 loss : 0.407 KL: 0.908
# Step:72200 loss : 0.368 KL: 0.908
# Step:72300 loss : 0.345 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:72400 loss : 0.399 KL: 0.908
# Step:72500 loss : 0.376 KL: 0.908
# Step:72600 loss : 0.391 KL: 0.908
# Step:72700 loss : 0.438 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:72800 loss : 0.438 KL: 0.908
# Step:72900 loss : 0.431 KL: 0.908
# Step:73000 loss : 0.407 KL: 0.908
# Step:73100 loss : 0.446 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:73200 loss : 0.368 KL: 0.908
# Step:73300 loss : 0.407 KL: 0.908
# Step:73400 loss : 0.431 KL: 0.908
# Step:73500 loss : 0.384 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.903
# Step:73600 loss : 0.423 KL: 0.908
# Step:73700 loss : 0.462 KL: 0.908
# Step:73800 loss : 0.423 KL: 0.908
# Step:73900 loss : 0.391 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:74000 loss : 0.431 KL: 0.908
# Step:74100 loss : 0.352 KL: 0.908
# Step:74200 loss : 0.454 KL: 0.908
# Step:74300 loss : 0.407 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.911
# Step:74400 loss : 0.477 KL: 0.908
# Step:74500 loss : 0.399 KL: 0.908
# Step:74600 loss : 0.407 KL: 0.908
# Step:74700 loss : 0.368 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:74800 loss : 0.391 KL: 0.908
# Step:74900 loss : 0.360 KL: 0.908
# Step:75000 loss : 0.423 KL: 0.908
# Step:75100 loss : 0.376 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:75200 loss : 0.407 KL: 0.908
# Step:75300 loss : 0.438 KL: 0.908
# Step:75400 loss : 0.407 KL: 0.908
# Step:75500 loss : 0.415 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:75600 loss : 0.415 KL: 0.908
# Step:75700 loss : 0.399 KL: 0.908
# Step:75800 loss : 0.376 KL: 0.908
# Step:75900 loss : 0.423 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.904
# Step:76000 loss : 0.399 KL: 0.908
# Step:76100 loss : 0.415 KL: 0.908
# Step:76200 loss : 0.345 KL: 0.908
# Step:76300 loss : 0.407 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:76400 loss : 0.407 KL: 0.908
# Step:76500 loss : 0.376 KL: 0.908
# Step:76600 loss : 0.415 KL: 0.908
# Step:76700 loss : 0.431 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.913
# Step:76800 loss : 0.438 KL: 0.908
# Step:76900 loss : 0.399 KL: 0.908
# Step:77000 loss : 0.407 KL: 0.908
# Step:77100 loss : 0.415 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:77200 loss : 0.368 KL: 0.908
# Step:77300 loss : 0.415 KL: 0.908
# Step:77400 loss : 0.407 KL: 0.908
# Step:77500 loss : 0.407 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.904
# Step:77600 loss : 0.399 KL: 0.908
# Step:77700 loss : 0.399 KL: 0.908
# Step:77800 loss : 0.462 KL: 0.908
# Step:77900 loss : 0.399 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:78000 loss : 0.431 KL: 0.908
# Step:78100 loss : 0.376 KL: 0.908
# Step:78200 loss : 0.407 KL: 0.908
# Step:78300 loss : 0.384 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:78400 loss : 0.384 KL: 0.908
# Step:78500 loss : 0.415 KL: 0.908
# Step:78600 loss : 0.399 KL: 0.908
# Step:78700 loss : 0.423 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:78800 loss : 0.360 KL: 0.908
# Step:78900 loss : 0.423 KL: 0.908
# Step:79000 loss : 0.376 KL: 0.908
# Step:79100 loss : 0.446 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.911
# Step:79200 loss : 0.376 KL: 0.908
# Step:79300 loss : 0.407 KL: 0.908
# Step:79400 loss : 0.431 KL: 0.908
# Step:79500 loss : 0.423 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:79600 loss : 0.438 KL: 0.908
# Step:79700 loss : 0.446 KL: 0.908
# Step:79800 loss : 0.415 KL: 0.908
# Step:79900 loss : 0.407 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:80000 loss : 0.399 KL: 0.908
# Step:80100 loss : 0.415 KL: 0.908
# Step:80200 loss : 0.431 KL: 0.908
# Step:80300 loss : 0.376 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:80400 loss : 0.384 KL: 0.908
# Step:80500 loss : 0.376 KL: 0.908
# Step:80600 loss : 0.438 KL: 0.908
# Step:80700 loss : 0.431 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:80800 loss : 0.384 KL: 0.908
# Step:80900 loss : 0.407 KL: 0.908
# Step:81000 loss : 0.384 KL: 0.908
# Step:81100 loss : 0.446 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:81200 loss : 0.438 KL: 0.908
# Step:81300 loss : 0.415 KL: 0.908
# Step:81400 loss : 0.391 KL: 0.908
# Step:81500 loss : 0.368 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:81600 loss : 0.423 KL: 0.908
# Step:81700 loss : 0.399 KL: 0.908
# Step:81800 loss : 0.415 KL: 0.908
# Step:81900 loss : 0.384 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.904
# Step:82000 loss : 0.391 KL: 0.908
# Step:82100 loss : 0.454 KL: 0.908
# Step:82200 loss : 0.391 KL: 0.908
# Step:82300 loss : 0.384 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.904
# Step:82400 loss : 0.376 KL: 0.908
# Step:82500 loss : 0.391 KL: 0.908
# Step:82600 loss : 0.391 KL: 0.908
# Step:82700 loss : 0.352 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.903
# Step:82800 loss : 0.415 KL: 0.908
# Step:82900 loss : 0.368 KL: 0.908
# Step:83000 loss : 0.376 KL: 0.908
# Step:83100 loss : 0.399 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:83200 loss : 0.407 KL: 0.908
# Step:83300 loss : 0.407 KL: 0.908
# Step:83400 loss : 0.423 KL: 0.908
# Step:83500 loss : 0.376 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:83600 loss : 0.431 KL: 0.908
# Step:83700 loss : 0.438 KL: 0.908
# Step:83800 loss : 0.423 KL: 0.908
# Step:83900 loss : 0.423 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:84000 loss : 0.423 KL: 0.908
# Step:84100 loss : 0.399 KL: 0.908
# Step:84200 loss : 0.431 KL: 0.908
# Step:84300 loss : 0.391 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:84400 loss : 0.438 KL: 0.908
# Step:84500 loss : 0.376 KL: 0.908
# Step:84600 loss : 0.407 KL: 0.908
# Step:84700 loss : 0.368 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:84800 loss : 0.399 KL: 0.908
# Step:84900 loss : 0.431 KL: 0.908
# Step:85000 loss : 0.407 KL: 0.908
# Step:85100 loss : 0.368 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.901
# Step:85200 loss : 0.415 KL: 0.908
# Step:85300 loss : 0.415 KL: 0.908
# Step:85400 loss : 0.391 KL: 0.908
# Step:85500 loss : 0.384 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:85600 loss : 0.384 KL: 0.908
# Step:85700 loss : 0.376 KL: 0.908
# Step:85800 loss : 0.415 KL: 0.908
# Step:85900 loss : 0.407 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.910
# Step:86000 loss : 0.399 KL: 0.908
# Step:86100 loss : 0.446 KL: 0.908
# Step:86200 loss : 0.407 KL: 0.908
# Step:86300 loss : 0.407 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:86400 loss : 0.415 KL: 0.908
# Step:86500 loss : 0.446 KL: 0.908
# Step:86600 loss : 0.407 KL: 0.908
# Step:86700 loss : 0.446 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:86800 loss : 0.431 KL: 0.908
# Step:86900 loss : 0.431 KL: 0.908
# Step:87000 loss : 0.407 KL: 0.908
# Step:87100 loss : 0.438 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:87200 loss : 0.399 KL: 0.908
# Step:87300 loss : 0.407 KL: 0.908
# Step:87400 loss : 0.399 KL: 0.908
# Step:87500 loss : 0.438 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.899
# Step:87600 loss : 0.376 KL: 0.908
# Step:87700 loss : 0.415 KL: 0.908
# Step:87800 loss : 0.391 KL: 0.908
# Step:87900 loss : 0.423 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:88000 loss : 0.376 KL: 0.908
# Step:88100 loss : 0.352 KL: 0.908
# Step:88200 loss : 0.438 KL: 0.908
# Step:88300 loss : 0.376 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.912
# Step:88400 loss : 0.399 KL: 0.908
# Step:88500 loss : 0.368 KL: 0.908
# Step:88600 loss : 0.431 KL: 0.908
# Step:88700 loss : 0.391 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.911
# Step:88800 loss : 0.391 KL: 0.908
# Step:88900 loss : 0.391 KL: 0.908
# Step:89000 loss : 0.376 KL: 0.908
# Step:89100 loss : 0.384 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.910
# Step:89200 loss : 0.368 KL: 0.908
# Step:89300 loss : 0.399 KL: 0.908
# Step:89400 loss : 0.423 KL: 0.908
# Step:89500 loss : 0.391 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:89600 loss : 0.438 KL: 0.908
# Step:89700 loss : 0.438 KL: 0.908
# Step:89800 loss : 0.368 KL: 0.908
# Step:89900 loss : 0.399 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.903
# Step:90000 loss : 0.407 KL: 0.908
# Step:90100 loss : 0.384 KL: 0.908
# Step:90200 loss : 0.431 KL: 0.908
# Step:90300 loss : 0.384 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:90400 loss : 0.399 KL: 0.908
# Step:90500 loss : 0.384 KL: 0.908
# Step:90600 loss : 0.407 KL: 0.908
# Step:90700 loss : 0.368 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.912
# Step:90800 loss : 0.376 KL: 0.908
# Step:90900 loss : 0.391 KL: 0.908
# Step:91000 loss : 0.423 KL: 0.908
# Step:91100 loss : 0.415 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.910
# Step:91200 loss : 0.438 KL: 0.908
# Step:91300 loss : 0.423 KL: 0.908
# Step:91400 loss : 0.399 KL: 0.908
# Step:91500 loss : 0.431 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:91600 loss : 0.407 KL: 0.908
# Step:91700 loss : 0.376 KL: 0.908
# Step:91800 loss : 0.391 KL: 0.908
# Step:91900 loss : 0.399 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:92000 loss : 0.399 KL: 0.908
# Step:92100 loss : 0.391 KL: 0.908
# Step:92200 loss : 0.399 KL: 0.908
# Step:92300 loss : 0.391 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:92400 loss : 0.384 KL: 0.908
# Step:92500 loss : 0.376 KL: 0.908
# Step:92600 loss : 0.407 KL: 0.908
# Step:92700 loss : 0.384 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.910
# Step:92800 loss : 0.423 KL: 0.908
# Step:92900 loss : 0.399 KL: 0.908
# Step:93000 loss : 0.407 KL: 0.908
# Step:93100 loss : 0.391 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.912
# Step:93200 loss : 0.345 KL: 0.908
# Step:93300 loss : 0.376 KL: 0.908
# Step:93400 loss : 0.423 KL: 0.908
# Step:93500 loss : 0.431 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.913
# Step:93600 loss : 0.454 KL: 0.908
# Step:93700 loss : 0.368 KL: 0.908
# Step:93800 loss : 0.438 KL: 0.908
# Step:93900 loss : 0.438 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:94000 loss : 0.399 KL: 0.908
# Step:94100 loss : 0.384 KL: 0.908
# Step:94200 loss : 0.407 KL: 0.908
# Step:94300 loss : 0.399 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.910
# Step:94400 loss : 0.431 KL: 0.908
# Step:94500 loss : 0.446 KL: 0.908
# Step:94600 loss : 0.391 KL: 0.908
# Step:94700 loss : 0.407 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:94800 loss : 0.368 KL: 0.908
# Step:94900 loss : 0.485 KL: 0.908
# Step:95000 loss : 0.376 KL: 0.908
# Step:95100 loss : 0.337 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.910
# Step:95200 loss : 0.376 KL: 0.908
# Step:95300 loss : 0.368 KL: 0.908
# Step:95400 loss : 0.384 KL: 0.908
# Step:95500 loss : 0.415 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.911
# Step:95600 loss : 0.423 KL: 0.908
# Step:95700 loss : 0.407 KL: 0.908
# Step:95800 loss : 0.407 KL: 0.908
# Step:95900 loss : 0.360 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.912
# Step:96000 loss : 0.423 KL: 0.908
# Step:96100 loss : 0.415 KL: 0.908
# Step:96200 loss : 0.399 KL: 0.908
# Step:96300 loss : 0.415 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:96400 loss : 0.391 KL: 0.908
# Step:96500 loss : 0.391 KL: 0.908
# Step:96600 loss : 0.415 KL: 0.908
# Step:96700 loss : 0.446 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.910
# Step:96800 loss : 0.431 KL: 0.908
# Step:96900 loss : 0.407 KL: 0.908
# ...
# Step:2612000 loss : 0.391 KL: 0.907
# Step:2612100 loss : 0.391 KL: 0.907
# Step:2612200 loss : 0.407 KL: 0.907
# Step:2612300 loss : 0.376 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:2612400 loss : 0.438 KL: 0.907
# Step:2612500 loss : 0.415 KL: 0.907
# Step:2612600 loss : 0.423 KL: 0.907
# Step:2612700 loss : 0.438 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:2612800 loss : 0.384 KL: 0.907
# Step:2612900 loss : 0.415 KL: 0.907
# Step:2613000 loss : 0.384 KL: 0.907
# Step:2613100 loss : 0.391 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:2613200 loss : 0.391 KL: 0.907
# Step:2613300 loss : 0.454 KL: 0.907
# Step:2613400 loss : 0.391 KL: 0.907
# Step:2613500 loss : 0.423 KL: 0.907
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.901
# Step:2613600 loss : 0.454 KL: 0.907
# Step:2613700 loss : 0.399 KL: 0.907
# Step:2613800 loss : 0.423 KL: 0.908
# Step:2613900 loss : 0.415 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:2614000 loss : 0.399 KL: 0.908
# Step:2614100 loss : 0.384 KL: 0.908
# Step:2614200 loss : 0.407 KL: 0.908
# Step:2614300 loss : 0.446 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:2614400 loss : 0.454 KL: 0.908
# Step:2614500 loss : 0.391 KL: 0.908
# Step:2614600 loss : 0.407 KL: 0.908
# Step:2614700 loss : 0.438 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.910
# Step:2614800 loss : 0.384 KL: 0.908
# Step:2614900 loss : 0.438 KL: 0.908
# Step:2615000 loss : 0.423 KL: 0.908
# Step:2615100 loss : 0.384 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:2615200 loss : 0.430 KL: 0.908
# Step:2615300 loss : 0.391 KL: 0.908
# Step:2615400 loss : 0.407 KL: 0.908
# Step:2615500 loss : 0.438 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:2615600 loss : 0.376 KL: 0.908
# Step:2615700 loss : 0.407 KL: 0.908
# Step:2615800 loss : 0.423 KL: 0.908
# Step:2615900 loss : 0.430 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.899
# Step:2616000 loss : 0.454 KL: 0.908
# Step:2616100 loss : 0.415 KL: 0.908
# Step:2616200 loss : 0.415 KL: 0.908
# Step:2616300 loss : 0.391 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:2616400 loss : 0.360 KL: 0.908
# Step:2616500 loss : 0.407 KL: 0.908
# Step:2616600 loss : 0.384 KL: 0.908
# Step:2616700 loss : 0.399 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.912
# Step:2616800 loss : 0.454 KL: 0.908
# Step:2616900 loss : 0.423 KL: 0.908
# Step:2617000 loss : 0.376 KL: 0.908
# Step:2617100 loss : 0.438 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.911
# Step:2617200 loss : 0.399 KL: 0.908
# Step:2617300 loss : 0.415 KL: 0.908
# Step:2617400 loss : 0.415 KL: 0.908
# Step:2617500 loss : 0.399 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.910
# Step:2617600 loss : 0.384 KL: 0.908
# Step:2617700 loss : 0.446 KL: 0.908
# Step:2617800 loss : 0.376 KL: 0.908
# Step:2617900 loss : 0.399 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:2618000 loss : 0.415 KL: 0.908
# Step:2618100 loss : 0.430 KL: 0.908
# Step:2618200 loss : 0.415 KL: 0.908
# Step:2618300 loss : 0.415 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:2618400 loss : 0.423 KL: 0.908
# Step:2618500 loss : 0.399 KL: 0.908
# Step:2618600 loss : 0.391 KL: 0.908
# Step:2618700 loss : 0.415 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:2618800 loss : 0.368 KL: 0.908
# Step:2618900 loss : 0.368 KL: 0.908
# Step:2619000 loss : 0.368 KL: 0.908
# Step:2619100 loss : 0.407 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.912
# Step:2619200 loss : 0.391 KL: 0.908
# Step:2619300 loss : 0.399 KL: 0.908
# Step:2619400 loss : 0.415 KL: 0.908
# Step:2619500 loss : 0.438 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.910
# Step:2619600 loss : 0.376 KL: 0.908
# Step:2619700 loss : 0.376 KL: 0.908
# Step:2619800 loss : 0.360 KL: 0.908
# Step:2619900 loss : 0.399 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:2620000 loss : 0.391 KL: 0.908
# Step:2620100 loss : 0.438 KL: 0.908
# Step:2620200 loss : 0.407 KL: 0.908
# Step:2620300 loss : 0.407 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:2620400 loss : 0.438 KL: 0.908
# Step:2620500 loss : 0.415 KL: 0.908
# Step:2620600 loss : 0.384 KL: 0.908
# Step:2620700 loss : 0.407 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.904
# Step:2620800 loss : 0.430 KL: 0.908
# Step:2620900 loss : 0.399 KL: 0.908
# Step:2621000 loss : 0.415 KL: 0.908
# Step:2621100 loss : 0.462 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:2621200 loss : 0.415 KL: 0.908
# Step:2621300 loss : 0.391 KL: 0.908
# Step:2621400 loss : 0.391 KL: 0.908
# Step:2621500 loss : 0.368 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.911
# Step:2621600 loss : 0.423 KL: 0.908
# Step:2621700 loss : 0.415 KL: 0.908
# Step:2621800 loss : 0.399 KL: 0.908
# Step:2621900 loss : 0.399 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.911
# Step:2622000 loss : 0.423 KL: 0.908
# Step:2622100 loss : 0.376 KL: 0.908
# Step:2622200 loss : 0.446 KL: 0.908
# Step:2622300 loss : 0.470 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.910
# Step:2622400 loss : 0.368 KL: 0.908
# Step:2622500 loss : 0.407 KL: 0.908
# Step:2622600 loss : 0.384 KL: 0.908
# Step:2622700 loss : 0.415 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.910
# Step:2622800 loss : 0.391 KL: 0.908
# Step:2622900 loss : 0.399 KL: 0.908
# Step:2623000 loss : 0.407 KL: 0.908
# Step:2623100 loss : 0.391 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:2623200 loss : 0.376 KL: 0.908
# Step:2623300 loss : 0.376 KL: 0.908
# Step:2623400 loss : 0.376 KL: 0.908
# Step:2623500 loss : 0.368 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.910
# Step:2623600 loss : 0.384 KL: 0.908
# Step:2623700 loss : 0.462 KL: 0.908
# Step:2623800 loss : 0.430 KL: 0.908
# Step:2623900 loss : 0.415 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.911
# Step:2624000 loss : 0.399 KL: 0.908
# Step:2624100 loss : 0.399 KL: 0.908
# Step:2624200 loss : 0.391 KL: 0.908
# Step:2624300 loss : 0.345 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.912
# Step:2624400 loss : 0.407 KL: 0.908
# Step:2624500 loss : 0.438 KL: 0.908
# Step:2624600 loss : 0.423 KL: 0.908
# Step:2624700 loss : 0.415 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:2624800 loss : 0.415 KL: 0.908
# Step:2624900 loss : 0.391 KL: 0.908
# Step:2625000 loss : 0.438 KL: 0.908
# Step:2625100 loss : 0.423 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.910
# Step:2625200 loss : 0.446 KL: 0.908
# Step:2625300 loss : 0.368 KL: 0.908
# Step:2625400 loss : 0.430 KL: 0.908
# Step:2625500 loss : 0.399 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.903
# Step:2625600 loss : 0.391 KL: 0.908
# Step:2625700 loss : 0.352 KL: 0.908
# Step:2625800 loss : 0.407 KL: 0.908
# Step:2625900 loss : 0.399 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.911
# Step:2626000 loss : 0.352 KL: 0.908
# Step:2626100 loss : 0.430 KL: 0.908
# Step:2626200 loss : 0.399 KL: 0.908
# Step:2626300 loss : 0.454 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.911
# Step:2626400 loss : 0.384 KL: 0.908
# Step:2626500 loss : 0.384 KL: 0.908
# Step:2626600 loss : 0.430 KL: 0.908
# Step:2626700 loss : 0.376 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.910
# Step:2626800 loss : 0.391 KL: 0.908
# Step:2626900 loss : 0.391 KL: 0.908
# Step:2627000 loss : 0.391 KL: 0.908
# Step:2627100 loss : 0.423 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:2627200 loss : 0.384 KL: 0.908
# Step:2627300 loss : 0.399 KL: 0.908
# Step:2627400 loss : 0.423 KL: 0.908
# Step:2627500 loss : 0.438 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:2627600 loss : 0.399 KL: 0.908
# Step:2627700 loss : 0.415 KL: 0.908
# Step:2627800 loss : 0.384 KL: 0.908
# Step:2627900 loss : 0.454 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:2628000 loss : 0.391 KL: 0.908
# Step:2628100 loss : 0.415 KL: 0.908
# Step:2628200 loss : 0.430 KL: 0.908
# Step:2628300 loss : 0.407 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.910
# Step:2628400 loss : 0.391 KL: 0.908
# Step:2628500 loss : 0.407 KL: 0.908
# Step:2628600 loss : 0.391 KL: 0.908
# Step:2628700 loss : 0.407 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.911
# Step:2628800 loss : 0.430 KL: 0.908
# Step:2628900 loss : 0.446 KL: 0.908
# Step:2629000 loss : 0.384 KL: 0.908
# Step:2629100 loss : 0.399 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:2629200 loss : 0.368 KL: 0.908
# Step:2629300 loss : 0.384 KL: 0.908
# Step:2629400 loss : 0.368 KL: 0.908
# Step:2629500 loss : 0.430 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:2629600 loss : 0.407 KL: 0.908
# Step:2629700 loss : 0.384 KL: 0.908
# Step:2629800 loss : 0.399 KL: 0.908
# Step:2629900 loss : 0.376 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:2630000 loss : 0.376 KL: 0.908
# Step:2630100 loss : 0.415 KL: 0.908
# Step:2630200 loss : 0.399 KL: 0.908
# Step:2630300 loss : 0.360 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:2630400 loss : 0.415 KL: 0.908
# Step:2630500 loss : 0.438 KL: 0.908
# Step:2630600 loss : 0.399 KL: 0.908
# Step:2630700 loss : 0.391 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:2630800 loss : 0.423 KL: 0.908
# Step:2630900 loss : 0.446 KL: 0.908
# Step:2631000 loss : 0.391 KL: 0.908
# Step:2631100 loss : 0.423 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.911
# Step:2631200 loss : 0.430 KL: 0.908
# Step:2631300 loss : 0.384 KL: 0.908
# Step:2631400 loss : 0.423 KL: 0.908
# Step:2631500 loss : 0.407 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.904
# Step:2631600 loss : 0.384 KL: 0.908
# Step:2631700 loss : 0.391 KL: 0.908
# Step:2631800 loss : 0.391 KL: 0.908
# Step:2631900 loss : 0.399 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:2632000 loss : 0.423 KL: 0.908
# Step:2632100 loss : 0.454 KL: 0.908
# Step:2632200 loss : 0.384 KL: 0.908
# Step:2632300 loss : 0.376 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:2632400 loss : 0.399 KL: 0.908
# Step:2632500 loss : 0.376 KL: 0.908
# Step:2632600 loss : 0.430 KL: 0.908
# Step:2632700 loss : 0.391 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:2632800 loss : 0.360 KL: 0.908
# Step:2632900 loss : 0.415 KL: 0.908
# Step:2633000 loss : 0.399 KL: 0.908
# Step:2633100 loss : 0.438 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:2633200 loss : 0.415 KL: 0.908
# Step:2633300 loss : 0.407 KL: 0.908
# Step:2633400 loss : 0.423 KL: 0.908
# Step:2633500 loss : 0.415 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:2633600 loss : 0.368 KL: 0.908
# Step:2633700 loss : 0.430 KL: 0.908
# Step:2633800 loss : 0.384 KL: 0.908
# Step:2633900 loss : 0.415 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:2634000 loss : 0.446 KL: 0.908
# Step:2634100 loss : 0.368 KL: 0.908
# Step:2634200 loss : 0.352 KL: 0.908
# Step:2634300 loss : 0.399 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:2634400 loss : 0.376 KL: 0.908
# Step:2634500 loss : 0.430 KL: 0.908
# Step:2634600 loss : 0.384 KL: 0.908
# Step:2634700 loss : 0.345 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:2634800 loss : 0.407 KL: 0.908
# Step:2634900 loss : 0.477 KL: 0.908
# Step:2635000 loss : 0.454 KL: 0.908
# Step:2635100 loss : 0.368 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:2635200 loss : 0.430 KL: 0.908
# Step:2635300 loss : 0.399 KL: 0.908
# Step:2635400 loss : 0.423 KL: 0.908
# Step:2635500 loss : 0.376 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.904
# Step:2635600 loss : 0.470 KL: 0.908
# Step:2635700 loss : 0.415 KL: 0.908
# Step:2635800 loss : 0.438 KL: 0.908
# Step:2635900 loss : 0.446 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:2636000 loss : 0.415 KL: 0.908
# Step:2636100 loss : 0.407 KL: 0.908
# Step:2636200 loss : 0.407 KL: 0.908
# Step:2636300 loss : 0.391 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:2636400 loss : 0.438 KL: 0.908
# Step:2636500 loss : 0.399 KL: 0.908
# Step:2636600 loss : 0.415 KL: 0.908
# Step:2636700 loss : 0.423 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:2636800 loss : 0.438 KL: 0.908
# Step:2636900 loss : 0.399 KL: 0.908
# Step:2637000 loss : 0.423 KL: 0.908
# Step:2637100 loss : 0.438 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.900
# Step:2637200 loss : 0.391 KL: 0.908
# Step:2637300 loss : 0.438 KL: 0.908
# Step:2637400 loss : 0.423 KL: 0.908
# Step:2637500 loss : 0.391 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:2637600 loss : 0.454 KL: 0.908
# Step:2637700 loss : 0.430 KL: 0.908
# Step:2637800 loss : 0.384 KL: 0.908
# Step:2637900 loss : 0.407 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.908
# Step:2638000 loss : 0.407 KL: 0.908
# Step:2638100 loss : 0.430 KL: 0.908
# Step:2638200 loss : 0.454 KL: 0.908
# Step:2638300 loss : 0.399 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.909
# Step:2638400 loss : 0.399 KL: 0.908
# Step:2638500 loss : 0.430 KL: 0.908
# Step:2638600 loss : 0.391 KL: 0.908
# Step:2638700 loss : 0.423 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:2638800 loss : 0.470 KL: 0.908
# Step:2638900 loss : 0.470 KL: 0.908
# Step:2639000 loss : 0.415 KL: 0.908
# Step:2639100 loss : 0.391 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.907
# Step:2639200 loss : 0.415 KL: 0.908
# Step:2639300 loss : 0.399 KL: 0.908
# Step:2639400 loss : 0.399 KL: 0.908
# Step:2639500 loss : 0.399 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.900
# Step:2639600 loss : 0.376 KL: 0.908
# Step:2639700 loss : 0.376 KL: 0.908
# Step:2639800 loss : 0.415 KL: 0.908
# Step:2639900 loss : 0.407 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.904
# Step:2640000 loss : 0.407 KL: 0.908
# Step:2640100 loss : 0.399 KL: 0.908
# Step:2640200 loss : 0.384 KL: 0.908
# Step:2640300 loss : 0.430 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.910
# Step:2640400 loss : 0.376 KL: 0.908
# Step:2640500 loss : 0.384 KL: 0.908
# Step:2640600 loss : 0.407 KL: 0.908
# Step:2640700 loss : 0.407 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.910
# Step:2640800 loss : 0.407 KL: 0.908
# Step:2640900 loss : 0.399 KL: 0.908
# Step:2641000 loss : 0.391 KL: 0.908
# Step:2641100 loss : 0.415 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.906
# Step:2641200 loss : 0.368 KL: 0.908
# Step:2641300 loss : 0.415 KL: 0.908
# Step:2641400 loss : 0.376 KL: 0.908
# Step:2641500 loss : 0.337 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:2641600 loss : 0.423 KL: 0.908
# Step:2641700 loss : 0.399 KL: 0.908
# Step:2641800 loss : 0.368 KL: 0.908
# Step:2641900 loss : 0.345 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.901
# Step:2642000 loss : 0.376 KL: 0.908
# Step:2642100 loss : 0.399 KL: 0.908
# Step:2642200 loss : 0.352 KL: 0.908
# Step:2642300 loss : 0.368 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.905
# Step:2642400 loss : 0.376 KL: 0.908
# Step:2642500 loss : 0.415 KL: 0.908
# Step:2642600 loss : 0.376 KL: 0.908
# Step:2642700 loss : 0.407 KL: 0.908
# int32
#  ...Held_out nats: -inf
#  ... Validation Accuracy: 0.914
# Step:2642800 loss : 0.438 KL: 0.908
# Step:2642900 loss : 0.376 KL: 0.908
# Step:2643000 loss : 0.391 KL: 0.908

# %% [markdown]
# <a href="https://colab.research.google.com/github/EziamaUgonna/Bayesian_analysis-/blob/master/Dissertation2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade -q gspread
from tensorboardcolab import *
import shutil
#clean out the directory
shutil.rmtree('./Graph', ignore_errors=True)
os.mkdir('./Graph')
#tf.reset_default_graph()
#will start the tunneling and will print out a link:
tbc=TensorBoardColab()
# Out:
# Using TensorFlow backend.
# Wait for 8 seconds...
# TensorBoard link:
# http://4f258549.ngrok.io

# %%
# !pip show tensorflow
# Out:
# Name: tensorflow
# Version: 1.13.1
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: opensource@google.com
# License: Apache 2.0
# Location: /usr/local/lib/python3.6/dist-packages
# Requires: keras-applications, keras-preprocessing, protobuf, wheel, numpy, gast, absl-py, tensorflow-estimator, grpcio, astor, tensorboard, termcolor, six
# Required-by: stable-baselines, magenta, fancyimpute

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

# %%
# Dependencies
import os 
import warnings 
#from absl import flags 
import matplotlib 
import numpy as np 
import tensorflow as tf 
import tensorflow_probability as tfp
import math
import pandas as pd
tfd = tfp.distributions
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
#from hyperopt import fmin, tpe, hp, STATUS_OK, STATUS_FAIL, Trials
#import python_utils
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.

# %%
# clear graph (if any) before running 
tf.reset_default_graph()

# %%
####Delete all flags before declare#####

def del_all_flags(FLAGS):
    flags_dict = FLAGS._flags()    
    keys_list = [keys for keys in flags_dict]    
    for keys in keys_list:
        FLAGS.__delattr__(keys)

del_all_flags(tf.flags.FLAGS)

flags = tf.app.flags
FLAGS = tf.app.flags.FLAGS
flags.DEFINE_float("learning_rate", default = 0.0001, help = "Initial learning rate.")
flags.DEFINE_integer("epochs", default = 700, help = "Number of epochs to train for")
flags.DEFINE_integer("batch_size", default =128, help = "Batch size.")
flags.DEFINE_integer("eval_freq", default = 400, help =" Frequency at which to validate the model.")
flags.DEFINE_float("kernel_posterior_scale_mean", default = -0.9, help = "Initial kernel posterior mean of the scale (log var) for q(w)")
flags.DEFINE_float("kernel_posterior_scale_constraint", default = 0.2, help = "Posterior kernel constraint for the scale (log var) for q(w)")
flags.DEFINE_float("kl_annealing", default = 50, help = "Epochs to anneal the KL term (anneals from 0 to 1)")
flags.DEFINE_integer("num_hidden_layers", default = 4, help = "Number of hidden layers")
flags.DEFINE_integer("num_monte_carlo",

                     default=50,

                     help="Network draws to compute predictive probabilities.")
tf.app.flags.DEFINE_string('f', '', 'kernel')
#initialize flags 
#FLAGS = flags.FLAGS
print(FLAGS.learning_rate)
print(FLAGS.epochs)
print(FLAGS.num_monte_carlo)
# Out:
# 0.0001
# 700
# 50

# %%
def build_input_pipeline(X_train,X_test,y_train, y_test, batch_size, valid_size):
  #Build an iterator over training batches 
  training_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
  #Shuffle the dataset (note shuffle argument much larger than training size)
  # and form batches of size batch_size
  training_batches = training_dataset.shuffle(20000, reshuffle_each_iteration =True).repeat().batch(batch_size)
  training_iterator = tf.data.make_one_shot_iterator(training_batches)
  
  #Building iterator over the heldout set with batch_size = heldout_size,
  # i.e., return the entire heldout set as a constant.
  heldout_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test))
  heldout_batches = heldout_dataset.repeat().batch(valid_size)
  heldout_iterator = tf.data.make_one_shot_iterator(heldout_batches)
  
  #Combine these into a feasible iterator that can switch between training 
  # and validation inputs.
  # Here should be minibatch increment be defined 
  handle = tf.placeholder(tf.string, shape = [])
  feedable_iterator = tf.data.Iterator.from_string_handle(handle, training_batches.output_types, training_batches.output_shapes)
  features_final, labels_final = feedable_iterator.get_next()
  
  return features_final, labels_final, handle, training_iterator, heldout_iterator

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !ls "/content/gdrive/My Drive/"
# Out:
#  acc_1.csv   Bayesian_log_trial_.ipynb	 elvin.csv	   Untitled1.ipynb
#  acc_2.csv   BNN_Work.ipynb		 kernel.ipynb	   work2.csv
#  acc_3.csv  'Colab Notebooks'		 preds_2.npy	   work_main
#  acc_4.csv   data1.csv			 preds_3.npy
#  acc_5.csv   data23.csv			 Untitled0.ipynb

# %%
# Read in the dataset
df = pd.read_csv('/content/gdrive/My Drive/work2.csv').astype(np.float32)
change = df.query('Speed>0').sample(frac = .1).index
df.loc[change, 'Speed'] = 0
df.loc[change, 'Class'] = 0
df.to_csv('work2.csv', header = True, index =False)
df.shape
# Out:
# (1048575, 20)

# %%
X = df.iloc[:,:-1].values
y = df.iloc[:,-1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state =1)

#reshape y-data to become column vector 
y_train = np.reshape(y_train, [-1,1])
y_test = np.reshape(y_test, [-1,1])

# %%
# Standardize the dataset 
scalar_x_train = StandardScaler().fit(X_train)
scalar_x_test = StandardScaler().fit(X_test)
X_train = scalar_x_train.transform(X_train)
X_test = scalar_x_test.transform(X_test)

# %%
def main(argv):
  (features_final, labels_final, handle, training_iterator, heldout_iterator) = build_input_pipeline(X_train,X_test, y_train,y_test, FLAGS.batch_size, 500)
  
  #features, labels = build_input_pipeline(X,y, FLAGS.batch_size)
  #Building Bayesian Logistic 
  with tf.name_scope("logistic_regression", values=[features_final]):
    layer = tfp.layers.DenseFlipout(
        units=1,
        activation= tf.nn.relu,
        kernel_posterior_fn=tfp.layers.default_mean_field_normal_fn(),
        bias_posterior_fn=tfp.layers.default_mean_field_normal_fn())
    logits = layer(features_final)
   # logits = layer(features)
    labels_distribution = tfd.Bernoulli(logits=logits)
 #Compute the -ELBO as the loss, averaged over the batch size 
    t = tf.Variable(0.0)
    kl_regularizer = t / (FLAGS.kl_annealing * len(X_train) / FLAGS.batch_size)
  
    #Compute the -ELBO as the loss. The kl term is annealed from 1 to 1 over 
    # the epochs specified by the kl_annealing flag.
    #log_likelihood = labels_distribution.log_prob(labels_final)
    #log_likelihood = labels_distribution.log_prob(labels)
   #neg_log_likelihood = tf.reduce_mean(tf.squared_difference(logits,labels_final))
    neg_log_likelihood = -tf.reduce_mean(input_tensor = labels_distribution.log_prob(labels_final))
    #neg_log_likelihood = -tf.reduce_mean(input_tensor = log_likelihood)
    
    kl = sum(layer.losses)/len(X_train) * tf.minimum(1.0, kl_regularizer)
    elbo_loss = neg_log_likelihood + kl
   
  """neg_log_likelihood = -tf.reduce_mean(labels_distribution.log_prob(features))
  kl = sum(layer.losses)/len(X_train)
  elbo_loss = neg_log_likelihood + kl """
  #Build metrics for evaluation. Predictions are formed from single forward 
  #pass of the probabilistic layers. They are cheap but noise predictions
  #predictions = tf.argmax(input = logits, axis=1)
  predictions = tf.cast(logits>0, dtype = tf.int32)
  #accuracy, accuracy_update_op = tf.metrics.accuracy(labels= labels_final,  predictions = predictions)
  
  with tf.name_scope("train"):
    train_accuracy, train_accuracy_update_op = tf.metrics.accuracy(labels= labels_final,  predictions = predictions)
    optimizer =tf.train.AdamOptimizer(learning_rate=FLAGS.learning_rate)
    train_op = optimizer.minimize(elbo_loss)
    update_step_op = tf.assign(t, t+1)
    #init_op = tf.group(tf.global_variables_initializer(), tf.local_variables_initializer())
  
  with tf.name_scope("valid"):
    valid_accuracy, validation_accuracy_update_op = tf.metrics.accuracy(labels = labels_final,predictions = predictions)
    init_op = tf.group(tf.global_variables_initializer(), 
                       tf.local_variables_initializer())
    stream_vars_valid = [v for v in tf.local_variables() if "valid" in v.name]
    reset_valid_op = tf.variables_initializer(stream_vars_valid)
    
    
    
  with tf.Session() as sess:
    
    sess.run(init_op)
    #Run the training looop
    # Fit the model to data.
    train_handle = sess.run(training_iterator.string_handle())
    heldout_handle = sess.run(heldout_iterator.string_handle())
    training_steps = int(round(FLAGS.epochs * (len(X_train) / FLAGS.batch_size)))
    for step in range(training_steps):
      _ = sess.run([train_op,train_accuracy_update_op, update_step_op],feed_dict={handle: train_handle})
      
      # Manually print the frequency 
      if step % 100 == 0:
        loss_value, accuracy_value, kl_value = sess.run([elbo_loss, train_accuracy, kl], feed_dict= {handle:train_handle})
        print("Step:{:>3d} loss : {:.3f} KL: {:.3f}" .format(step , loss_value, accuracy_value, kl_value))
        
      if (step +1) % FLAGS.eval_freq ==0: 
        # Compute log prob of heldout set by averaging draws from the model:
        # p(heldout | train) = int_model p(heldout|model) p(model|train) ~= 1/n * sum_{i=1}^n p(heldout | model_i)
        # where model_i is a draw from the posterior 
        #p(model|train)
        probs = np.asarray([sess.run((labels_distribution.probs), 
                                     feed_dict ={handle: heldout_handle})
      
                            for _ in range(FLAGS.num_monte_carlo)])
     
        mean_probs = np.mean(probs, axis =0).astype(np.int32)
        print(mean_probs.dtype)
        
        _, label_vals = sess.run((features_final, labels_final), feed_dict = {handle: heldout_handle})
        label_vals = (label_vals).astype(np.int32)
      
       # heldout_lp = np.mean(np.log(mean_probs[np.arange(mean_probs.shape[0]), label_vals]))
        
        
        #print(" ...Held_out nats: {:.3f}".format(heldout_lp))
        
       # Calculate validation accuracy

        for _ in range(20):

          sess.run(validation_accuracy_update_op, feed_dict={handle: heldout_handle})

        valid_value = sess.run(

            valid_accuracy, feed_dict={handle: heldout_handle})

        print(

            " ... Validation Accuracy: {:.3f}".format(valid_value))

        sess.run(reset_valid_op)
if __name__ == "__main__": 
  tf.app.run()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/metrics_impl.py:455: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Step:  0 loss : 0.632 KL: 0.477
# Step:100 loss : 0.637 KL: 0.488
# Step:200 loss : 0.635 KL: 0.490
# Step:300 loss : 0.621 KL: 0.497
# int32
#  ... Validation Accuracy: 0.507
# Step:400 loss : 0.630 KL: 0.498
# Step:500 loss : 0.586 KL: 0.500
# Step:600 loss : 0.589 KL: 0.505
# Step:700 loss : 0.591 KL: 0.507
# int32
#  ... Validation Accuracy: 0.537
# Step:800 loss : 0.602 KL: 0.511
# Step:900 loss : 0.599 KL: 0.515
# Step:1000 loss : 0.557 KL: 0.518
# Step:1100 loss : 0.582 KL: 0.520
# int32
#  ... Validation Accuracy: 0.548
# Step:1200 loss : 0.549 KL: 0.522
# Step:1300 loss : 0.565 KL: 0.525
# Step:1400 loss : 0.520 KL: 0.527
# Step:1500 loss : 0.557 KL: 0.530
# int32
#  ... Validation Accuracy: 0.556
# Step:1600 loss : 0.566 KL: 0.532
# Step:1700 loss : 0.555 KL: 0.535
# Step:1800 loss : 0.524 KL: 0.537
# Step:1900 loss : 0.545 KL: 0.539
# int32
#  ... Validation Accuracy: 0.585
# Step:2000 loss : 0.531 KL: 0.542
# Step:2100 loss : 0.550 KL: 0.544
# Step:2200 loss : 0.570 KL: 0.545
# Step:2300 loss : 0.518 KL: 0.548
# int32
#  ... Validation Accuracy: 0.594
# Step:2400 loss : 0.537 KL: 0.550
# Step:2500 loss : 0.503 KL: 0.551
# Step:2600 loss : 0.489 KL: 0.553
# Step:2700 loss : 0.501 KL: 0.555
# int32
#  ... Validation Accuracy: 0.602
# Step:2800 loss : 0.520 KL: 0.557
# Step:2900 loss : 0.468 KL: 0.558
# Step:3000 loss : 0.498 KL: 0.560
# Step:3100 loss : 0.525 KL: 0.561
# int32
#  ... Validation Accuracy: 0.614
# Step:3200 loss : 0.502 KL: 0.563
# Step:3300 loss : 0.481 KL: 0.565
# Step:3400 loss : 0.536 KL: 0.566
# Step:3500 loss : 0.470 KL: 0.568
# int32
#  ... Validation Accuracy: 0.619
# Step:3600 loss : 0.522 KL: 0.569
# Step:3700 loss : 0.437 KL: 0.570
# Step:3800 loss : 0.513 KL: 0.571
# Step:3900 loss : 0.482 KL: 0.572
# int32
#  ... Validation Accuracy: 0.615
# Step:4000 loss : 0.476 KL: 0.574
# Step:4100 loss : 0.509 KL: 0.575
# Step:4200 loss : 0.497 KL: 0.576
# Step:4300 loss : 0.437 KL: 0.577
# int32
#  ... Validation Accuracy: 0.619
# Step:4400 loss : 0.448 KL: 0.578
# Step:4500 loss : 0.464 KL: 0.579
# Step:4600 loss : 0.481 KL: 0.580
# Step:4700 loss : 0.453 KL: 0.580
# int32
#  ... Validation Accuracy: 0.619
# Step:4800 loss : 0.453 KL: 0.581
# Step:4900 loss : 0.492 KL: 0.582
# Step:5000 loss : 0.462 KL: 0.583
# Step:5100 loss : 0.445 KL: 0.584
# int32
#  ... Validation Accuracy: 0.631
# Step:5200 loss : 0.451 KL: 0.584
# Step:5300 loss : 0.473 KL: 0.585
# Step:5400 loss : 0.437 KL: 0.586
# Step:5500 loss : 0.411 KL: 0.587
# int32
#  ... Validation Accuracy: 0.629
# Step:5600 loss : 0.396 KL: 0.587
# Step:5700 loss : 0.471 KL: 0.588
# Step:5800 loss : 0.458 KL: 0.589
# Step:5900 loss : 0.429 KL: 0.589
# int32
#  ... Validation Accuracy: 0.629
# Step:6000 loss : 0.440 KL: 0.590
# Step:6100 loss : 0.430 KL: 0.591
# Step:6200 loss : 0.436 KL: 0.591
# Step:6300 loss : 0.475 KL: 0.592
# int32
#  ... Validation Accuracy: 0.633
# Step:6400 loss : 0.441 KL: 0.592
# Step:6500 loss : 0.468 KL: 0.593
# Step:6600 loss : 0.411 KL: 0.594
# Step:6700 loss : 0.417 KL: 0.594
# int32
#  ... Validation Accuracy: 0.632
# Step:6800 loss : 0.398 KL: 0.595
# Step:6900 loss : 0.399 KL: 0.595
# Step:7000 loss : 0.438 KL: 0.596
# Step:7100 loss : 0.400 KL: 0.596
# int32
#  ... Validation Accuracy: 0.642
# Step:7200 loss : 0.413 KL: 0.597
# Step:7300 loss : 0.432 KL: 0.598
# Step:7400 loss : 0.403 KL: 0.598
# Step:7500 loss : 0.408 KL: 0.599
# int32
#  ... Validation Accuracy: 0.650
# Step:7600 loss : 0.426 KL: 0.599
# Step:7700 loss : 0.408 KL: 0.600
# Step:7800 loss : 0.388 KL: 0.601
# Step:7900 loss : 0.404 KL: 0.601
# int32
#  ... Validation Accuracy: 0.641
# Step:8000 loss : 0.441 KL: 0.602
# Step:8100 loss : 0.382 KL: 0.603
# Step:8200 loss : 0.382 KL: 0.603
# Step:8300 loss : 0.421 KL: 0.604
# int32
#  ... Validation Accuracy: 0.662
# Step:8400 loss : 0.499 KL: 0.605
# Step:8500 loss : 0.394 KL: 0.605
# Step:8600 loss : 0.365 KL: 0.606
# Step:8700 loss : 0.375 KL: 0.607
# int32
#  ... Validation Accuracy: 0.672
# Step:8800 loss : 0.425 KL: 0.608
# Step:8900 loss : 0.363 KL: 0.608
# Step:9000 loss : 0.317 KL: 0.609
# Step:9100 loss : 0.389 KL: 0.610
# int32
#  ... Validation Accuracy: 0.675
# Step:9200 loss : 0.359 KL: 0.610
# Step:9300 loss : 0.405 KL: 0.611
# Step:9400 loss : 0.434 KL: 0.612
# Step:9500 loss : 0.432 KL: 0.613
# int32
#  ... Validation Accuracy: 0.684
# Step:9600 loss : 0.376 KL: 0.614
# Step:9700 loss : 0.419 KL: 0.614
# Step:9800 loss : 0.383 KL: 0.615
# Step:9900 loss : 0.369 KL: 0.616
# int32
#  ... Validation Accuracy: 0.693
# Step:10000 loss : 0.346 KL: 0.617
# Step:10100 loss : 0.356 KL: 0.618
# Step:10200 loss : 0.382 KL: 0.618
# Step:10300 loss : 0.411 KL: 0.619
# int32
#  ... Validation Accuracy: 0.695
# Step:10400 loss : 0.376 KL: 0.620
# Step:10500 loss : 0.365 KL: 0.621
# Step:10600 loss : 0.359 KL: 0.622
# Step:10700 loss : 0.347 KL: 0.622
# int32
#  ... Validation Accuracy: 0.709
# Step:10800 loss : 0.379 KL: 0.623
# Step:10900 loss : 0.408 KL: 0.624
# Step:11000 loss : 0.334 KL: 0.625
# Step:11100 loss : 0.361 KL: 0.626
# int32
#  ... Validation Accuracy: 0.723
# Step:11200 loss : 0.360 KL: 0.627
# Step:11300 loss : 0.335 KL: 0.628
# Step:11400 loss : 0.319 KL: 0.629
# Step:11500 loss : 0.322 KL: 0.629
# int32
#  ... Validation Accuracy: 0.729
# Step:11600 loss : 0.369 KL: 0.630
# Step:11700 loss : 0.351 KL: 0.631
# Step:11800 loss : 0.355 KL: 0.632
# Step:11900 loss : 0.326 KL: 0.633
# int32
#  ... Validation Accuracy: 0.749
# Step:12000 loss : 0.352 KL: 0.634
# Step:12100 loss : 0.298 KL: 0.635
# Step:12200 loss : 0.347 KL: 0.636
# Step:12300 loss : 0.350 KL: 0.637
# int32
#  ... Validation Accuracy: 0.758
# Step:12400 loss : 0.353 KL: 0.638
# Step:12500 loss : 0.305 KL: 0.639
# Step:12600 loss : 0.295 KL: 0.639
# Step:12700 loss : 0.283 KL: 0.640
# int32
#  ... Validation Accuracy: 0.749
# Step:12800 loss : 0.325 KL: 0.641
# Step:12900 loss : 0.336 KL: 0.642
# Step:13000 loss : 0.389 KL: 0.643
# Step:13100 loss : 0.316 KL: 0.644
# int32
#  ... Validation Accuracy: 0.755
# Step:13200 loss : 0.324 KL: 0.645
# Step:13300 loss : 0.306 KL: 0.646
# Step:13400 loss : 0.302 KL: 0.647
# Step:13500 loss : 0.339 KL: 0.648
# int32
#  ... Validation Accuracy: 0.771
# Step:13600 loss : 0.357 KL: 0.649
# Step:13700 loss : 0.304 KL: 0.650
# Step:13800 loss : 0.295 KL: 0.651
# Step:13900 loss : 0.292 KL: 0.651
# int32
#  ... Validation Accuracy: 0.781
# Step:14000 loss : 0.328 KL: 0.652
# Step:14100 loss : 0.276 KL: 0.653
# Step:14200 loss : 0.318 KL: 0.654
# Step:14300 loss : 0.298 KL: 0.655
# int32
#  ... Validation Accuracy: 0.796
# Step:14400 loss : 0.317 KL: 0.656
# Step:14500 loss : 0.288 KL: 0.657
# Step:14600 loss : 0.262 KL: 0.658
# Step:14700 loss : 0.314 KL: 0.659
# int32
#  ... Validation Accuracy: 0.797
# Step:14800 loss : 0.310 KL: 0.660
# Step:14900 loss : 0.316 KL: 0.661
# Step:15000 loss : 0.287 KL: 0.662
# Step:15100 loss : 0.272 KL: 0.663
# int32
#  ... Validation Accuracy: 0.802
# Step:15200 loss : 0.302 KL: 0.663
# Step:15300 loss : 0.317 KL: 0.664
# Step:15400 loss : 0.303 KL: 0.665
# Step:15500 loss : 0.349 KL: 0.666
# int32
#  ... Validation Accuracy: 0.786
# Step:15600 loss : 0.233 KL: 0.667
# Step:15700 loss : 0.278 KL: 0.668
# Step:15800 loss : 0.295 KL: 0.669
# Step:15900 loss : 0.311 KL: 0.669
# int32
#  ... Validation Accuracy: 0.799
# Step:16000 loss : 0.305 KL: 0.670
# Step:16100 loss : 0.297 KL: 0.671
# Step:16200 loss : 0.273 KL: 0.672
# Step:16300 loss : 0.229 KL: 0.673
# int32
#  ... Validation Accuracy: 0.809
# Step:16400 loss : 0.273 KL: 0.674
# Step:16500 loss : 0.269 KL: 0.674
# Step:16600 loss : 0.277 KL: 0.675
# Step:16700 loss : 0.303 KL: 0.676
# int32
#  ... Validation Accuracy: 0.815
# Step:16800 loss : 0.278 KL: 0.677
# Step:16900 loss : 0.318 KL: 0.678
# Step:17000 loss : 0.295 KL: 0.678
# Step:17100 loss : 0.259 KL: 0.679
# int32
#  ... Validation Accuracy: 0.817
# Step:17200 loss : 0.242 KL: 0.680
# Step:17300 loss : 0.280 KL: 0.681
# Step:17400 loss : 0.266 KL: 0.681
# Step:17500 loss : 0.255 KL: 0.682
# int32
#  ... Validation Accuracy: 0.821
# Step:17600 loss : 0.252 KL: 0.683
# Step:17700 loss : 0.272 KL: 0.684
# Step:17800 loss : 0.259 KL: 0.685
# Step:17900 loss : 0.235 KL: 0.685
# int32
#  ... Validation Accuracy: 0.812
# Step:18000 loss : 0.254 KL: 0.686
# Step:18100 loss : 0.247 KL: 0.687
# Step:18200 loss : 0.255 KL: 0.688
# Step:18300 loss : 0.256 KL: 0.688
# int32
#  ... Validation Accuracy: 0.821
# Step:18400 loss : 0.264 KL: 0.689
# Step:18500 loss : 0.224 KL: 0.690
# Step:18600 loss : 0.276 KL: 0.690
# Step:18700 loss : 0.266 KL: 0.691
# int32
#  ... Validation Accuracy: 0.830
# Step:18800 loss : 0.317 KL: 0.692
# Step:18900 loss : 0.267 KL: 0.693
# Step:19000 loss : 0.272 KL: 0.693
# Step:19100 loss : 0.288 KL: 0.694
# int32
#  ... Validation Accuracy: 0.824
# Step:19200 loss : 0.243 KL: 0.695
# Step:19300 loss : 0.235 KL: 0.695
# Step:19400 loss : 0.229 KL: 0.696
# Step:19500 loss : 0.277 KL: 0.697
# int32
#  ... Validation Accuracy: 0.834
# Step:19600 loss : 0.272 KL: 0.697
# Step:19700 loss : 0.237 KL: 0.698
# Step:19800 loss : 0.269 KL: 0.699
# Step:19900 loss : 0.225 KL: 0.699
# int32
#  ... Validation Accuracy: 0.840
# Step:20000 loss : 0.225 KL: 0.700
# Step:20100 loss : 0.235 KL: 0.701
# Step:20200 loss : 0.287 KL: 0.701
# Step:20300 loss : 0.284 KL: 0.702
# int32
#  ... Validation Accuracy: 0.850
# Step:20400 loss : 0.256 KL: 0.703
# Step:20500 loss : 0.240 KL: 0.703
# Step:20600 loss : 0.232 KL: 0.704
# Step:20700 loss : 0.304 KL: 0.705
# int32
#  ... Validation Accuracy: 0.866
# Step:20800 loss : 0.276 KL: 0.706
# Step:20900 loss : 0.236 KL: 0.706
# Step:21000 loss : 0.249 KL: 0.707
# Step:21100 loss : 0.279 KL: 0.708
# int32
#  ... Validation Accuracy: 0.886
# Step:21200 loss : 0.207 KL: 0.709
# Step:21300 loss : 0.182 KL: 0.709
# Step:21400 loss : 0.256 KL: 0.710
# Step:21500 loss : 0.220 KL: 0.711
# int32
#  ... Validation Accuracy: 0.894
# Step:21600 loss : 0.322 KL: 0.712
# Step:21700 loss : 0.221 KL: 0.713
# Step:21800 loss : 0.220 KL: 0.713
# Step:21900 loss : 0.227 KL: 0.714
# int32
#  ... Validation Accuracy: 0.902
# Step:22000 loss : 0.238 KL: 0.715
# Step:22100 loss : 0.179 KL: 0.716
# Step:22200 loss : 0.254 KL: 0.717
# Step:22300 loss : 0.179 KL: 0.718
# int32
#  ... Validation Accuracy: 0.916
# Step:22400 loss : 0.210 KL: 0.719
# Step:22500 loss : 0.205 KL: 0.719
# Step:22600 loss : 0.219 KL: 0.720
# Step:22700 loss : 0.246 KL: 0.721
# int32
#  ... Validation Accuracy: 0.929
# Step:22800 loss : 0.245 KL: 0.722
# Step:22900 loss : 0.223 KL: 0.723
# Step:23000 loss : 0.195 KL: 0.724
# Step:23100 loss : 0.242 KL: 0.725
# int32
#  ... Validation Accuracy: 0.935
# Step:23200 loss : 0.242 KL: 0.726
# Step:23300 loss : 0.187 KL: 0.727
# Step:23400 loss : 0.201 KL: 0.728
# Step:23500 loss : 0.177 KL: 0.728
# int32
#  ... Validation Accuracy: 0.932
# Step:23600 loss : 0.225 KL: 0.729
# Step:23700 loss : 0.217 KL: 0.730
# Step:23800 loss : 0.204 KL: 0.731
# Step:23900 loss : 0.162 KL: 0.732
# int32
#  ... Validation Accuracy: 0.936
# Step:24000 loss : 0.206 KL: 0.733
# Step:24100 loss : 0.166 KL: 0.734
# Step:24200 loss : 0.186 KL: 0.735
# Step:24300 loss : 0.176 KL: 0.735
# int32
#  ... Validation Accuracy: 0.932
# Step:24400 loss : 0.154 KL: 0.736
# Step:24500 loss : 0.149 KL: 0.737
# Step:24600 loss : 0.196 KL: 0.738
# Step:24700 loss : 0.206 KL: 0.739
# int32
#  ... Validation Accuracy: 0.939
# Step:24800 loss : 0.163 KL: 0.739
# Step:24900 loss : 0.198 KL: 0.740
# Step:25000 loss : 0.180 KL: 0.741
# Step:25100 loss : 0.173 KL: 0.742
# int32
#  ... Validation Accuracy: 0.936
# Step:25200 loss : 0.180 KL: 0.743
# Step:25300 loss : 0.206 KL: 0.743
# Step:25400 loss : 0.211 KL: 0.744
# Step:25500 loss : 0.140 KL: 0.745
# int32
#  ... Validation Accuracy: 0.934
# Step:25600 loss : 0.154 KL: 0.746
# Step:25700 loss : 0.152 KL: 0.746
# Step:25800 loss : 0.144 KL: 0.747
# Step:25900 loss : 0.192 KL: 0.748
# int32
#  ... Validation Accuracy: 0.934
# Step:26000 loss : 0.168 KL: 0.749
# Step:26100 loss : 0.179 KL: 0.749
# Step:26200 loss : 0.199 KL: 0.750
# Step:26300 loss : 0.215 KL: 0.751
# int32
#  ... Validation Accuracy: 0.941
# Step:26400 loss : 0.186 KL: 0.751
# Step:26500 loss : 0.158 KL: 0.752
# Step:26600 loss : 0.153 KL: 0.753
# Step:26700 loss : 0.198 KL: 0.754
# int32
#  ... Validation Accuracy: 0.936
# Step:26800 loss : 0.204 KL: 0.754
# Step:26900 loss : 0.179 KL: 0.755
# Step:27000 loss : 0.143 KL: 0.756
# Step:27100 loss : 0.171 KL: 0.756
# int32
#  ... Validation Accuracy: 0.943
# Step:27200 loss : 0.155 KL: 0.757
# Step:27300 loss : 0.141 KL: 0.758
# Step:27400 loss : 0.138 KL: 0.758
# Step:27500 loss : 0.174 KL: 0.759
# int32
#  ... Validation Accuracy: 0.936
# Step:27600 loss : 0.122 KL: 0.760
# Step:27700 loss : 0.180 KL: 0.760
# Step:27800 loss : 0.159 KL: 0.761
# Step:27900 loss : 0.193 KL: 0.762
# int32
#  ... Validation Accuracy: 0.937
# Step:28000 loss : 0.151 KL: 0.762
# Step:28100 loss : 0.181 KL: 0.763
# Step:28200 loss : 0.157 KL: 0.764
# Step:28300 loss : 0.172 KL: 0.764
# int32
#  ... Validation Accuracy: 0.938
# Step:28400 loss : 0.178 KL: 0.765
# Step:28500 loss : 0.144 KL: 0.765
# Step:28600 loss : 0.137 KL: 0.766
# Step:28700 loss : 0.171 KL: 0.767
# int32
#  ... Validation Accuracy: 0.947
# Step:28800 loss : 0.147 KL: 0.767
# Step:28900 loss : 0.181 KL: 0.768
# Step:29000 loss : 0.133 KL: 0.769
# Step:29100 loss : 0.153 KL: 0.769
# int32
#  ... Validation Accuracy: 0.946
# Step:29200 loss : 0.167 KL: 0.770
# Step:29300 loss : 0.168 KL: 0.770
# Step:29400 loss : 0.177 KL: 0.771
# Step:29500 loss : 0.160 KL: 0.772
# int32
#  ... Validation Accuracy: 0.944
# Step:29600 loss : 0.157 KL: 0.772
# Step:29700 loss : 0.127 KL: 0.773
# Step:29800 loss : 0.181 KL: 0.773
# Step:29900 loss : 0.142 KL: 0.774
# int32
#  ... Validation Accuracy: 0.944
# Step:30000 loss : 0.148 KL: 0.774
# Step:30100 loss : 0.141 KL: 0.775
# Step:30200 loss : 0.110 KL: 0.776
# Step:30300 loss : 0.182 KL: 0.776
# int32
#  ... Validation Accuracy: 0.942
# Step:30400 loss : 0.205 KL: 0.777
# Step:30500 loss : 0.126 KL: 0.777
# Step:30600 loss : 0.158 KL: 0.778
# Step:30700 loss : 0.178 KL: 0.778
# int32
#  ... Validation Accuracy: 0.947
# Step:30800 loss : 0.169 KL: 0.779
# Step:30900 loss : 0.168 KL: 0.779
# Step:31000 loss : 0.164 KL: 0.780
# Step:31100 loss : 0.118 KL: 0.781
# int32
#  ... Validation Accuracy: 0.949
# Step:31200 loss : 0.177 KL: 0.781
# Step:31300 loss : 0.170 KL: 0.782
# Step:31400 loss : 0.113 KL: 0.782
# Step:31500 loss : 0.212 KL: 0.783
# int32
#  ... Validation Accuracy: 0.947
# Step:31600 loss : 0.154 KL: 0.783
# Step:31700 loss : 0.117 KL: 0.784
# Step:31800 loss : 0.118 KL: 0.784
# Step:31900 loss : 0.182 KL: 0.785
# int32
#  ... Validation Accuracy: 0.943
# Step:32000 loss : 0.149 KL: 0.785
# Step:32100 loss : 0.137 KL: 0.786
# Step:32200 loss : 0.136 KL: 0.786
# Step:32300 loss : 0.148 KL: 0.787
# int32
#  ... Validation Accuracy: 0.948
# Step:32400 loss : 0.162 KL: 0.787
# Step:32500 loss : 0.155 KL: 0.788
# Step:32600 loss : 0.151 KL: 0.788
# Step:32700 loss : 0.134 KL: 0.789
# int32
#  ... Validation Accuracy: 0.945
# Step:32800 loss : 0.134 KL: 0.789
# Step:32900 loss : 0.167 KL: 0.790
# Step:33000 loss : 0.123 KL: 0.790
# Step:33100 loss : 0.150 KL: 0.791
# int32
#  ... Validation Accuracy: 0.950
# Step:33200 loss : 0.190 KL: 0.791
# Step:33300 loss : 0.149 KL: 0.792
# Step:33400 loss : 0.186 KL: 0.792
# Step:33500 loss : 0.134 KL: 0.793
# int32
#  ... Validation Accuracy: 0.951
# Step:33600 loss : 0.160 KL: 0.793
# Step:33700 loss : 0.174 KL: 0.794
# Step:33800 loss : 0.172 KL: 0.794
# Step:33900 loss : 0.143 KL: 0.795
# int32
#  ... Validation Accuracy: 0.951
# Step:34000 loss : 0.117 KL: 0.795
# Step:34100 loss : 0.125 KL: 0.795
# Step:34200 loss : 0.102 KL: 0.796
# Step:34300 loss : 0.111 KL: 0.796
# int32
#  ... Validation Accuracy: 0.948
# Step:34400 loss : 0.180 KL: 0.797
# Step:34500 loss : 0.139 KL: 0.797
# Step:34600 loss : 0.107 KL: 0.798
# Step:34700 loss : 0.138 KL: 0.798
# int32
#  ... Validation Accuracy: 0.953
# Step:34800 loss : 0.134 KL: 0.799
# Step:34900 loss : 0.142 KL: 0.799
# Step:35000 loss : 0.147 KL: 0.799
# Step:35100 loss : 0.187 KL: 0.800
# int32
#  ... Validation Accuracy: 0.950
# Step:35200 loss : 0.153 KL: 0.800
# Step:35300 loss : 0.129 KL: 0.801
# Step:35400 loss : 0.130 KL: 0.801
# Step:35500 loss : 0.126 KL: 0.802
# int32
#  ... Validation Accuracy: 0.955
# Step:35600 loss : 0.104 KL: 0.802
# Step:35700 loss : 0.135 KL: 0.802
# Step:35800 loss : 0.213 KL: 0.803
# Step:35900 loss : 0.146 KL: 0.803
# int32
#  ... Validation Accuracy: 0.952
# Step:36000 loss : 0.149 KL: 0.804
# Step:36100 loss : 0.175 KL: 0.804
# Step:36200 loss : 0.123 KL: 0.805
# Step:36300 loss : 0.095 KL: 0.805
# int32
#  ... Validation Accuracy: 0.952
# Step:36400 loss : 0.151 KL: 0.805
# Step:36500 loss : 0.196 KL: 0.806
# Step:36600 loss : 0.110 KL: 0.806
# Step:36700 loss : 0.115 KL: 0.807
# int32
#  ... Validation Accuracy: 0.952
# Step:36800 loss : 0.118 KL: 0.807
# Step:36900 loss : 0.090 KL: 0.807
# Step:37000 loss : 0.145 KL: 0.808
# Step:37100 loss : 0.132 KL: 0.808
# int32
#  ... Validation Accuracy: 0.954
# Step:37200 loss : 0.147 KL: 0.809
# Step:37300 loss : 0.128 KL: 0.809
# Step:37400 loss : 0.122 KL: 0.809
# Step:37500 loss : 0.087 KL: 0.810
# int32
#  ... Validation Accuracy: 0.954
# Step:37600 loss : 0.140 KL: 0.810
# Step:37700 loss : 0.115 KL: 0.810
# Step:37800 loss : 0.132 KL: 0.811
# Step:37900 loss : 0.095 KL: 0.811
# int32
#  ... Validation Accuracy: 0.957
# Step:38000 loss : 0.149 KL: 0.812
# Step:38100 loss : 0.136 KL: 0.812
# Step:38200 loss : 0.108 KL: 0.812
# Step:38300 loss : 0.129 KL: 0.813
# int32
#  ... Validation Accuracy: 0.952
# Step:38400 loss : 0.169 KL: 0.813
# Step:38500 loss : 0.150 KL: 0.814
# Step:38600 loss : 0.142 KL: 0.814
# Step:38700 loss : 0.081 KL: 0.814
# int32
#  ... Validation Accuracy: 0.957
# Step:38800 loss : 0.150 KL: 0.815
# Step:38900 loss : 0.101 KL: 0.815
# Step:39000 loss : 0.152 KL: 0.815
# Step:39100 loss : 0.185 KL: 0.816
# int32
#  ... Validation Accuracy: 0.957
# Step:39200 loss : 0.142 KL: 0.816
# Step:39300 loss : 0.164 KL: 0.816
# Step:39400 loss : 0.111 KL: 0.817
# Step:39500 loss : 0.137 KL: 0.817
# int32
#  ... Validation Accuracy: 0.956
# Step:39600 loss : 0.133 KL: 0.817
# Step:39700 loss : 0.138 KL: 0.818
# Step:39800 loss : 0.099 KL: 0.818
# Step:39900 loss : 0.220 KL: 0.819
# int32
#  ... Validation Accuracy: 0.958
# Step:40000 loss : 0.121 KL: 0.819
# Step:40100 loss : 0.191 KL: 0.819
# Step:40200 loss : 0.110 KL: 0.820
# Step:40300 loss : 0.131 KL: 0.820
# int32
#  ... Validation Accuracy: 0.956
# Step:40400 loss : 0.111 KL: 0.820
# Step:40500 loss : 0.174 KL: 0.821
# Step:40600 loss : 0.077 KL: 0.821
# Step:40700 loss : 0.117 KL: 0.821
# int32
#  ... Validation Accuracy: 0.954
# Step:40800 loss : 0.139 KL: 0.822
# Step:40900 loss : 0.107 KL: 0.822
# Step:41000 loss : 0.071 KL: 0.822
# Step:41100 loss : 0.143 KL: 0.823
# int32
#  ... Validation Accuracy: 0.958
# Step:41200 loss : 0.134 KL: 0.823
# Step:41300 loss : 0.131 KL: 0.823
# Step:41400 loss : 0.125 KL: 0.824
# Step:41500 loss : 0.117 KL: 0.824
# int32
#  ... Validation Accuracy: 0.956
# Step:41600 loss : 0.143 KL: 0.824
# Step:41700 loss : 0.108 KL: 0.824
# Step:41800 loss : 0.147 KL: 0.825
# Step:41900 loss : 0.168 KL: 0.825
# int32
#  ... Validation Accuracy: 0.958
# Step:42000 loss : 0.149 KL: 0.825
# Step:42100 loss : 0.142 KL: 0.826
# Step:42200 loss : 0.133 KL: 0.826
# Step:42300 loss : 0.156 KL: 0.826
# int32
#  ... Validation Accuracy: 0.960
# Step:42400 loss : 0.129 KL: 0.827
# Step:42500 loss : 0.069 KL: 0.827
# Step:42600 loss : 0.120 KL: 0.827
# Step:42700 loss : 0.130 KL: 0.828
# int32
#  ... Validation Accuracy: 0.955
# Step:42800 loss : 0.146 KL: 0.828
# Step:42900 loss : 0.154 KL: 0.828
# Step:43000 loss : 0.165 KL: 0.829
# Step:43100 loss : 0.097 KL: 0.829
# int32
#  ... Validation Accuracy: 0.956
# Step:43200 loss : 0.152 KL: 0.829
# Step:43300 loss : 0.099 KL: 0.829
# Step:43400 loss : 0.129 KL: 0.830
# Step:43500 loss : 0.120 KL: 0.830
# int32
#  ... Validation Accuracy: 0.959
# Step:43600 loss : 0.141 KL: 0.830
# Step:43700 loss : 0.168 KL: 0.831
# Step:43800 loss : 0.095 KL: 0.831
# Step:43900 loss : 0.135 KL: 0.831
# int32
#  ... Validation Accuracy: 0.959
# Step:44000 loss : 0.128 KL: 0.832
# Step:44100 loss : 0.137 KL: 0.832
# Step:44200 loss : 0.158 KL: 0.832
# Step:44300 loss : 0.120 KL: 0.832
# int32
#  ... Validation Accuracy: 0.961
# Step:44400 loss : 0.084 KL: 0.833
# Step:44500 loss : 0.130 KL: 0.833
# Step:44600 loss : 0.104 KL: 0.833
# Step:44700 loss : 0.152 KL: 0.834
# int32
#  ... Validation Accuracy: 0.965
# Step:44800 loss : 0.145 KL: 0.834
# Step:44900 loss : 0.129 KL: 0.834
# Step:45000 loss : 0.085 KL: 0.834
# Step:45100 loss : 0.082 KL: 0.835
# int32
#  ... Validation Accuracy: 0.958
# Step:45200 loss : 0.076 KL: 0.835
# Step:45300 loss : 0.186 KL: 0.835
# Step:45400 loss : 0.139 KL: 0.835
# Step:45500 loss : 0.148 KL: 0.836
# int32
#  ... Validation Accuracy: 0.958
# Step:45600 loss : 0.108 KL: 0.836
# Step:45700 loss : 0.143 KL: 0.836
# Step:45800 loss : 0.116 KL: 0.837
# Step:45900 loss : 0.159 KL: 0.837
# int32
#  ... Validation Accuracy: 0.962
# Step:46000 loss : 0.110 KL: 0.837
# Step:46100 loss : 0.153 KL: 0.837
# Step:46200 loss : 0.127 KL: 0.838
# Step:46300 loss : 0.140 KL: 0.838
# int32
#  ... Validation Accuracy: 0.959
# Step:46400 loss : 0.131 KL: 0.838
# Step:46500 loss : 0.124 KL: 0.838
# Step:46600 loss : 0.135 KL: 0.839
# Step:46700 loss : 0.177 KL: 0.839
# int32
#  ... Validation Accuracy: 0.958
# Step:46800 loss : 0.107 KL: 0.839
# Step:46900 loss : 0.120 KL: 0.839
# Step:47000 loss : 0.161 KL: 0.840
# Step:47100 loss : 0.134 KL: 0.840
# int32
#  ... Validation Accuracy: 0.961
# Step:47200 loss : 0.105 KL: 0.840
# Step:47300 loss : 0.124 KL: 0.840
# Step:47400 loss : 0.122 KL: 0.841
# Step:47500 loss : 0.123 KL: 0.841
# int32
#  ... Validation Accuracy: 0.960
# Step:47600 loss : 0.165 KL: 0.841
# Step:47700 loss : 0.116 KL: 0.842
# Step:47800 loss : 0.100 KL: 0.842
# Step:47900 loss : 0.086 KL: 0.842
# int32
#  ... Validation Accuracy: 0.957
# Step:48000 loss : 0.129 KL: 0.842
# Step:48100 loss : 0.083 KL: 0.843
# Step:48200 loss : 0.128 KL: 0.843
# Step:48300 loss : 0.153 KL: 0.843
# int32
#  ... Validation Accuracy: 0.965
# Step:48400 loss : 0.085 KL: 0.843
# Step:48500 loss : 0.120 KL: 0.843
# Step:48600 loss : 0.169 KL: 0.844
# Step:48700 loss : 0.132 KL: 0.844
# int32
#  ... Validation Accuracy: 0.961
# Step:48800 loss : 0.129 KL: 0.844
# Step:48900 loss : 0.077 KL: 0.844
# Step:49000 loss : 0.121 KL: 0.845
# Step:49100 loss : 0.150 KL: 0.845
# int32
#  ... Validation Accuracy: 0.957
# Step:49200 loss : 0.124 KL: 0.845
# Step:49300 loss : 0.129 KL: 0.845
# Step:49400 loss : 0.177 KL: 0.846
# Step:49500 loss : 0.115 KL: 0.846
# int32
#  ... Validation Accuracy: 0.960
# Step:49600 loss : 0.097 KL: 0.846
# Step:49700 loss : 0.118 KL: 0.846
# Step:49800 loss : 0.109 KL: 0.847
# Step:49900 loss : 0.125 KL: 0.847
# int32
#  ... Validation Accuracy: 0.964
# Step:50000 loss : 0.096 KL: 0.847
# Step:50100 loss : 0.100 KL: 0.847
# Step:50200 loss : 0.116 KL: 0.847
# Step:50300 loss : 0.116 KL: 0.848
# int32
#  ... Validation Accuracy: 0.957
# Step:50400 loss : 0.106 KL: 0.848
# Step:50500 loss : 0.108 KL: 0.848
# Step:50600 loss : 0.079 KL: 0.848
# Step:50700 loss : 0.109 KL: 0.849
# int32
#  ... Validation Accuracy: 0.965
# Step:50800 loss : 0.137 KL: 0.849
# Step:50900 loss : 0.090 KL: 0.849
# Step:51000 loss : 0.132 KL: 0.849
# Step:51100 loss : 0.088 KL: 0.850
# int32
#  ... Validation Accuracy: 0.961
# Step:51200 loss : 0.130 KL: 0.850
# Step:51300 loss : 0.108 KL: 0.850
# Step:51400 loss : 0.159 KL: 0.850
# Step:51500 loss : 0.132 KL: 0.850
# int32
#  ... Validation Accuracy: 0.959
# Step:51600 loss : 0.140 KL: 0.851
# Step:51700 loss : 0.160 KL: 0.851
# Step:51800 loss : 0.148 KL: 0.851
# Step:51900 loss : 0.135 KL: 0.851
# int32
#  ... Validation Accuracy: 0.957
# Step:52000 loss : 0.095 KL: 0.851
# Step:52100 loss : 0.097 KL: 0.852
# Step:52200 loss : 0.098 KL: 0.852
# Step:52300 loss : 0.102 KL: 0.852
# int32
#  ... Validation Accuracy: 0.964
# Step:52400 loss : 0.149 KL: 0.852
# Step:52500 loss : 0.142 KL: 0.853
# Step:52600 loss : 0.107 KL: 0.853
# Step:52700 loss : 0.099 KL: 0.853
# int32
#  ... Validation Accuracy: 0.963
# Step:52800 loss : 0.169 KL: 0.853
# Step:52900 loss : 0.097 KL: 0.853
# Step:53000 loss : 0.149 KL: 0.854
# Step:53100 loss : 0.119 KL: 0.854
# int32
#  ... Validation Accuracy: 0.963
# Step:53200 loss : 0.163 KL: 0.854
# Step:53300 loss : 0.109 KL: 0.854
# Step:53400 loss : 0.157 KL: 0.854
# Step:53500 loss : 0.117 KL: 0.855
# int32
#  ... Validation Accuracy: 0.961
# Step:53600 loss : 0.090 KL: 0.855
# Step:53700 loss : 0.171 KL: 0.855
# Step:53800 loss : 0.114 KL: 0.855
# Step:53900 loss : 0.103 KL: 0.855
# int32
#  ... Validation Accuracy: 0.959
# Step:54000 loss : 0.137 KL: 0.856
# Step:54100 loss : 0.144 KL: 0.856
# Step:54200 loss : 0.109 KL: 0.856
# Step:54300 loss : 0.082 KL: 0.856
# int32
#  ... Validation Accuracy: 0.962
# Step:54400 loss : 0.117 KL: 0.856
# Step:54500 loss : 0.078 KL: 0.857
# Step:54600 loss : 0.121 KL: 0.857
# Step:54700 loss : 0.073 KL: 0.857
# int32
#  ... Validation Accuracy: 0.967
# Step:54800 loss : 0.093 KL: 0.857
# Step:54900 loss : 0.108 KL: 0.857
# Step:55000 loss : 0.173 KL: 0.858
# Step:55100 loss : 0.108 KL: 0.858
# int32
#  ... Validation Accuracy: 0.964
# Step:55200 loss : 0.118 KL: 0.858
# Step:55300 loss : 0.116 KL: 0.858
# Step:55400 loss : 0.100 KL: 0.858
# Step:55500 loss : 0.110 KL: 0.859
# int32
#  ... Validation Accuracy: 0.961
# Step:55600 loss : 0.090 KL: 0.859
# Step:55700 loss : 0.136 KL: 0.859
# Step:55800 loss : 0.123 KL: 0.859
# Step:55900 loss : 0.090 KL: 0.859
# int32
#  ... Validation Accuracy: 0.963
# Step:56000 loss : 0.102 KL: 0.860
# Step:56100 loss : 0.140 KL: 0.860
# Step:56200 loss : 0.101 KL: 0.860
# Step:56300 loss : 0.142 KL: 0.860
# int32
#  ... Validation Accuracy: 0.962
# Step:56400 loss : 0.115 KL: 0.860
# Step:56500 loss : 0.111 KL: 0.860
# Step:56600 loss : 0.131 KL: 0.861
# Step:56700 loss : 0.147 KL: 0.861
# int32
#  ... Validation Accuracy: 0.963
# Step:56800 loss : 0.116 KL: 0.861
# Step:56900 loss : 0.068 KL: 0.861
# Step:57000 loss : 0.133 KL: 0.861
# Step:57100 loss : 0.127 KL: 0.862
# int32
#  ... Validation Accuracy: 0.967
# Step:57200 loss : 0.130 KL: 0.862
# Step:57300 loss : 0.108 KL: 0.862
# Step:57400 loss : 0.111 KL: 0.862
# Step:57500 loss : 0.133 KL: 0.862
# int32
#  ... Validation Accuracy: 0.964
# Step:57600 loss : 0.118 KL: 0.862
# Step:57700 loss : 0.110 KL: 0.863
# Step:57800 loss : 0.127 KL: 0.863
# Step:57900 loss : 0.129 KL: 0.863
# int32
#  ... Validation Accuracy: 0.961
# Step:58000 loss : 0.111 KL: 0.863
# Step:58100 loss : 0.119 KL: 0.863
# Step:58200 loss : 0.160 KL: 0.863
# Step:58300 loss : 0.113 KL: 0.864
# int32
#  ... Validation Accuracy: 0.962
# Step:58400 loss : 0.098 KL: 0.864
# Step:58500 loss : 0.115 KL: 0.864
# Step:58600 loss : 0.085 KL: 0.864
# Step:58700 loss : 0.140 KL: 0.864
# int32
#  ... Validation Accuracy: 0.962
# Step:58800 loss : 0.066 KL: 0.865
# Step:58900 loss : 0.107 KL: 0.865
# Step:59000 loss : 0.137 KL: 0.865
# Step:59100 loss : 0.109 KL: 0.865
# int32
#  ... Validation Accuracy: 0.966
# Step:59200 loss : 0.109 KL: 0.865
# Step:59300 loss : 0.134 KL: 0.865
# Step:59400 loss : 0.094 KL: 0.866
# Step:59500 loss : 0.099 KL: 0.866
# int32
#  ... Validation Accuracy: 0.967
# Step:59600 loss : 0.095 KL: 0.866
# Step:59700 loss : 0.126 KL: 0.866
# Step:59800 loss : 0.115 KL: 0.866
# Step:59900 loss : 0.183 KL: 0.866
# int32
#  ... Validation Accuracy: 0.963
# Step:60000 loss : 0.110 KL: 0.867
# Step:60100 loss : 0.131 KL: 0.867
# Step:60200 loss : 0.112 KL: 0.867
# Step:60300 loss : 0.125 KL: 0.867
# int32
#  ... Validation Accuracy: 0.962
# Step:60400 loss : 0.092 KL: 0.867
# Step:60500 loss : 0.105 KL: 0.867
# Step:60600 loss : 0.094 KL: 0.868
# Step:60700 loss : 0.107 KL: 0.868
# int32
#  ... Validation Accuracy: 0.965
# Step:60800 loss : 0.159 KL: 0.868
# Step:60900 loss : 0.113 KL: 0.868
# Step:61000 loss : 0.110 KL: 0.868
# Step:61100 loss : 0.134 KL: 0.868
# int32
#  ... Validation Accuracy: 0.965
# Step:61200 loss : 0.120 KL: 0.869
# Step:61300 loss : 0.095 KL: 0.869
# Step:61400 loss : 0.089 KL: 0.869
# Step:61500 loss : 0.117 KL: 0.869
# int32
#  ... Validation Accuracy: 0.966
# Step:61600 loss : 0.154 KL: 0.869
# Step:61700 loss : 0.068 KL: 0.869
# Step:61800 loss : 0.096 KL: 0.869
# Step:61900 loss : 0.095 KL: 0.870
# int32
#  ... Validation Accuracy: 0.965
# Step:62000 loss : 0.166 KL: 0.870
# Step:62100 loss : 0.111 KL: 0.870
# Step:62200 loss : 0.164 KL: 0.870
# Step:62300 loss : 0.116 KL: 0.870
# int32
#  ... Validation Accuracy: 0.966
# Step:62400 loss : 0.099 KL: 0.870
# Step:62500 loss : 0.094 KL: 0.871
# Step:62600 loss : 0.081 KL: 0.871
# Step:62700 loss : 0.085 KL: 0.871
# int32
#  ... Validation Accuracy: 0.965
# Step:62800 loss : 0.174 KL: 0.871
# Step:62900 loss : 0.076 KL: 0.871
# Step:63000 loss : 0.113 KL: 0.871
# Step:63100 loss : 0.171 KL: 0.871
# int32
#  ... Validation Accuracy: 0.967
# Step:63200 loss : 0.126 KL: 0.872
# Step:63300 loss : 0.160 KL: 0.872
# Step:63400 loss : 0.132 KL: 0.872
# Step:63500 loss : 0.080 KL: 0.872
# int32
#  ... Validation Accuracy: 0.965
# Step:63600 loss : 0.120 KL: 0.872
# Step:63700 loss : 0.101 KL: 0.872
# Step:63800 loss : 0.117 KL: 0.872
# Step:63900 loss : 0.138 KL: 0.873
# int32
#  ... Validation Accuracy: 0.967
# Step:64000 loss : 0.113 KL: 0.873
# Step:64100 loss : 0.122 KL: 0.873
# Step:64200 loss : 0.118 KL: 0.873
# Step:64300 loss : 0.076 KL: 0.873
# int32
#  ... Validation Accuracy: 0.963
# Step:64400 loss : 0.092 KL: 0.873
# Step:64500 loss : 0.130 KL: 0.874
# Step:64600 loss : 0.100 KL: 0.874
# Step:64700 loss : 0.091 KL: 0.874
# int32
#  ... Validation Accuracy: 0.967
# Step:64800 loss : 0.080 KL: 0.874
# Step:64900 loss : 0.119 KL: 0.874
# Step:65000 loss : 0.147 KL: 0.874
# Step:65100 loss : 0.105 KL: 0.874
# int32
#  ... Validation Accuracy: 0.967
# Step:65200 loss : 0.129 KL: 0.875
# Step:65300 loss : 0.127 KL: 0.875
# Step:65400 loss : 0.137 KL: 0.875
# Step:65500 loss : 0.102 KL: 0.875
# int32
#  ... Validation Accuracy: 0.968
# Step:65600 loss : 0.139 KL: 0.875
# Step:65700 loss : 0.105 KL: 0.875
# Step:65800 loss : 0.152 KL: 0.875
# Step:65900 loss : 0.127 KL: 0.875
# int32
#  ... Validation Accuracy: 0.967
# Step:66000 loss : 0.186 KL: 0.876
# Step:66100 loss : 0.121 KL: 0.876
# Step:66200 loss : 0.146 KL: 0.876
# Step:66300 loss : 0.170 KL: 0.876
# int32
#  ... Validation Accuracy: 0.967
# Step:66400 loss : 0.125 KL: 0.876
# Step:66500 loss : 0.147 KL: 0.876
# Step:66600 loss : 0.126 KL: 0.876
# Step:66700 loss : 0.121 KL: 0.877
# int32
#  ... Validation Accuracy: 0.962
# Step:66800 loss : 0.074 KL: 0.877
# Step:66900 loss : 0.122 KL: 0.877
# Step:67000 loss : 0.065 KL: 0.877
# Step:67100 loss : 0.139 KL: 0.877
# int32
#  ... Validation Accuracy: 0.968
# Step:67200 loss : 0.104 KL: 0.877
# Step:67300 loss : 0.102 KL: 0.877
# Step:67400 loss : 0.092 KL: 0.878
# Step:67500 loss : 0.116 KL: 0.878
# int32
#  ... Validation Accuracy: 0.968
# Step:67600 loss : 0.123 KL: 0.878
# Step:67700 loss : 0.131 KL: 0.878
# Step:67800 loss : 0.104 KL: 0.878
# Step:67900 loss : 0.104 KL: 0.878
# int32
#  ... Validation Accuracy: 0.969
# Step:68000 loss : 0.131 KL: 0.878
# Step:68100 loss : 0.099 KL: 0.878
# Step:68200 loss : 0.080 KL: 0.879
# Step:68300 loss : 0.133 KL: 0.879
# int32
#  ... Validation Accuracy: 0.968
# Step:68400 loss : 0.115 KL: 0.879
# Step:68500 loss : 0.121 KL: 0.879
# Step:68600 loss : 0.094 KL: 0.879
# Step:68700 loss : 0.111 KL: 0.879
# int32
#  ... Validation Accuracy: 0.965
# Step:68800 loss : 0.119 KL: 0.879
# Step:68900 loss : 0.143 KL: 0.879
# Step:69000 loss : 0.111 KL: 0.880
# Step:69100 loss : 0.098 KL: 0.880
# int32
#  ... Validation Accuracy: 0.966
# Step:69200 loss : 0.092 KL: 0.880
# Step:69300 loss : 0.055 KL: 0.880
# Step:69400 loss : 0.115 KL: 0.880
# Step:69500 loss : 0.127 KL: 0.880
# int32
#  ... Validation Accuracy: 0.969
# Step:69600 loss : 0.136 KL: 0.880
# Step:69700 loss : 0.069 KL: 0.880
# Step:69800 loss : 0.067 KL: 0.881
# Step:69900 loss : 0.134 KL: 0.881
# int32
#  ... Validation Accuracy: 0.968
# Step:70000 loss : 0.155 KL: 0.881
# Step:70100 loss : 0.138 KL: 0.881
# Step:70200 loss : 0.107 KL: 0.881
# Step:70300 loss : 0.102 KL: 0.881
# int32
#  ... Validation Accuracy: 0.968
# Step:70400 loss : 0.064 KL: 0.881
# Step:70500 loss : 0.100 KL: 0.881
# Step:70600 loss : 0.087 KL: 0.882
# Step:70700 loss : 0.113 KL: 0.882
# int32
#  ... Validation Accuracy: 0.970
# Step:70800 loss : 0.121 KL: 0.882
# Step:70900 loss : 0.149 KL: 0.882
# Step:71000 loss : 0.100 KL: 0.882
# Step:71100 loss : 0.109 KL: 0.882
# int32
#  ... Validation Accuracy: 0.966
# Step:71200 loss : 0.126 KL: 0.882
# Step:71300 loss : 0.148 KL: 0.882
# Step:71400 loss : 0.133 KL: 0.883
# Step:71500 loss : 0.066 KL: 0.883
# int32
#  ... Validation Accuracy: 0.966
# Step:71600 loss : 0.099 KL: 0.883
# Step:71700 loss : 0.082 KL: 0.883
# Step:71800 loss : 0.109 KL: 0.883
# Step:71900 loss : 0.106 KL: 0.883
# int32
#  ... Validation Accuracy: 0.970
# Step:72000 loss : 0.108 KL: 0.883
# Step:72100 loss : 0.115 KL: 0.883
# Step:72200 loss : 0.114 KL: 0.884
# Step:72300 loss : 0.076 KL: 0.884

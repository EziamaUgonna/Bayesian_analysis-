# %% [markdown]
# <a href="https://colab.research.google.com/github/EziamaUgonna/Bayesian_analysis-/blob/master/Dissertation2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade -q gspread
from tensorboardcolab import *
import shutil
#clean out the directory
shutil.rmtree('./Graph', ignore_errors=True)
os.mkdir('./Graph')
#tf.reset_default_graph()
#will start the tunneling and will print out a link:
tbc=TensorBoardColab()
# Out:
# Using TensorFlow backend.
# Wait for 8 seconds...
# TensorBoard link:
# https://a78f6f62.ngrok.io

# %%
# !pip show tensorflow
# Out:
# Name: tensorflow
# Version: 1.13.1
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: opensource@google.com
# License: Apache 2.0
# Location: /usr/local/lib/python3.6/dist-packages
# Requires: tensorboard, tensorflow-estimator, termcolor, wheel, six, protobuf, absl-py, astor, keras-applications, numpy, keras-preprocessing, grpcio, gast
# Required-by: stable-baselines, magenta, fancyimpute

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

# %%
# Dependencies
import os 
import warnings 
#from absl import flags 
import matplotlib 
import numpy as np 
import tensorflow as tf 
import tensorflow_probability as tfp
import math
import pandas as pd
tfd = tfp.distributions
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
#from hyperopt import fmin, tpe, hp, STATUS_OK, STATUS_FAIL, Trials
#import python_utils
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.

# %%
# clear graph (if any) before running 
tf.reset_default_graph()

# %%
####Delete all flags before declare#####

def del_all_flags(FLAGS):
    flags_dict = FLAGS._flags()    
    keys_list = [keys for keys in flags_dict]    
    for keys in keys_list:
        FLAGS.__delattr__(keys)

del_all_flags(tf.flags.FLAGS)

flags = tf.app.flags
FLAGS = tf.app.flags.FLAGS
flags.DEFINE_float("learning_rate", default = 0.0001, help = "Initial learning rate.")
flags.DEFINE_integer("epochs", default = 700, help = "Number of epochs to train for")
flags.DEFINE_integer("batch_size", default =128, help = "Batch size.")
flags.DEFINE_integer("eval_freq", default = 400, help =" Frequency at which to validate the model.")
flags.DEFINE_float("kernel_posterior_scale_mean", default = -0.9, help = "Initial kernel posterior mean of the scale (log var) for q(w)")
flags.DEFINE_float("kernel_posterior_scale_constraint", default = 0.2, help = "Posterior kernel constraint for the scale (log var) for q(w)")
flags.DEFINE_float("kl_annealing", default = 50, help = "Epochs to anneal the KL term (anneals from 0 to 1)")
flags.DEFINE_integer("num_hidden_layers", default = 4, help = "Number of hidden layers")
flags.DEFINE_integer("num_monte_carlo",

                     default=50,

                     help="Network draws to compute predictive probabilities.")
tf.app.flags.DEFINE_string('f', '', 'kernel')
#initialize flags 
#FLAGS = flags.FLAGS
print(FLAGS.learning_rate)
print(FLAGS.epochs)
print(FLAGS.num_monte_carlo)
# Out:
# 0.0001
# 700
# 50

# %%
def build_input_pipeline(X_train,X_test,y_train, y_test, batch_size, valid_size):
  #Build an iterator over training batches 
  training_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
  #Shuffle the dataset (note shuffle argument much larger than training size)
  # and form batches of size batch_size
  training_batches = training_dataset.shuffle(20000, reshuffle_each_iteration =True).repeat().batch(batch_size)
  training_iterator = tf.data.make_one_shot_iterator(training_batches)
  
  #Building iterator over the heldout set with batch_size = heldout_size,
  # i.e., return the entire heldout set as a constant.
  heldout_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test))
  heldout_batches = heldout_dataset.repeat().batch(valid_size)
  heldout_iterator = tf.data.make_one_shot_iterator(heldout_batches)
  
  #Combine these into a feasible iterator that can switch between training 
  # and validation inputs.
  # Here should be minibatch increment be defined 
  handle = tf.placeholder(tf.string, shape = [])
  feedable_iterator = tf.data.Iterator.from_string_handle(handle, training_batches.output_types, training_batches.output_shapes)
  features_final, labels_final = feedable_iterator.get_next()
  
  return features_final, labels_final, handle, training_iterator, heldout_iterator

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !ls "/content/gdrive/My Drive/"
# Out:
#  acc_1.csv   Bayesian_log_trial_.ipynb	 elvin.csv	   Untitled1.ipynb
#  acc_2.csv   BNN_Work.ipynb		 kernel.ipynb	   work2.csv
#  acc_3.csv  'Colab Notebooks'		 preds_2.npy	   work_main
#  acc_4.csv   data1.csv			 preds_3.npy
#  acc_5.csv   data23.csv			 Untitled0.ipynb

# %%
# Read in the dataset
df = pd.read_csv('/content/gdrive/My Drive/work2.csv').astype(np.float32)
change = df.query('Speed>0').sample(frac = .1).index
df.loc[change, 'Speed'] = 0
df.loc[change, 'Class'] = 0
df.to_csv('work2.csv', header = True, index =False)
df.shape
# Out:
# (1048575, 20)

# %%
X = df.iloc[:,:-1].values
y = df.iloc[:,-1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state =1)

#reshape y-data to become column vector 
y_train = np.reshape(y_train, [-1,1])
y_test = np.reshape(y_test, [-1,1])

# %%
# Standardize the dataset 
scalar_x_train = StandardScaler().fit(X_train)
scalar_x_test = StandardScaler().fit(X_test)
X_train = scalar_x_train.transform(X_train)
X_test = scalar_x_test.transform(X_test)

# %%
def main(argv):
  (features_final, labels_final, handle, training_iterator, heldout_iterator) = build_input_pipeline(X_train,X_test, y_train,y_test, FLAGS.batch_size, 500)
  
  #features, labels = build_input_pipeline(X,y, FLAGS.batch_size)
  #Building Bayesian Logistic 
  with tf.name_scope("logistic_regression", values=[features_final]):
    layer = tfp.layers.DenseFlipout(
        units=1,
        activation= tf.nn.relu,
        kernel_posterior_fn=tfp.layers.default_mean_field_normal_fn(),
        bias_posterior_fn=tfp.layers.default_mean_field_normal_fn())
    logits = layer(features_final)
   # logits = layer(features)
    labels_distribution = tfd.Bernoulli(logits=logits)
 #Compute the -ELBO as the loss, averaged over the batch size 
    t = tf.Variable(0.0)
    kl_regularizer = t / (FLAGS.kl_annealing * len(X_train) / FLAGS.batch_size)
  
    #Compute the -ELBO as the loss. The kl term is annealed from 1 to 1 over 
    # the epochs specified by the kl_annealing flag.
    #log_likelihood = labels_distribution.log_prob(labels_final)
    #log_likelihood = labels_distribution.log_prob(labels)
   #neg_log_likelihood = tf.reduce_mean(tf.squared_difference(logits,labels_final))
    neg_log_likelihood = -tf.reduce_mean(input_tensor = labels_distribution.log_prob(labels_final))
    #neg_log_likelihood = -tf.reduce_mean(input_tensor = log_likelihood)
    
    kl = sum(layer.losses)/len(X_train) * tf.minimum(1.0, kl_regularizer)
    elbo_loss = neg_log_likelihood + kl
   
  """neg_log_likelihood = -tf.reduce_mean(labels_distribution.log_prob(features))
  kl = sum(layer.losses)/len(X_train)
  elbo_loss = neg_log_likelihood + kl """
  #Build metrics for evaluation. Predictions are formed from single forward 
  #pass of the probabilistic layers. They are cheap but noise predictions
  #predictions = tf.argmax(input = logits, axis=1)
  predictions = tf.cast(logits>0, dtype = tf.int32)
  #accuracy, accuracy_update_op = tf.metrics.accuracy(labels= labels_final,  predictions = predictions)
  
  with tf.name_scope("train"):
    train_accuracy, train_accuracy_update_op = tf.metrics.accuracy(labels= labels_final,  predictions = predictions)
    optimizer =tf.train.AdamOptimizer(learning_rate=FLAGS.learning_rate)
    train_op = optimizer.minimize(elbo_loss)
    update_step_op = tf.assign(t, t+1)
    #init_op = tf.group(tf.global_variables_initializer(), tf.local_variables_initializer())
  
  with tf.name_scope("valid"):
    valid_accuracy, validation_accuracy_update_op = tf.metrics.accuracy(labels = labels_final,predictions = predictions)
    init_op = tf.group(tf.global_variables_initializer(), 
                       tf.local_variables_initializer())
    stream_vars_valid = [v for v in tf.local_variables() if "valid" in v.name]
    reset_valid_op = tf.variables_initializer(stream_vars_valid)
    
    
    
  with tf.Session() as sess:
    
    sess.run(init_op)
    #Run the training looop
    # Fit the model to data.
    train_handle = sess.run(training_iterator.string_handle())
    heldout_handle = sess.run(heldout_iterator.string_handle())
    training_steps = int(round(FLAGS.epochs * (len(X_train) / FLAGS.batch_size)))
    for step in range(training_steps):
      _ = sess.run([train_op,train_accuracy_update_op, update_step_op],feed_dict={handle: train_handle})
      
      # Manually print the frequency 
      if step % 100 == 0:
        loss_value, accuracy_value, kl_value = sess.run([elbo_loss, train_accuracy, kl], feed_dict= {handle:train_handle})
        print("Step:{:>3d} loss : {:.3f} KL: {:.3f}" .format(step , loss_value, accuracy_value, kl_value))
        
      if (step +1) % FLAGS.eval_freq ==0: 
        # Compute log prob of heldout set by averaging draws from the model:
        # p(heldout | train) = int_model p(heldout|model) p(model|train) ~= 1/n * sum_{i=1}^n p(heldout | model_i)
        # where model_i is a draw from the posterior 
        #p(model|train)
        probs = np.asarray([sess.run((labels_distribution.probs), 
                                     feed_dict ={handle: heldout_handle})
      
                            for _ in range(FLAGS.num_monte_carlo)])
     
        mean_probs = np.mean(probs, axis =0).astype(np.int32)
        print(mean_probs.dtype)
        
        _, label_vals = sess.run((features_final, labels_final), feed_dict = {handle: heldout_handle})
        label_vals = (label_vals).astype(np.int32)
      
       # heldout_lp = np.mean(np.log(mean_probs[np.arange(mean_probs.shape[0]), label_vals]))
        
        
        #print(" ...Held_out nats: {:.3f}".format(heldout_lp))
        
       # Calculate validation accuracy

        for _ in range(20):

          sess.run(validation_accuracy_update_op, feed_dict={handle: heldout_handle})

        valid_value = sess.run(

            valid_accuracy, feed_dict={handle: heldout_handle})

        print(

            " ... Validation Accuracy: {:.3f}".format(valid_value))

        sess.run(reset_valid_op)
if __name__ == "__main__": 
  tf.app.run()
# Out:
# Step:  0 loss : 0.617 KL: 0.500
# Step:100 loss : 0.657 KL: 0.472
# Step:200 loss : 0.624 KL: 0.476
# Step:300 loss : 0.601 KL: 0.482
# int32
#  ... Validation Accuracy: 0.514
# Step:400 loss : 0.619 KL: 0.486
# Step:500 loss : 0.615 KL: 0.492
# Step:600 loss : 0.581 KL: 0.497
# Step:700 loss : 0.586 KL: 0.502
# int32
#  ... Validation Accuracy: 0.542
# Step:800 loss : 0.594 KL: 0.506
# Step:900 loss : 0.568 KL: 0.509
# Step:1000 loss : 0.568 KL: 0.513
# Step:1100 loss : 0.587 KL: 0.516
# int32
#  ... Validation Accuracy: 0.564
# Step:1200 loss : 0.561 KL: 0.520
# Step:1300 loss : 0.541 KL: 0.524
# Step:1400 loss : 0.576 KL: 0.527
# Step:1500 loss : 0.576 KL: 0.530
# int32
#  ... Validation Accuracy: 0.572
# Step:1600 loss : 0.532 KL: 0.533
# Step:1700 loss : 0.590 KL: 0.536
# Step:1800 loss : 0.552 KL: 0.539
# Step:1900 loss : 0.544 KL: 0.541
# int32
#  ... Validation Accuracy: 0.590
# Step:2000 loss : 0.543 KL: 0.544
# Step:2100 loss : 0.512 KL: 0.546
# Step:2200 loss : 0.525 KL: 0.548
# Step:2300 loss : 0.513 KL: 0.550
# int32
#  ... Validation Accuracy: 0.594
# Step:2400 loss : 0.504 KL: 0.552
# Step:2500 loss : 0.512 KL: 0.554
# Step:2600 loss : 0.499 KL: 0.555
# Step:2700 loss : 0.501 KL: 0.557
# int32
#  ... Validation Accuracy: 0.594
# Step:2800 loss : 0.507 KL: 0.559
# Step:2900 loss : 0.494 KL: 0.560
# Step:3000 loss : 0.489 KL: 0.561
# Step:3100 loss : 0.490 KL: 0.563
# int32
#  ... Validation Accuracy: 0.597
# Step:3200 loss : 0.469 KL: 0.564
# Step:3300 loss : 0.505 KL: 0.565
# Step:3400 loss : 0.448 KL: 0.567
# Step:3500 loss : 0.506 KL: 0.568
# int32
#  ... Validation Accuracy: 0.612
# Step:3600 loss : 0.496 KL: 0.569
# Step:3700 loss : 0.469 KL: 0.570
# Step:3800 loss : 0.474 KL: 0.571
# Step:3900 loss : 0.489 KL: 0.572
# int32
#  ... Validation Accuracy: 0.608
# Step:4000 loss : 0.453 KL: 0.573
# Step:4100 loss : 0.471 KL: 0.573
# Step:4200 loss : 0.422 KL: 0.574
# Step:4300 loss : 0.452 KL: 0.575
# int32
#  ... Validation Accuracy: 0.606
# Step:4400 loss : 0.456 KL: 0.576
# Step:4500 loss : 0.533 KL: 0.577
# Step:4600 loss : 0.446 KL: 0.578
# Step:4700 loss : 0.438 KL: 0.579
# int32
#  ... Validation Accuracy: 0.607
# Step:4800 loss : 0.444 KL: 0.580
# Step:4900 loss : 0.476 KL: 0.580
# Step:5000 loss : 0.400 KL: 0.581
# Step:5100 loss : 0.453 KL: 0.582
# int32
#  ... Validation Accuracy: 0.618
# Step:5200 loss : 0.411 KL: 0.583
# Step:5300 loss : 0.439 KL: 0.583
# Step:5400 loss : 0.435 KL: 0.584
# Step:5500 loss : 0.423 KL: 0.585
# int32
#  ... Validation Accuracy: 0.604
# Step:5600 loss : 0.448 KL: 0.585
# Step:5700 loss : 0.440 KL: 0.586
# Step:5800 loss : 0.425 KL: 0.587
# Step:5900 loss : 0.455 KL: 0.587
# int32
#  ... Validation Accuracy: 0.621
# Step:6000 loss : 0.427 KL: 0.588
# Step:6100 loss : 0.452 KL: 0.589
# Step:6200 loss : 0.441 KL: 0.589
# Step:6300 loss : 0.405 KL: 0.590
# int32
#  ... Validation Accuracy: 0.628
# Step:6400 loss : 0.463 KL: 0.591
# Step:6500 loss : 0.434 KL: 0.591
# Step:6600 loss : 0.412 KL: 0.592
# Step:6700 loss : 0.406 KL: 0.592
# int32
#  ... Validation Accuracy: 0.630
# Step:6800 loss : 0.423 KL: 0.593
# Step:6900 loss : 0.398 KL: 0.594
# Step:7000 loss : 0.404 KL: 0.594
# Step:7100 loss : 0.417 KL: 0.595
# int32
#  ... Validation Accuracy: 0.633
# Step:7200 loss : 0.442 KL: 0.595
# Step:7300 loss : 0.435 KL: 0.596
# Step:7400 loss : 0.400 KL: 0.597
# Step:7500 loss : 0.459 KL: 0.597
# int32
#  ... Validation Accuracy: 0.645
# Step:7600 loss : 0.404 KL: 0.598
# Step:7700 loss : 0.434 KL: 0.599
# Step:7800 loss : 0.454 KL: 0.599
# Step:7900 loss : 0.389 KL: 0.600
# int32
#  ... Validation Accuracy: 0.634
# Step:8000 loss : 0.384 KL: 0.601
# Step:8100 loss : 0.396 KL: 0.601
# Step:8200 loss : 0.360 KL: 0.602
# Step:8300 loss : 0.369 KL: 0.603
# int32
#  ... Validation Accuracy: 0.656
# Step:8400 loss : 0.353 KL: 0.603
# Step:8500 loss : 0.404 KL: 0.604
# Step:8600 loss : 0.387 KL: 0.605
# Step:8700 loss : 0.406 KL: 0.605
# int32
#  ... Validation Accuracy: 0.659
# Step:8800 loss : 0.410 KL: 0.606
# Step:8900 loss : 0.391 KL: 0.607
# Step:9000 loss : 0.374 KL: 0.607
# Step:9100 loss : 0.340 KL: 0.608
# int32
#  ... Validation Accuracy: 0.661
# Step:9200 loss : 0.403 KL: 0.609
# Step:9300 loss : 0.398 KL: 0.609
# Step:9400 loss : 0.388 KL: 0.610
# Step:9500 loss : 0.368 KL: 0.611
# int32
#  ... Validation Accuracy: 0.670
# Step:9600 loss : 0.384 KL: 0.612
# Step:9700 loss : 0.393 KL: 0.612
# Step:9800 loss : 0.362 KL: 0.613
# Step:9900 loss : 0.373 KL: 0.614
# int32
#  ... Validation Accuracy: 0.680
# Step:10000 loss : 0.365 KL: 0.614
# Step:10100 loss : 0.384 KL: 0.615
# Step:10200 loss : 0.375 KL: 0.616
# Step:10300 loss : 0.367 KL: 0.617
# int32
#  ... Validation Accuracy: 0.682
# Step:10400 loss : 0.392 KL: 0.617
# Step:10500 loss : 0.359 KL: 0.618
# Step:10600 loss : 0.394 KL: 0.619
# Step:10700 loss : 0.415 KL: 0.620
# int32
#  ... Validation Accuracy: 0.700
# Step:10800 loss : 0.401 KL: 0.620
# Step:10900 loss : 0.395 KL: 0.621
# Step:11000 loss : 0.364 KL: 0.622
# Step:11100 loss : 0.381 KL: 0.623
# int32
#  ... Validation Accuracy: 0.707
# Step:11200 loss : 0.300 KL: 0.624
# Step:11300 loss : 0.347 KL: 0.624
# Step:11400 loss : 0.325 KL: 0.625
# Step:11500 loss : 0.330 KL: 0.626
# int32
#  ... Validation Accuracy: 0.713
# Step:11600 loss : 0.380 KL: 0.627
# Step:11700 loss : 0.335 KL: 0.628
# Step:11800 loss : 0.357 KL: 0.628
# Step:11900 loss : 0.314 KL: 0.629
# int32
#  ... Validation Accuracy: 0.725
# Step:12000 loss : 0.301 KL: 0.630
# Step:12100 loss : 0.417 KL: 0.631
# Step:12200 loss : 0.326 KL: 0.632
# Step:12300 loss : 0.346 KL: 0.632
# int32
#  ... Validation Accuracy: 0.736
# Step:12400 loss : 0.318 KL: 0.633
# Step:12500 loss : 0.342 KL: 0.634
# Step:12600 loss : 0.343 KL: 0.635
# Step:12700 loss : 0.329 KL: 0.636
# int32
#  ... Validation Accuracy: 0.738
# Step:12800 loss : 0.360 KL: 0.637
# Step:12900 loss : 0.338 KL: 0.638
# Step:13000 loss : 0.303 KL: 0.638
# Step:13100 loss : 0.301 KL: 0.639
# int32
#  ... Validation Accuracy: 0.747
# Step:13200 loss : 0.328 KL: 0.640
# Step:13300 loss : 0.265 KL: 0.641
# Step:13400 loss : 0.306 KL: 0.642
# Step:13500 loss : 0.348 KL: 0.643
# int32
#  ... Validation Accuracy: 0.758
# Step:13600 loss : 0.328 KL: 0.644
# Step:13700 loss : 0.302 KL: 0.644
# Step:13800 loss : 0.293 KL: 0.645
# Step:13900 loss : 0.303 KL: 0.646
# int32
#  ... Validation Accuracy: 0.770
# Step:14000 loss : 0.310 KL: 0.647
# Step:14100 loss : 0.288 KL: 0.648
# Step:14200 loss : 0.266 KL: 0.649
# Step:14300 loss : 0.315 KL: 0.650
# int32
#  ... Validation Accuracy: 0.783
# Step:14400 loss : 0.313 KL: 0.651
# Step:14500 loss : 0.334 KL: 0.652
# Step:14600 loss : 0.290 KL: 0.653
# Step:14700 loss : 0.333 KL: 0.653
# int32
#  ... Validation Accuracy: 0.790
# Step:14800 loss : 0.283 KL: 0.654
# Step:14900 loss : 0.363 KL: 0.655
# Step:15000 loss : 0.305 KL: 0.656
# Step:15100 loss : 0.348 KL: 0.657
# int32
#  ... Validation Accuracy: 0.795
# Step:15200 loss : 0.236 KL: 0.658
# Step:15300 loss : 0.393 KL: 0.659
# Step:15400 loss : 0.260 KL: 0.660
# Step:15500 loss : 0.297 KL: 0.661
# int32
#  ... Validation Accuracy: 0.794
# Step:15600 loss : 0.280 KL: 0.661
# Step:15700 loss : 0.335 KL: 0.662
# Step:15800 loss : 0.305 KL: 0.663
# Step:15900 loss : 0.361 KL: 0.664
# int32
#  ... Validation Accuracy: 0.804
# Step:16000 loss : 0.277 KL: 0.665
# Step:16100 loss : 0.338 KL: 0.666
# Step:16200 loss : 0.292 KL: 0.667
# Step:16300 loss : 0.306 KL: 0.668
# int32
#  ... Validation Accuracy: 0.808
# Step:16400 loss : 0.310 KL: 0.668
# Step:16500 loss : 0.268 KL: 0.669
# Step:16600 loss : 0.312 KL: 0.670
# Step:16700 loss : 0.326 KL: 0.671
# int32
#  ... Validation Accuracy: 0.818
# Step:16800 loss : 0.252 KL: 0.672
# Step:16900 loss : 0.284 KL: 0.673
# Step:17000 loss : 0.298 KL: 0.673
# Step:17100 loss : 0.259 KL: 0.674
# int32
#  ... Validation Accuracy: 0.816
# Step:17200 loss : 0.218 KL: 0.675
# Step:17300 loss : 0.348 KL: 0.676
# Step:17400 loss : 0.287 KL: 0.677
# Step:17500 loss : 0.273 KL: 0.677
# int32
#  ... Validation Accuracy: 0.821
# Step:17600 loss : 0.262 KL: 0.678
# Step:17700 loss : 0.285 KL: 0.679
# Step:17800 loss : 0.283 KL: 0.680
# Step:17900 loss : 0.266 KL: 0.681
# int32
#  ... Validation Accuracy: 0.819
# Step:18000 loss : 0.302 KL: 0.681
# Step:18100 loss : 0.290 KL: 0.682
# Step:18200 loss : 0.301 KL: 0.683
# Step:18300 loss : 0.247 KL: 0.684
# int32
#  ... Validation Accuracy: 0.826
# Step:18400 loss : 0.280 KL: 0.685
# Step:18500 loss : 0.306 KL: 0.685
# Step:18600 loss : 0.252 KL: 0.686
# Step:18700 loss : 0.283 KL: 0.687
# int32
#  ... Validation Accuracy: 0.831
# Step:18800 loss : 0.262 KL: 0.687
# Step:18900 loss : 0.269 KL: 0.688
# Step:19000 loss : 0.267 KL: 0.689
# Step:19100 loss : 0.278 KL: 0.690
# int32
#  ... Validation Accuracy: 0.822
# Step:19200 loss : 0.270 KL: 0.690
# Step:19300 loss : 0.287 KL: 0.691
# Step:19400 loss : 0.278 KL: 0.692
# Step:19500 loss : 0.242 KL: 0.693
# int32
#  ... Validation Accuracy: 0.832
# Step:19600 loss : 0.257 KL: 0.693
# Step:19700 loss : 0.227 KL: 0.694
# Step:19800 loss : 0.249 KL: 0.695
# Step:19900 loss : 0.268 KL: 0.695
# int32
#  ... Validation Accuracy: 0.833
# Step:20000 loss : 0.234 KL: 0.696
# Step:20100 loss : 0.265 KL: 0.697
# Step:20200 loss : 0.258 KL: 0.697
# Step:20300 loss : 0.277 KL: 0.698
# int32
#  ... Validation Accuracy: 0.833
# Step:20400 loss : 0.274 KL: 0.699
# Step:20500 loss : 0.209 KL: 0.699
# Step:20600 loss : 0.295 KL: 0.700
# Step:20700 loss : 0.240 KL: 0.700
# int32
#  ... Validation Accuracy: 0.837
# Step:20800 loss : 0.253 KL: 0.701
# Step:20900 loss : 0.253 KL: 0.702
# Step:21000 loss : 0.275 KL: 0.702
# Step:21100 loss : 0.237 KL: 0.703
# int32
#  ... Validation Accuracy: 0.840
# Step:21200 loss : 0.267 KL: 0.704
# Step:21300 loss : 0.249 KL: 0.704
# Step:21400 loss : 0.232 KL: 0.705
# Step:21500 loss : 0.246 KL: 0.705
# int32
#  ... Validation Accuracy: 0.836
# Step:21600 loss : 0.288 KL: 0.706
# Step:21700 loss : 0.238 KL: 0.707
# Step:21800 loss : 0.212 KL: 0.707
# Step:21900 loss : 0.283 KL: 0.708
# int32
#  ... Validation Accuracy: 0.842
# Step:22000 loss : 0.207 KL: 0.708
# Step:22100 loss : 0.226 KL: 0.709
# Step:22200 loss : 0.254 KL: 0.710
# Step:22300 loss : 0.227 KL: 0.710
# int32
#  ... Validation Accuracy: 0.847
# Step:22400 loss : 0.246 KL: 0.711
# Step:22500 loss : 0.220 KL: 0.711
# Step:22600 loss : 0.271 KL: 0.712
# Step:22700 loss : 0.231 KL: 0.713
# int32
#  ... Validation Accuracy: 0.858
# Step:22800 loss : 0.235 KL: 0.713
# Step:22900 loss : 0.258 KL: 0.714
# Step:23000 loss : 0.205 KL: 0.714
# Step:23100 loss : 0.237 KL: 0.715
# int32
#  ... Validation Accuracy: 0.865
# Step:23200 loss : 0.195 KL: 0.716
# Step:23300 loss : 0.188 KL: 0.716
# Step:23400 loss : 0.190 KL: 0.717
# Step:23500 loss : 0.228 KL: 0.718
# int32
#  ... Validation Accuracy: 0.877
# Step:23600 loss : 0.269 KL: 0.718
# Step:23700 loss : 0.217 KL: 0.719
# Step:23800 loss : 0.208 KL: 0.720
# Step:23900 loss : 0.208 KL: 0.720
# int32
#  ... Validation Accuracy: 0.891
# Step:24000 loss : 0.223 KL: 0.721
# Step:24100 loss : 0.210 KL: 0.722
# Step:24200 loss : 0.246 KL: 0.722
# Step:24300 loss : 0.218 KL: 0.723
# int32
#  ... Validation Accuracy: 0.904
# Step:24400 loss : 0.243 KL: 0.724
# Step:24500 loss : 0.235 KL: 0.724
# Step:24600 loss : 0.163 KL: 0.725
# Step:24700 loss : 0.241 KL: 0.726
# int32
#  ... Validation Accuracy: 0.909
# Step:24800 loss : 0.262 KL: 0.727
# Step:24900 loss : 0.199 KL: 0.727
# Step:25000 loss : 0.190 KL: 0.728
# Step:25100 loss : 0.203 KL: 0.729
# int32
#  ... Validation Accuracy: 0.926
# Step:25200 loss : 0.169 KL: 0.730
# Step:25300 loss : 0.201 KL: 0.730
# Step:25400 loss : 0.218 KL: 0.731
# Step:25500 loss : 0.208 KL: 0.732
# int32
#  ... Validation Accuracy: 0.937
# Step:25600 loss : 0.226 KL: 0.733
# Step:25700 loss : 0.182 KL: 0.734
# Step:25800 loss : 0.233 KL: 0.734
# Step:25900 loss : 0.209 KL: 0.735
# int32
#  ... Validation Accuracy: 0.938
# Step:26000 loss : 0.155 KL: 0.736
# Step:26100 loss : 0.191 KL: 0.737
# Step:26200 loss : 0.153 KL: 0.738
# Step:26300 loss : 0.181 KL: 0.738
# int32
#  ... Validation Accuracy: 0.943
# Step:26400 loss : 0.237 KL: 0.739
# Step:26500 loss : 0.182 KL: 0.740
# Step:26600 loss : 0.196 KL: 0.741
# Step:26700 loss : 0.167 KL: 0.741
# int32
#  ... Validation Accuracy: 0.938
# Step:26800 loss : 0.172 KL: 0.742
# Step:26900 loss : 0.195 KL: 0.743
# Step:27000 loss : 0.232 KL: 0.744
# Step:27100 loss : 0.183 KL: 0.744
# int32
#  ... Validation Accuracy: 0.935
# Step:27200 loss : 0.139 KL: 0.745
# Step:27300 loss : 0.175 KL: 0.746
# Step:27400 loss : 0.188 KL: 0.747
# Step:27500 loss : 0.183 KL: 0.747
# int32
#  ... Validation Accuracy: 0.943
# Step:27600 loss : 0.203 KL: 0.748
# Step:27700 loss : 0.199 KL: 0.749
# Step:27800 loss : 0.168 KL: 0.749
# Step:27900 loss : 0.146 KL: 0.750
# int32
#  ... Validation Accuracy: 0.942
# Step:28000 loss : 0.182 KL: 0.751
# Step:28100 loss : 0.169 KL: 0.751
# Step:28200 loss : 0.143 KL: 0.752
# Step:28300 loss : 0.222 KL: 0.753
# int32
#  ... Validation Accuracy: 0.938
# Step:28400 loss : 0.147 KL: 0.753
# Step:28500 loss : 0.178 KL: 0.754
# Step:28600 loss : 0.196 KL: 0.755
# Step:28700 loss : 0.205 KL: 0.755
# int32
#  ... Validation Accuracy: 0.941
# Step:28800 loss : 0.136 KL: 0.756
# Step:28900 loss : 0.174 KL: 0.757
# Step:29000 loss : 0.144 KL: 0.757
# Step:29100 loss : 0.169 KL: 0.758
# int32
#  ... Validation Accuracy: 0.938
# Step:29200 loss : 0.124 KL: 0.759
# Step:29300 loss : 0.201 KL: 0.759
# Step:29400 loss : 0.212 KL: 0.760
# Step:29500 loss : 0.185 KL: 0.760
# int32
#  ... Validation Accuracy: 0.941
# Step:29600 loss : 0.139 KL: 0.761
# Step:29700 loss : 0.151 KL: 0.762
# Step:29800 loss : 0.182 KL: 0.762
# Step:29900 loss : 0.119 KL: 0.763
# int32
#  ... Validation Accuracy: 0.940
# Step:30000 loss : 0.185 KL: 0.763
# Step:30100 loss : 0.154 KL: 0.764
# Step:30200 loss : 0.193 KL: 0.765
# Step:30300 loss : 0.161 KL: 0.765
# int32
#  ... Validation Accuracy: 0.946
# Step:30400 loss : 0.139 KL: 0.766
# Step:30500 loss : 0.160 KL: 0.766
# Step:30600 loss : 0.191 KL: 0.767
# Step:30700 loss : 0.198 KL: 0.768
# int32
#  ... Validation Accuracy: 0.943
# Step:30800 loss : 0.150 KL: 0.768
# Step:30900 loss : 0.153 KL: 0.769
# Step:31000 loss : 0.126 KL: 0.769
# Step:31100 loss : 0.129 KL: 0.770
# int32
#  ... Validation Accuracy: 0.944
# Step:31200 loss : 0.134 KL: 0.770
# Step:31300 loss : 0.159 KL: 0.771
# Step:31400 loss : 0.122 KL: 0.772
# Step:31500 loss : 0.154 KL: 0.772
# int32
#  ... Validation Accuracy: 0.943
# Step:31600 loss : 0.186 KL: 0.773
# Step:31700 loss : 0.139 KL: 0.773
# Step:31800 loss : 0.244 KL: 0.774
# Step:31900 loss : 0.121 KL: 0.774
# int32
#  ... Validation Accuracy: 0.945
# Step:32000 loss : 0.127 KL: 0.775
# Step:32100 loss : 0.138 KL: 0.775
# Step:32200 loss : 0.127 KL: 0.776
# Step:32300 loss : 0.168 KL: 0.776
# int32
#  ... Validation Accuracy: 0.945
# Step:32400 loss : 0.180 KL: 0.777
# Step:32500 loss : 0.147 KL: 0.777
# Step:32600 loss : 0.168 KL: 0.778
# Step:32700 loss : 0.181 KL: 0.778
# int32
#  ... Validation Accuracy: 0.950
# Step:32800 loss : 0.160 KL: 0.779
# Step:32900 loss : 0.155 KL: 0.779
# Step:33000 loss : 0.103 KL: 0.780
# Step:33100 loss : 0.123 KL: 0.780
# int32
#  ... Validation Accuracy: 0.948
# Step:33200 loss : 0.173 KL: 0.781
# Step:33300 loss : 0.165 KL: 0.781
# Step:33400 loss : 0.124 KL: 0.782
# Step:33500 loss : 0.142 KL: 0.782
# int32
#  ... Validation Accuracy: 0.947
# Step:33600 loss : 0.117 KL: 0.783
# Step:33700 loss : 0.163 KL: 0.783
# Step:33800 loss : 0.181 KL: 0.784
# Step:33900 loss : 0.128 KL: 0.784
# int32
#  ... Validation Accuracy: 0.946
# Step:34000 loss : 0.118 KL: 0.785
# Step:34100 loss : 0.152 KL: 0.785
# Step:34200 loss : 0.116 KL: 0.786
# Step:34300 loss : 0.186 KL: 0.786
# int32
#  ... Validation Accuracy: 0.951
# Step:34400 loss : 0.114 KL: 0.787
# Step:34500 loss : 0.176 KL: 0.787
# Step:34600 loss : 0.129 KL: 0.788
# Step:34700 loss : 0.152 KL: 0.788
# int32
#  ... Validation Accuracy: 0.948
# Step:34800 loss : 0.116 KL: 0.789
# Step:34900 loss : 0.168 KL: 0.789
# Step:35000 loss : 0.129 KL: 0.790
# Step:35100 loss : 0.134 KL: 0.790
# int32
#  ... Validation Accuracy: 0.953
# Step:35200 loss : 0.122 KL: 0.790
# Step:35300 loss : 0.142 KL: 0.791
# Step:35400 loss : 0.145 KL: 0.791
# Step:35500 loss : 0.134 KL: 0.792
# int32
#  ... Validation Accuracy: 0.954
# Step:35600 loss : 0.141 KL: 0.792
# Step:35700 loss : 0.115 KL: 0.793
# Step:35800 loss : 0.126 KL: 0.793
# Step:35900 loss : 0.082 KL: 0.794
# int32
#  ... Validation Accuracy: 0.948
# Step:36000 loss : 0.130 KL: 0.794
# Step:36100 loss : 0.118 KL: 0.794
# Step:36200 loss : 0.104 KL: 0.795
# Step:36300 loss : 0.112 KL: 0.795
# int32
#  ... Validation Accuracy: 0.951
# Step:36400 loss : 0.185 KL: 0.796
# Step:36500 loss : 0.134 KL: 0.796
# Step:36600 loss : 0.123 KL: 0.797
# Step:36700 loss : 0.161 KL: 0.797
# int32
#  ... Validation Accuracy: 0.953
# Step:36800 loss : 0.084 KL: 0.797
# Step:36900 loss : 0.099 KL: 0.798
# Step:37000 loss : 0.162 KL: 0.798
# Step:37100 loss : 0.149 KL: 0.799
# int32
#  ... Validation Accuracy: 0.952
# Step:37200 loss : 0.139 KL: 0.799
# Step:37300 loss : 0.168 KL: 0.799
# Step:37400 loss : 0.189 KL: 0.800
# Step:37500 loss : 0.105 KL: 0.800
# int32
#  ... Validation Accuracy: 0.956
# Step:37600 loss : 0.133 KL: 0.801
# Step:37700 loss : 0.100 KL: 0.801
# Step:37800 loss : 0.151 KL: 0.802
# Step:37900 loss : 0.192 KL: 0.802
# int32
#  ... Validation Accuracy: 0.960
# Step:38000 loss : 0.164 KL: 0.802
# Step:38100 loss : 0.199 KL: 0.803
# Step:38200 loss : 0.104 KL: 0.803
# Step:38300 loss : 0.180 KL: 0.804
# int32
#  ... Validation Accuracy: 0.952
# Step:38400 loss : 0.135 KL: 0.804
# Step:38500 loss : 0.117 KL: 0.804
# Step:38600 loss : 0.146 KL: 0.805
# Step:38700 loss : 0.140 KL: 0.805
# int32
#  ... Validation Accuracy: 0.953
# Step:38800 loss : 0.137 KL: 0.805
# Step:38900 loss : 0.100 KL: 0.806
# Step:39000 loss : 0.134 KL: 0.806
# Step:39100 loss : 0.099 KL: 0.807
# int32
#  ... Validation Accuracy: 0.954
# Step:39200 loss : 0.098 KL: 0.807
# Step:39300 loss : 0.168 KL: 0.807
# Step:39400 loss : 0.138 KL: 0.808
# Step:39500 loss : 0.080 KL: 0.808
# int32
#  ... Validation Accuracy: 0.955
# Step:39600 loss : 0.133 KL: 0.808
# Step:39700 loss : 0.216 KL: 0.809
# Step:39800 loss : 0.098 KL: 0.809
# Step:39900 loss : 0.112 KL: 0.810
# int32
#  ... Validation Accuracy: 0.957
# Step:40000 loss : 0.130 KL: 0.810
# Step:40100 loss : 0.170 KL: 0.810
# Step:40200 loss : 0.105 KL: 0.811
# Step:40300 loss : 0.098 KL: 0.811
# int32
#  ... Validation Accuracy: 0.959
# Step:40400 loss : 0.124 KL: 0.811
# Step:40500 loss : 0.125 KL: 0.812
# Step:40600 loss : 0.117 KL: 0.812
# Step:40700 loss : 0.118 KL: 0.812
# int32
#  ... Validation Accuracy: 0.955
# Step:40800 loss : 0.093 KL: 0.813
# Step:40900 loss : 0.107 KL: 0.813
# Step:41000 loss : 0.132 KL: 0.814
# Step:41100 loss : 0.148 KL: 0.814
# int32
#  ... Validation Accuracy: 0.958
# Step:41200 loss : 0.163 KL: 0.814
# Step:41300 loss : 0.129 KL: 0.815
# Step:41400 loss : 0.132 KL: 0.815
# Step:41500 loss : 0.114 KL: 0.815
# int32
#  ... Validation Accuracy: 0.958
# Step:41600 loss : 0.114 KL: 0.816
# Step:41700 loss : 0.130 KL: 0.816
# Step:41800 loss : 0.131 KL: 0.816
# Step:41900 loss : 0.085 KL: 0.817
# int32
#  ... Validation Accuracy: 0.960
# Step:42000 loss : 0.109 KL: 0.817
# Step:42100 loss : 0.081 KL: 0.817
# Step:42200 loss : 0.092 KL: 0.818
# Step:42300 loss : 0.115 KL: 0.818
# int32
#  ... Validation Accuracy: 0.959
# Step:42400 loss : 0.147 KL: 0.818
# Step:42500 loss : 0.137 KL: 0.819
# Step:42600 loss : 0.106 KL: 0.819
# Step:42700 loss : 0.110 KL: 0.819
# int32
#  ... Validation Accuracy: 0.960
# Step:42800 loss : 0.168 KL: 0.820
# Step:42900 loss : 0.109 KL: 0.820
# Step:43000 loss : 0.132 KL: 0.820
# Step:43100 loss : 0.156 KL: 0.821
# int32
#  ... Validation Accuracy: 0.956
# Step:43200 loss : 0.084 KL: 0.821
# Step:43300 loss : 0.113 KL: 0.821
# Step:43400 loss : 0.104 KL: 0.821
# Step:43500 loss : 0.116 KL: 0.822
# int32
#  ... Validation Accuracy: 0.960
# Step:43600 loss : 0.116 KL: 0.822
# Step:43700 loss : 0.102 KL: 0.822
# Step:43800 loss : 0.098 KL: 0.823
# Step:43900 loss : 0.174 KL: 0.823
# int32
#  ... Validation Accuracy: 0.958
# Step:44000 loss : 0.109 KL: 0.823
# Step:44100 loss : 0.107 KL: 0.824
# Step:44200 loss : 0.125 KL: 0.824
# Step:44300 loss : 0.137 KL: 0.824
# int32
#  ... Validation Accuracy: 0.961
# Step:44400 loss : 0.146 KL: 0.825
# Step:44500 loss : 0.112 KL: 0.825
# Step:44600 loss : 0.117 KL: 0.825
# Step:44700 loss : 0.129 KL: 0.825
# int32
#  ... Validation Accuracy: 0.960
# Step:44800 loss : 0.163 KL: 0.826
# Step:44900 loss : 0.126 KL: 0.826
# Step:45000 loss : 0.144 KL: 0.826
# Step:45100 loss : 0.115 KL: 0.827
# int32
#  ... Validation Accuracy: 0.959
# Step:45200 loss : 0.125 KL: 0.827
# Step:45300 loss : 0.075 KL: 0.827
# Step:45400 loss : 0.161 KL: 0.828
# Step:45500 loss : 0.121 KL: 0.828
# int32
#  ... Validation Accuracy: 0.957
# Step:45600 loss : 0.162 KL: 0.828
# Step:45700 loss : 0.113 KL: 0.828
# Step:45800 loss : 0.149 KL: 0.829
# Step:45900 loss : 0.179 KL: 0.829
# int32
#  ... Validation Accuracy: 0.963
# Step:46000 loss : 0.154 KL: 0.829
# Step:46100 loss : 0.134 KL: 0.830
# Step:46200 loss : 0.144 KL: 0.830
# Step:46300 loss : 0.111 KL: 0.830
# int32
#  ... Validation Accuracy: 0.957
# Step:46400 loss : 0.136 KL: 0.830
# Step:46500 loss : 0.188 KL: 0.831
# Step:46600 loss : 0.120 KL: 0.831
# Step:46700 loss : 0.108 KL: 0.831
# int32
#  ... Validation Accuracy: 0.965
# Step:46800 loss : 0.141 KL: 0.831
# Step:46900 loss : 0.227 KL: 0.832
# Step:47000 loss : 0.093 KL: 0.832
# Step:47100 loss : 0.127 KL: 0.832
# int32
#  ... Validation Accuracy: 0.962
# Step:47200 loss : 0.096 KL: 0.833
# Step:47300 loss : 0.150 KL: 0.833
# Step:47400 loss : 0.157 KL: 0.833
# Step:47500 loss : 0.081 KL: 0.833
# int32
#  ... Validation Accuracy: 0.960
# Step:47600 loss : 0.115 KL: 0.834
# Step:47700 loss : 0.142 KL: 0.834
# Step:47800 loss : 0.121 KL: 0.834
# Step:47900 loss : 0.100 KL: 0.834
# int32
#  ... Validation Accuracy: 0.958
# Step:48000 loss : 0.119 KL: 0.835
# Step:48100 loss : 0.113 KL: 0.835
# Step:48200 loss : 0.127 KL: 0.835
# Step:48300 loss : 0.161 KL: 0.835
# int32
#  ... Validation Accuracy: 0.963
# Step:48400 loss : 0.108 KL: 0.836
# Step:48500 loss : 0.093 KL: 0.836
# Step:48600 loss : 0.064 KL: 0.836
# Step:48700 loss : 0.108 KL: 0.837
# int32
#  ... Validation Accuracy: 0.960
# Step:48800 loss : 0.172 KL: 0.837
# Step:48900 loss : 0.124 KL: 0.837
# Step:49000 loss : 0.178 KL: 0.837
# Step:49100 loss : 0.086 KL: 0.838
# int32
#  ... Validation Accuracy: 0.964
# Step:49200 loss : 0.131 KL: 0.838
# Step:49300 loss : 0.106 KL: 0.838
# Step:49400 loss : 0.112 KL: 0.838
# Step:49500 loss : 0.099 KL: 0.839
# int32
#  ... Validation Accuracy: 0.960
# Step:49600 loss : 0.119 KL: 0.839
# Step:49700 loss : 0.113 KL: 0.839
# Step:49800 loss : 0.128 KL: 0.839
# Step:49900 loss : 0.121 KL: 0.840
# int32
#  ... Validation Accuracy: 0.962
# Step:50000 loss : 0.174 KL: 0.840
# Step:50100 loss : 0.115 KL: 0.840
# Step:50200 loss : 0.155 KL: 0.840
# Step:50300 loss : 0.113 KL: 0.840
# int32
#  ... Validation Accuracy: 0.960
# Step:50400 loss : 0.076 KL: 0.841
# Step:50500 loss : 0.097 KL: 0.841
# Step:50600 loss : 0.100 KL: 0.841
# Step:50700 loss : 0.141 KL: 0.841
# int32
#  ... Validation Accuracy: 0.961
# Step:50800 loss : 0.110 KL: 0.842
# Step:50900 loss : 0.170 KL: 0.842
# Step:51000 loss : 0.159 KL: 0.842
# Step:51100 loss : 0.114 KL: 0.842
# int32
#  ... Validation Accuracy: 0.963
# Step:51200 loss : 0.148 KL: 0.843
# Step:51300 loss : 0.099 KL: 0.843
# Step:51400 loss : 0.080 KL: 0.843
# Step:51500 loss : 0.086 KL: 0.843
# int32
#  ... Validation Accuracy: 0.965
# Step:51600 loss : 0.149 KL: 0.844
# Step:51700 loss : 0.118 KL: 0.844
# Step:51800 loss : 0.087 KL: 0.844
# Step:51900 loss : 0.093 KL: 0.844
# int32
#  ... Validation Accuracy: 0.960
# Step:52000 loss : 0.112 KL: 0.844
# Step:52100 loss : 0.073 KL: 0.845
# Step:52200 loss : 0.100 KL: 0.845
# Step:52300 loss : 0.120 KL: 0.845
# int32
#  ... Validation Accuracy: 0.965
# Step:52400 loss : 0.118 KL: 0.845
# Step:52500 loss : 0.127 KL: 0.846
# Step:52600 loss : 0.103 KL: 0.846
# Step:52700 loss : 0.115 KL: 0.846
# int32
#  ... Validation Accuracy: 0.961
# Step:52800 loss : 0.150 KL: 0.846
# Step:52900 loss : 0.135 KL: 0.846
# Step:53000 loss : 0.132 KL: 0.847
# Step:53100 loss : 0.163 KL: 0.847
# int32
#  ... Validation Accuracy: 0.961
# Step:53200 loss : 0.115 KL: 0.847
# Step:53300 loss : 0.142 KL: 0.847
# Step:53400 loss : 0.146 KL: 0.848
# Step:53500 loss : 0.106 KL: 0.848
# int32
#  ... Validation Accuracy: 0.964
# Step:53600 loss : 0.143 KL: 0.848
# Step:53700 loss : 0.137 KL: 0.848
# Step:53800 loss : 0.130 KL: 0.848
# Step:53900 loss : 0.152 KL: 0.849
# int32
#  ... Validation Accuracy: 0.967
# Step:54000 loss : 0.129 KL: 0.849
# Step:54100 loss : 0.139 KL: 0.849
# Step:54200 loss : 0.168 KL: 0.849
# Step:54300 loss : 0.093 KL: 0.849
# int32
#  ... Validation Accuracy: 0.961
# Step:54400 loss : 0.150 KL: 0.850
# Step:54500 loss : 0.104 KL: 0.850
# Step:54600 loss : 0.105 KL: 0.850
# Step:54700 loss : 0.113 KL: 0.850
# int32
#  ... Validation Accuracy: 0.966
# Step:54800 loss : 0.155 KL: 0.851
# Step:54900 loss : 0.172 KL: 0.851
# Step:55000 loss : 0.139 KL: 0.851
# Step:55100 loss : 0.089 KL: 0.851
# int32
#  ... Validation Accuracy: 0.964
# Step:55200 loss : 0.095 KL: 0.851
# Step:55300 loss : 0.081 KL: 0.852
# Step:55400 loss : 0.156 KL: 0.852
# Step:55500 loss : 0.129 KL: 0.852
# int32
#  ... Validation Accuracy: 0.963
# Step:55600 loss : 0.086 KL: 0.852
# Step:55700 loss : 0.120 KL: 0.852
# Step:55800 loss : 0.115 KL: 0.853
# Step:55900 loss : 0.084 KL: 0.853
# int32
#  ... Validation Accuracy: 0.963
# Step:56000 loss : 0.052 KL: 0.853
# Step:56100 loss : 0.125 KL: 0.853
# Step:56200 loss : 0.158 KL: 0.853
# Step:56300 loss : 0.146 KL: 0.854
# int32
#  ... Validation Accuracy: 0.966
# Step:56400 loss : 0.095 KL: 0.854
# Step:56500 loss : 0.101 KL: 0.854
# Step:56600 loss : 0.059 KL: 0.854
# Step:56700 loss : 0.107 KL: 0.854
# int32
#  ... Validation Accuracy: 0.963
# Step:56800 loss : 0.128 KL: 0.855
# Step:56900 loss : 0.111 KL: 0.855
# Step:57000 loss : 0.117 KL: 0.855
# Step:57100 loss : 0.183 KL: 0.855
# int32
#  ... Validation Accuracy: 0.967
# Step:57200 loss : 0.103 KL: 0.855
# Step:57300 loss : 0.135 KL: 0.855
# Step:57400 loss : 0.114 KL: 0.856
# Step:57500 loss : 0.119 KL: 0.856
# int32
#  ... Validation Accuracy: 0.966
# Step:57600 loss : 0.123 KL: 0.856
# Step:57700 loss : 0.094 KL: 0.856
# Step:57800 loss : 0.143 KL: 0.856
# Step:57900 loss : 0.134 KL: 0.857
# int32
#  ... Validation Accuracy: 0.966
# Step:58000 loss : 0.115 KL: 0.857
# Step:58100 loss : 0.098 KL: 0.857
# Step:58200 loss : 0.151 KL: 0.857
# Step:58300 loss : 0.100 KL: 0.857
# int32
#  ... Validation Accuracy: 0.964
# Step:58400 loss : 0.132 KL: 0.858
# Step:58500 loss : 0.097 KL: 0.858
# Step:58600 loss : 0.144 KL: 0.858
# Step:58700 loss : 0.154 KL: 0.858
# int32
#  ... Validation Accuracy: 0.966
# Step:58800 loss : 0.119 KL: 0.858
# Step:58900 loss : 0.151 KL: 0.858
# Step:59000 loss : 0.126 KL: 0.859
# Step:59100 loss : 0.109 KL: 0.859
# int32
#  ... Validation Accuracy: 0.966
# Step:59200 loss : 0.079 KL: 0.859
# Step:59300 loss : 0.083 KL: 0.859
# Step:59400 loss : 0.086 KL: 0.859
# Step:59500 loss : 0.130 KL: 0.860
# int32
#  ... Validation Accuracy: 0.964
# Step:59600 loss : 0.128 KL: 0.860
# Step:59700 loss : 0.122 KL: 0.860
# Step:59800 loss : 0.090 KL: 0.860
# Step:59900 loss : 0.143 KL: 0.860
# int32
#  ... Validation Accuracy: 0.964
# Step:60000 loss : 0.090 KL: 0.860
# Step:60100 loss : 0.107 KL: 0.861
# Step:60200 loss : 0.129 KL: 0.861
# Step:60300 loss : 0.118 KL: 0.861
# int32
#  ... Validation Accuracy: 0.967
# Step:60400 loss : 0.113 KL: 0.861
# Step:60500 loss : 0.183 KL: 0.861
# Step:60600 loss : 0.110 KL: 0.861
# Step:60700 loss : 0.104 KL: 0.862
# int32
#  ... Validation Accuracy: 0.964
# Step:60800 loss : 0.160 KL: 0.862
# Step:60900 loss : 0.128 KL: 0.862
# Step:61000 loss : 0.082 KL: 0.862
# Step:61100 loss : 0.176 KL: 0.862
# int32
#  ... Validation Accuracy: 0.967
# Step:61200 loss : 0.155 KL: 0.862
# Step:61300 loss : 0.175 KL: 0.863
# Step:61400 loss : 0.103 KL: 0.863
# Step:61500 loss : 0.134 KL: 0.863
# int32
#  ... Validation Accuracy: 0.968
# Step:61600 loss : 0.088 KL: 0.863
# Step:61700 loss : 0.110 KL: 0.863
# Step:61800 loss : 0.115 KL: 0.863
# Step:61900 loss : 0.076 KL: 0.864
# int32
#  ... Validation Accuracy: 0.966
# Step:62000 loss : 0.109 KL: 0.864
# Step:62100 loss : 0.108 KL: 0.864
# Step:62200 loss : 0.096 KL: 0.864
# Step:62300 loss : 0.136 KL: 0.864
# int32
#  ... Validation Accuracy: 0.964
# Step:62400 loss : 0.110 KL: 0.864
# Step:62500 loss : 0.154 KL: 0.865
# Step:62600 loss : 0.090 KL: 0.865
# Step:62700 loss : 0.113 KL: 0.865
# int32
#  ... Validation Accuracy: 0.965
# Step:62800 loss : 0.118 KL: 0.865
# Step:62900 loss : 0.099 KL: 0.865
# Step:63000 loss : 0.109 KL: 0.865
# Step:63100 loss : 0.055 KL: 0.866
# int32
#  ... Validation Accuracy: 0.965
# Step:63200 loss : 0.154 KL: 0.866
# Step:63300 loss : 0.050 KL: 0.866
# Step:63400 loss : 0.102 KL: 0.866
# Step:63500 loss : 0.186 KL: 0.866
# int32
#  ... Validation Accuracy: 0.970
# Step:63600 loss : 0.101 KL: 0.866
# Step:63700 loss : 0.088 KL: 0.867
# Step:63800 loss : 0.104 KL: 0.867
# Step:63900 loss : 0.148 KL: 0.867
# int32
#  ... Validation Accuracy: 0.970
# Step:64000 loss : 0.157 KL: 0.867
# Step:64100 loss : 0.140 KL: 0.867
# Step:64200 loss : 0.130 KL: 0.867
# Step:64300 loss : 0.115 KL: 0.867
# int32
#  ... Validation Accuracy: 0.964
# Step:64400 loss : 0.140 KL: 0.868
# Step:64500 loss : 0.080 KL: 0.868
# Step:64600 loss : 0.100 KL: 0.868
# Step:64700 loss : 0.140 KL: 0.868
# int32
#  ... Validation Accuracy: 0.965
# Step:64800 loss : 0.120 KL: 0.868
# Step:64900 loss : 0.120 KL: 0.868
# Step:65000 loss : 0.126 KL: 0.869
# Step:65100 loss : 0.065 KL: 0.869
# int32
#  ... Validation Accuracy: 0.968
# Step:65200 loss : 0.121 KL: 0.869
# Step:65300 loss : 0.090 KL: 0.869
# Step:65400 loss : 0.126 KL: 0.869
# Step:65500 loss : 0.142 KL: 0.869
# int32
#  ... Validation Accuracy: 0.965
# Step:65600 loss : 0.104 KL: 0.869
# Step:65700 loss : 0.109 KL: 0.870
# Step:65800 loss : 0.120 KL: 0.870
# Step:65900 loss : 0.097 KL: 0.870
# int32
#  ... Validation Accuracy: 0.968
# Step:66000 loss : 0.077 KL: 0.870
# Step:66100 loss : 0.151 KL: 0.870
# Step:66200 loss : 0.115 KL: 0.870
# Step:66300 loss : 0.088 KL: 0.870
# int32
#  ... Validation Accuracy: 0.969
# Step:66400 loss : 0.182 KL: 0.871
# Step:66500 loss : 0.125 KL: 0.871
# Step:66600 loss : 0.103 KL: 0.871
# Step:66700 loss : 0.077 KL: 0.871
# int32
#  ... Validation Accuracy: 0.965
# Step:66800 loss : 0.128 KL: 0.871
# Step:66900 loss : 0.111 KL: 0.871
# Step:67000 loss : 0.156 KL: 0.871
# Step:67100 loss : 0.121 KL: 0.872
# int32
#  ... Validation Accuracy: 0.968
# Step:67200 loss : 0.117 KL: 0.872
# Step:67300 loss : 0.106 KL: 0.872
# Step:67400 loss : 0.131 KL: 0.872
# Step:67500 loss : 0.079 KL: 0.872
# int32
#  ... Validation Accuracy: 0.968
# Step:67600 loss : 0.104 KL: 0.872
# Step:67700 loss : 0.075 KL: 0.872
# Step:67800 loss : 0.109 KL: 0.873
# Step:67900 loss : 0.110 KL: 0.873
# int32
#  ... Validation Accuracy: 0.969
# Step:68000 loss : 0.089 KL: 0.873
# Step:68100 loss : 0.105 KL: 0.873
# Step:68200 loss : 0.093 KL: 0.873
# Step:68300 loss : 0.128 KL: 0.873
# int32
#  ... Validation Accuracy: 0.967
# Step:68400 loss : 0.113 KL: 0.873
# Step:68500 loss : 0.090 KL: 0.874
# Step:68600 loss : 0.090 KL: 0.874
# Step:68700 loss : 0.109 KL: 0.874
# int32
#  ... Validation Accuracy: 0.968
# Step:68800 loss : 0.107 KL: 0.874
# Step:68900 loss : 0.123 KL: 0.874
# Step:69000 loss : 0.112 KL: 0.874
# Step:69100 loss : 0.083 KL: 0.874
# int32
#  ... Validation Accuracy: 0.965
# Step:69200 loss : 0.057 KL: 0.874
# Step:69300 loss : 0.123 KL: 0.875
# Step:69400 loss : 0.136 KL: 0.875
# Step:69500 loss : 0.146 KL: 0.875
# int32
#  ... Validation Accuracy: 0.969
# Step:69600 loss : 0.073 KL: 0.875
# Step:69700 loss : 0.108 KL: 0.875
# Step:69800 loss : 0.095 KL: 0.875
# Step:69900 loss : 0.110 KL: 0.875
# int32
#  ... Validation Accuracy: 0.968
# Step:70000 loss : 0.083 KL: 0.876
# Step:70100 loss : 0.141 KL: 0.876
# Step:70200 loss : 0.077 KL: 0.876
# Step:70300 loss : 0.085 KL: 0.876
# int32
#  ... Validation Accuracy: 0.970
# Step:70400 loss : 0.143 KL: 0.876
# Step:70500 loss : 0.111 KL: 0.876
# Step:70600 loss : 0.141 KL: 0.876
# Step:70700 loss : 0.102 KL: 0.876
# int32
#  ... Validation Accuracy: 0.968
# Step:70800 loss : 0.130 KL: 0.877
# Step:70900 loss : 0.092 KL: 0.877
# Step:71000 loss : 0.139 KL: 0.877
# Step:71100 loss : 0.115 KL: 0.877
# int32
#  ... Validation Accuracy: 0.966
# Step:71200 loss : 0.114 KL: 0.877
# Step:71300 loss : 0.090 KL: 0.877
# Step:71400 loss : 0.117 KL: 0.877
# Step:71500 loss : 0.109 KL: 0.877
# int32
#  ... Validation Accuracy: 0.966
# Step:71600 loss : 0.089 KL: 0.878
# Step:71700 loss : 0.146 KL: 0.878
# Step:71800 loss : 0.129 KL: 0.878
# Step:71900 loss : 0.085 KL: 0.878
# int32
#  ... Validation Accuracy: 0.970
# Step:72000 loss : 0.101 KL: 0.878
# Step:72100 loss : 0.113 KL: 0.878
# Step:72200 loss : 0.158 KL: 0.878
# Step:72300 loss : 0.073 KL: 0.878
# int32
#  ... Validation Accuracy: 0.968
# Step:72400 loss : 0.141 KL: 0.879
# Step:72500 loss : 0.101 KL: 0.879
# Step:72600 loss : 0.089 KL: 0.879
# Step:72700 loss : 0.156 KL: 0.879
# int32
#  ... Validation Accuracy: 0.971
# Step:72800 loss : 0.125 KL: 0.879
# Step:72900 loss : 0.109 KL: 0.879
# Step:73000 loss : 0.149 KL: 0.879
# Step:73100 loss : 0.082 KL: 0.879
# int32
#  ... Validation Accuracy: 0.970
# Step:73200 loss : 0.076 KL: 0.880
# Step:73300 loss : 0.074 KL: 0.880
# Step:73400 loss : 0.081 KL: 0.880
# Step:73500 loss : 0.114 KL: 0.880
# int32
#  ... Validation Accuracy: 0.969
# Step:73600 loss : 0.104 KL: 0.880
# Step:73700 loss : 0.080 KL: 0.880
# Step:73800 loss : 0.102 KL: 0.880
# Step:73900 loss : 0.113 KL: 0.880
# int32
#  ... Validation Accuracy: 0.966
# Step:74000 loss : 0.081 KL: 0.881
# Step:74100 loss : 0.094 KL: 0.881
# Step:74200 loss : 0.081 KL: 0.881
# Step:74300 loss : 0.102 KL: 0.881
# int32
#  ... Validation Accuracy: 0.969
# Step:74400 loss : 0.109 KL: 0.881
# Step:74500 loss : 0.092 KL: 0.881
# Step:74600 loss : 0.111 KL: 0.881
# Step:74700 loss : 0.090 KL: 0.881
# int32
#  ... Validation Accuracy: 0.965
# Step:74800 loss : 0.131 KL: 0.881
# Step:74900 loss : 0.115 KL: 0.882
# Step:75000 loss : 0.093 KL: 0.882
# Step:75100 loss : 0.127 KL: 0.882
# int32
#  ... Validation Accuracy: 0.971
# Step:75200 loss : 0.111 KL: 0.882
# Step:75300 loss : 0.127 KL: 0.882
# Step:75400 loss : 0.078 KL: 0.882
# Step:75500 loss : 0.117 KL: 0.882
# int32
#  ... Validation Accuracy: 0.968
# Step:75600 loss : 0.100 KL: 0.882
# Step:75700 loss : 0.086 KL: 0.882
# Step:75800 loss : 0.092 KL: 0.883
# Step:75900 loss : 0.104 KL: 0.883
# int32
#  ... Validation Accuracy: 0.970
# Step:76000 loss : 0.102 KL: 0.883
# Step:76100 loss : 0.091 KL: 0.883
# Step:76200 loss : 0.122 KL: 0.883
# Step:76300 loss : 0.125 KL: 0.883
# int32
#  ... Validation Accuracy: 0.967
# Step:76400 loss : 0.139 KL: 0.883
# Step:76500 loss : 0.123 KL: 0.883
# Step:76600 loss : 0.119 KL: 0.883
# Step:76700 loss : 0.091 KL: 0.884
# int32
#  ... Validation Accuracy: 0.968
# Step:76800 loss : 0.081 KL: 0.884
# Step:76900 loss : 0.106 KL: 0.884
# Step:77000 loss : 0.073 KL: 0.884
# Step:77100 loss : 0.118 KL: 0.884
# int32
#  ... Validation Accuracy: 0.966
# Step:77200 loss : 0.055 KL: 0.884
# Step:77300 loss : 0.098 KL: 0.884
# Step:77400 loss : 0.065 KL: 0.884
# Step:77500 loss : 0.165 KL: 0.884
# int32
#  ... Validation Accuracy: 0.972
# Step:77600 loss : 0.123 KL: 0.885
# Step:77700 loss : 0.147 KL: 0.885
# Step:77800 loss : 0.061 KL: 0.885
# Step:77900 loss : 0.062 KL: 0.885
# int32
#  ... Validation Accuracy: 0.967
# Step:78000 loss : 0.108 KL: 0.885
# Step:78100 loss : 0.106 KL: 0.885
# Step:78200 loss : 0.115 KL: 0.885
# Step:78300 loss : 0.147 KL: 0.885
# int32
#  ... Validation Accuracy: 0.970
# Step:78400 loss : 0.139 KL: 0.885
# Step:78500 loss : 0.120 KL: 0.886
# Step:78600 loss : 0.156 KL: 0.886
# Step:78700 loss : 0.095 KL: 0.886
# int32
#  ... Validation Accuracy: 0.969
# Step:78800 loss : 0.158 KL: 0.886
# Step:78900 loss : 0.095 KL: 0.886
# Step:79000 loss : 0.106 KL: 0.886
# Step:79100 loss : 0.124 KL: 0.886
# int32
#  ... Validation Accuracy: 0.967
# Step:79200 loss : 0.091 KL: 0.886
# Step:79300 loss : 0.110 KL: 0.886
# Step:79400 loss : 0.078 KL: 0.886
# Step:79500 loss : 0.112 KL: 0.887
# int32
#  ... Validation Accuracy: 0.967
# Step:79600 loss : 0.154 KL: 0.887
# Step:79700 loss : 0.142 KL: 0.887
# Step:79800 loss : 0.097 KL: 0.887
# Step:79900 loss : 0.058 KL: 0.887
# int32
#  ... Validation Accuracy: 0.972
# Step:80000 loss : 0.149 KL: 0.887
# Step:80100 loss : 0.148 KL: 0.887
# Step:80200 loss : 0.087 KL: 0.887
# Step:80300 loss : 0.147 KL: 0.887
# int32
#  ... Validation Accuracy: 0.966
# Step:80400 loss : 0.097 KL: 0.888
# Step:80500 loss : 0.120 KL: 0.888
# Step:80600 loss : 0.096 KL: 0.888
# Step:80700 loss : 0.100 KL: 0.888
# int32
#  ... Validation Accuracy: 0.971
# Step:80800 loss : 0.127 KL: 0.888
# Step:80900 loss : 0.105 KL: 0.888
# Step:81000 loss : 0.104 KL: 0.888
# Step:81100 loss : 0.143 KL: 0.888
# int32
#  ... Validation Accuracy: 0.970
# Step:81200 loss : 0.087 KL: 0.888
# Step:81300 loss : 0.082 KL: 0.888
# Step:81400 loss : 0.097 KL: 0.889
# Step:81500 loss : 0.107 KL: 0.889
# int32
#  ... Validation Accuracy: 0.968
# Step:81600 loss : 0.097 KL: 0.889
# Step:81700 loss : 0.105 KL: 0.889
# Step:81800 loss : 0.112 KL: 0.889
# Step:81900 loss : 0.082 KL: 0.889
# int32
#  ... Validation Accuracy: 0.968
# Step:82000 loss : 0.088 KL: 0.889
# Step:82100 loss : 0.066 KL: 0.889
# Step:82200 loss : 0.156 KL: 0.889
# Step:82300 loss : 0.108 KL: 0.889
# int32
#  ... Validation Accuracy: 0.970
# Step:82400 loss : 0.079 KL: 0.889
# Step:82500 loss : 0.088 KL: 0.890
# Step:82600 loss : 0.104 KL: 0.890
# Step:82700 loss : 0.085 KL: 0.890
# int32
#  ... Validation Accuracy: 0.968
# Step:82800 loss : 0.098 KL: 0.890
# Step:82900 loss : 0.122 KL: 0.890
# Step:83000 loss : 0.136 KL: 0.890
# Step:83100 loss : 0.160 KL: 0.890
# int32
#  ... Validation Accuracy: 0.970
# Step:83200 loss : 0.108 KL: 0.890
# Step:83300 loss : 0.158 KL: 0.890
# Step:83400 loss : 0.113 KL: 0.890
# Step:83500 loss : 0.102 KL: 0.891
# int32
#  ... Validation Accuracy: 0.970
# Step:83600 loss : 0.134 KL: 0.891
# Step:83700 loss : 0.119 KL: 0.891
# Step:83800 loss : 0.090 KL: 0.891
# Step:83900 loss : 0.133 KL: 0.891
# int32
#  ... Validation Accuracy: 0.972
# Step:84000 loss : 0.092 KL: 0.891
# Step:84100 loss : 0.082 KL: 0.891
# Step:84200 loss : 0.103 KL: 0.891
# Step:84300 loss : 0.103 KL: 0.891
# int32
#  ... Validation Accuracy: 0.969
# Step:84400 loss : 0.079 KL: 0.891
# Step:84500 loss : 0.122 KL: 0.891
# Step:84600 loss : 0.114 KL: 0.892
# Step:84700 loss : 0.089 KL: 0.892
# int32
#  ... Validation Accuracy: 0.970
# Step:84800 loss : 0.101 KL: 0.892
# Step:84900 loss : 0.105 KL: 0.892
# Step:85000 loss : 0.074 KL: 0.892
# Step:85100 loss : 0.092 KL: 0.892
# int32
#  ... Validation Accuracy: 0.971
# Step:85200 loss : 0.097 KL: 0.892
# Step:85300 loss : 0.108 KL: 0.892
# Step:85400 loss : 0.114 KL: 0.892
# Step:85500 loss : 0.112 KL: 0.892
# int32
#  ... Validation Accuracy: 0.969
# Step:85600 loss : 0.100 KL: 0.892
# Step:85700 loss : 0.137 KL: 0.893
# Step:85800 loss : 0.140 KL: 0.893
# Step:85900 loss : 0.126 KL: 0.893
# int32
#  ... Validation Accuracy: 0.967
# Step:86000 loss : 0.130 KL: 0.893
# Step:86100 loss : 0.112 KL: 0.893
# Step:86200 loss : 0.112 KL: 0.893
# Step:86300 loss : 0.083 KL: 0.893
# int32
#  ... Validation Accuracy: 0.972
# Step:86400 loss : 0.118 KL: 0.893
# Step:86500 loss : 0.058 KL: 0.893
# Step:86600 loss : 0.121 KL: 0.893
# Step:86700 loss : 0.134 KL: 0.893
# int32
#  ... Validation Accuracy: 0.968
# Step:86800 loss : 0.155 KL: 0.894
# Step:86900 loss : 0.085 KL: 0.894
# Step:87000 loss : 0.083 KL: 0.894
# Step:87100 loss : 0.114 KL: 0.894
# int32
#  ... Validation Accuracy: 0.971
# Step:87200 loss : 0.085 KL: 0.894
# Step:87300 loss : 0.090 KL: 0.894
# Step:87400 loss : 0.103 KL: 0.894
# Step:87500 loss : 0.101 KL: 0.894
# int32
#  ... Validation Accuracy: 0.973
# Step:87600 loss : 0.114 KL: 0.894
# Step:87700 loss : 0.157 KL: 0.894
# Step:87800 loss : 0.160 KL: 0.894
# Step:87900 loss : 0.095 KL: 0.895
# int32
#  ... Validation Accuracy: 0.969
# Step:88000 loss : 0.091 KL: 0.895
# Step:88100 loss : 0.122 KL: 0.895
# Step:88200 loss : 0.080 KL: 0.895
# Step:88300 loss : 0.116 KL: 0.895
# int32
#  ... Validation Accuracy: 0.970
# Step:88400 loss : 0.129 KL: 0.895
# Step:88500 loss : 0.111 KL: 0.895
# Step:88600 loss : 0.071 KL: 0.895
# Step:88700 loss : 0.075 KL: 0.895
# int32
#  ... Validation Accuracy: 0.971
# Step:88800 loss : 0.132 KL: 0.895
# Step:88900 loss : 0.105 KL: 0.895
# Step:89000 loss : 0.140 KL: 0.895
# Step:89100 loss : 0.067 KL: 0.896
# int32
#  ... Validation Accuracy: 0.969
# Step:89200 loss : 0.142 KL: 0.896
# Step:89300 loss : 0.118 KL: 0.896
# Step:89400 loss : 0.088 KL: 0.896
# Step:89500 loss : 0.124 KL: 0.896
# int32
#  ... Validation Accuracy: 0.974
# Step:89600 loss : 0.098 KL: 0.896
# Step:89700 loss : 0.116 KL: 0.896
# Step:89800 loss : 0.104 KL: 0.896
# Step:89900 loss : 0.087 KL: 0.896
# int32
#  ... Validation Accuracy: 0.974
# Step:90000 loss : 0.112 KL: 0.896
# Step:90100 loss : 0.068 KL: 0.896
# Step:90200 loss : 0.114 KL: 0.896
# Step:90300 loss : 0.070 KL: 0.897
# int32
#  ... Validation Accuracy: 0.968
# Step:90400 loss : 0.084 KL: 0.897
# Step:90500 loss : 0.119 KL: 0.897
# Step:90600 loss : 0.109 KL: 0.897
# Step:90700 loss : 0.073 KL: 0.897
# int32
#  ... Validation Accuracy: 0.970
# Step:90800 loss : 0.129 KL: 0.897
# Step:90900 loss : 0.114 KL: 0.897
# Step:91000 loss : 0.139 KL: 0.897
# Step:91100 loss : 0.144 KL: 0.897
# int32
#  ... Validation Accuracy: 0.972
# Step:91200 loss : 0.106 KL: 0.897
# Step:91300 loss : 0.108 KL: 0.897
# Step:91400 loss : 0.092 KL: 0.897
# Step:91500 loss : 0.124 KL: 0.897
# int32
#  ... Validation Accuracy: 0.970
# Step:91600 loss : 0.135 KL: 0.898
# Step:91700 loss : 0.085 KL: 0.898
# Step:91800 loss : 0.118 KL: 0.898
# Step:91900 loss : 0.122 KL: 0.898
# int32
#  ... Validation Accuracy: 0.973
# Step:92000 loss : 0.092 KL: 0.898
# Step:92100 loss : 0.113 KL: 0.898
# Step:92200 loss : 0.099 KL: 0.898
# Step:92300 loss : 0.083 KL: 0.898
# int32
#  ... Validation Accuracy: 0.973
# Step:92400 loss : 0.115 KL: 0.898
# Step:92500 loss : 0.105 KL: 0.898
# Step:92600 loss : 0.111 KL: 0.898
# Step:92700 loss : 0.113 KL: 0.898
# int32
#  ... Validation Accuracy: 0.968
# Step:92800 loss : 0.121 KL: 0.899
# Step:92900 loss : 0.139 KL: 0.899
# Step:93000 loss : 0.129 KL: 0.899
# Step:93100 loss : 0.110 KL: 0.899
# int32
#  ... Validation Accuracy: 0.972
# Step:93200 loss : 0.084 KL: 0.899
# Step:93300 loss : 0.067 KL: 0.899
# Step:93400 loss : 0.122 KL: 0.899
# Step:93500 loss : 0.140 KL: 0.899
# int32
#  ... Validation Accuracy: 0.971
# Step:93600 loss : 0.079 KL: 0.899
# Step:93700 loss : 0.062 KL: 0.899
# Step:93800 loss : 0.085 KL: 0.899
# Step:93900 loss : 0.118 KL: 0.899
# int32
#  ... Validation Accuracy: 0.973
# Step:94000 loss : 0.131 KL: 0.899
# Step:94100 loss : 0.053 KL: 0.899
# Step:94200 loss : 0.063 KL: 0.900
# Step:94300 loss : 0.163 KL: 0.900
# int32
#  ... Validation Accuracy: 0.972
# Step:94400 loss : 0.147 KL: 0.900
# Step:94500 loss : 0.115 KL: 0.900
# Step:94600 loss : 0.104 KL: 0.900
# Step:94700 loss : 0.097 KL: 0.900
# int32
#  ... Validation Accuracy: 0.971
# Step:94800 loss : 0.122 KL: 0.900
# Step:94900 loss : 0.111 KL: 0.900
# Step:95000 loss : 0.098 KL: 0.900
# Step:95100 loss : 0.110 KL: 0.900
# int32
#  ... Validation Accuracy: 0.969
# Step:95200 loss : 0.084 KL: 0.900
# Step:95300 loss : 0.148 KL: 0.900
# Step:95400 loss : 0.116 KL: 0.900
# Step:95500 loss : 0.093 KL: 0.901
# int32
#  ... Validation Accuracy: 0.973
# Step:95600 loss : 0.053 KL: 0.901
# Step:95700 loss : 0.089 KL: 0.901
# Step:95800 loss : 0.078 KL: 0.901
# Step:95900 loss : 0.113 KL: 0.901
# int32
#  ... Validation Accuracy: 0.972
# Step:96000 loss : 0.091 KL: 0.901
# Step:96100 loss : 0.172 KL: 0.901
# Step:96200 loss : 0.119 KL: 0.901
# Step:96300 loss : 0.088 KL: 0.901
# int32
#  ... Validation Accuracy: 0.974
# Step:96400 loss : 0.111 KL: 0.901
# Step:96500 loss : 0.085 KL: 0.901
# Step:96600 loss : 0.078 KL: 0.901
# Step:96700 loss : 0.107 KL: 0.901
# int32
#  ... Validation Accuracy: 0.971
# Step:96800 loss : 0.136 KL: 0.901
# Step:96900 loss : 0.099 KL: 0.902
# Step:97000 loss : 0.147 KL: 0.902
# Step:97100 loss : 0.124 KL: 0.902
# int32
#  ... Validation Accuracy: 0.970
# Step:97200 loss : 0.067 KL: 0.902
# Step:97300 loss : 0.098 KL: 0.902
# Step:97400 loss : 0.163 KL: 0.902
# Step:97500 loss : 0.125 KL: 0.902
# int32
#  ... Validation Accuracy: 0.969
# Step:97600 loss : 0.152 KL: 0.902
# Step:97700 loss : 0.152 KL: 0.902
# Step:97800 loss : 0.110 KL: 0.902
# Step:97900 loss : 0.116 KL: 0.902
# int32
#  ... Validation Accuracy: 0.974
# Step:98000 loss : 0.119 KL: 0.902
# Step:98100 loss : 0.165 KL: 0.902
# Step:98200 loss : 0.071 KL: 0.902
# Step:98300 loss : 0.072 KL: 0.903
# int32
#  ... Validation Accuracy: 0.970
# Step:98400 loss : 0.115 KL: 0.903
# Step:98500 loss : 0.191 KL: 0.903
# Step:98600 loss : 0.112 KL: 0.903
# Step:98700 loss : 0.090 KL: 0.903
# int32
#  ... Validation Accuracy: 0.975
# Step:98800 loss : 0.095 KL: 0.903
# Step:98900 loss : 0.073 KL: 0.903
# Step:99000 loss : 0.104 KL: 0.903
# Step:99100 loss : 0.093 KL: 0.903
# int32
#  ... Validation Accuracy: 0.971
# Step:99200 loss : 0.078 KL: 0.903
# Step:99300 loss : 0.090 KL: 0.903
# Step:99400 loss : 0.095 KL: 0.903
# Step:99500 loss : 0.091 KL: 0.903
# int32
#  ... Validation Accuracy: 0.971
# Step:99600 loss : 0.136 KL: 0.903
# Step:99700 loss : 0.095 KL: 0.904
# Step:99800 loss : 0.086 KL: 0.904
# Step:99900 loss : 0.133 KL: 0.904
# int32
#  ... Validation Accuracy: 0.969
# Step:100000 loss : 0.111 KL: 0.904
# Step:100100 loss : 0.128 KL: 0.904
# Step:100200 loss : 0.128 KL: 0.904
# Step:100300 loss : 0.121 KL: 0.904
# int32
#  ... Validation Accuracy: 0.972
# Step:100400 loss : 0.089 KL: 0.904
# Step:100500 loss : 0.112 KL: 0.904
# Step:100600 loss : 0.122 KL: 0.904
# Step:100700 loss : 0.141 KL: 0.904
# int32
#  ... Validation Accuracy: 0.969
# Step:100800 loss : 0.116 KL: 0.904
# Step:100900 loss : 0.133 KL: 0.904
# Step:101000 loss : 0.081 KL: 0.904
# Step:101100 loss : 0.075 KL: 0.904
# int32
#  ... Validation Accuracy: 0.974
# Step:101200 loss : 0.093 KL: 0.905
# Step:101300 loss : 0.071 KL: 0.905
# Step:101400 loss : 0.086 KL: 0.905
# Step:101500 loss : 0.115 KL: 0.905
# int32
#  ... Validation Accuracy: 0.971
# Step:101600 loss : 0.077 KL: 0.905
# Step:101700 loss : 0.117 KL: 0.905
# Step:101800 loss : 0.074 KL: 0.905
# Step:101900 loss : 0.108 KL: 0.905
# int32
#  ... Validation Accuracy: 0.974
# Step:102000 loss : 0.095 KL: 0.905
# Step:102100 loss : 0.144 KL: 0.905
# Step:102200 loss : 0.119 KL: 0.905
# Step:102300 loss : 0.149 KL: 0.905
# int32
#  ... Validation Accuracy: 0.970
# Step:102400 loss : 0.111 KL: 0.905
# Step:102500 loss : 0.100 KL: 0.905
# Step:102600 loss : 0.224 KL: 0.905
# Step:102700 loss : 0.125 KL: 0.905
# int32
#  ... Validation Accuracy: 0.970
# Step:102800 loss : 0.139 KL: 0.906
# Step:102900 loss : 0.128 KL: 0.906
# Step:103000 loss : 0.091 KL: 0.906
# Step:103100 loss : 0.075 KL: 0.906
# int32
#  ... Validation Accuracy: 0.970
# Step:103200 loss : 0.082 KL: 0.906
# Step:103300 loss : 0.088 KL: 0.906
# Step:103400 loss : 0.175 KL: 0.906
# Step:103500 loss : 0.096 KL: 0.906
# int32
#  ... Validation Accuracy: 0.976
# Step:103600 loss : 0.124 KL: 0.906
# Step:103700 loss : 0.094 KL: 0.906
# Step:103800 loss : 0.069 KL: 0.906
# Step:103900 loss : 0.110 KL: 0.906
# int32
#  ... Validation Accuracy: 0.969
# Step:104000 loss : 0.086 KL: 0.906
# Step:104100 loss : 0.082 KL: 0.906
# Step:104200 loss : 0.108 KL: 0.906
# Step:104300 loss : 0.138 KL: 0.906
# int32
#  ... Validation Accuracy: 0.973
# Step:104400 loss : 0.092 KL: 0.907
# Step:104500 loss : 0.082 KL: 0.907
# Step:104600 loss : 0.110 KL: 0.907
# Step:104700 loss : 0.089 KL: 0.907
# int32
#  ... Validation Accuracy: 0.973
# Step:104800 loss : 0.143 KL: 0.907
# Step:104900 loss : 0.150 KL: 0.907
# Step:105000 loss : 0.061 KL: 0.907
# Step:105100 loss : 0.116 KL: 0.907
# int32
#  ... Validation Accuracy: 0.970
# Step:105200 loss : 0.114 KL: 0.907
# Step:105300 loss : 0.111 KL: 0.907
# Step:105400 loss : 0.117 KL: 0.907
# Step:105500 loss : 0.117 KL: 0.907
# int32
#  ... Validation Accuracy: 0.971
# Step:105600 loss : 0.104 KL: 0.907
# Step:105700 loss : 0.079 KL: 0.907
# Step:105800 loss : 0.070 KL: 0.907
# Step:105900 loss : 0.079 KL: 0.907
# int32
#  ... Validation Accuracy: 0.974
# Step:106000 loss : 0.093 KL: 0.908
# Step:106100 loss : 0.091 KL: 0.908
# Step:106200 loss : 0.084 KL: 0.908
# Step:106300 loss : 0.084 KL: 0.908
# int32
#  ... Validation Accuracy: 0.970
# Step:106400 loss : 0.083 KL: 0.908
# Step:106500 loss : 0.056 KL: 0.908
# Step:106600 loss : 0.117 KL: 0.908
# Step:106700 loss : 0.112 KL: 0.908
# int32
#  ... Validation Accuracy: 0.974
# Step:106800 loss : 0.075 KL: 0.908
# Step:106900 loss : 0.129 KL: 0.908
# Step:107000 loss : 0.080 KL: 0.908
# Step:107100 loss : 0.090 KL: 0.908
# int32
#  ... Validation Accuracy: 0.973
# Step:107200 loss : 0.106 KL: 0.908
# Step:107300 loss : 0.108 KL: 0.908
# Step:107400 loss : 0.124 KL: 0.908
# Step:107500 loss : 0.139 KL: 0.908
# int32
#  ... Validation Accuracy: 0.971
# Step:107600 loss : 0.102 KL: 0.908
# Step:107700 loss : 0.076 KL: 0.909
# Step:107800 loss : 0.085 KL: 0.909
# Step:107900 loss : 0.141 KL: 0.909
# int32
#  ... Validation Accuracy: 0.971
# Step:108000 loss : 0.140 KL: 0.909
# Step:108100 loss : 0.095 KL: 0.909
# Step:108200 loss : 0.102 KL: 0.909
# Step:108300 loss : 0.167 KL: 0.909
# int32
#  ... Validation Accuracy: 0.973
# Step:108400 loss : 0.103 KL: 0.909
# Step:108500 loss : 0.124 KL: 0.909
# Step:108600 loss : 0.073 KL: 0.909
# Step:108700 loss : 0.083 KL: 0.909
# int32
#  ... Validation Accuracy: 0.971
# Step:108800 loss : 0.114 KL: 0.909
# Step:108900 loss : 0.084 KL: 0.909
# Step:109000 loss : 0.130 KL: 0.909
# Step:109100 loss : 0.098 KL: 0.909
# int32
#  ... Validation Accuracy: 0.972
# Step:109200 loss : 0.114 KL: 0.909
# Step:109300 loss : 0.155 KL: 0.909
# Step:109400 loss : 0.108 KL: 0.910
# Step:109500 loss : 0.084 KL: 0.910
# int32
#  ... Validation Accuracy: 0.971
# Step:109600 loss : 0.095 KL: 0.910
# Step:109700 loss : 0.103 KL: 0.910
# Step:109800 loss : 0.095 KL: 0.910
# Step:109900 loss : 0.107 KL: 0.910
# int32
#  ... Validation Accuracy: 0.974
# Step:110000 loss : 0.124 KL: 0.910
# Step:110100 loss : 0.104 KL: 0.910
# Step:110200 loss : 0.098 KL: 0.910
# Step:110300 loss : 0.061 KL: 0.910
# int32
# ...
# Step:368800 loss : 0.149 KL: 0.957
# Step:368900 loss : 0.080 KL: 0.957
# Step:369000 loss : 0.095 KL: 0.957
# Step:369100 loss : 0.133 KL: 0.957
# int32
#  ... Validation Accuracy: 0.977
# Step:369200 loss : 0.061 KL: 0.957
# Step:369300 loss : 0.096 KL: 0.957
# Step:369400 loss : 0.140 KL: 0.957
# Step:369500 loss : 0.071 KL: 0.957
# int32
#  ... Validation Accuracy: 0.977
# Step:369600 loss : 0.159 KL: 0.957
# Step:369700 loss : 0.093 KL: 0.957
# Step:369800 loss : 0.125 KL: 0.957
# Step:369900 loss : 0.074 KL: 0.957
# int32
#  ... Validation Accuracy: 0.980
# Step:370000 loss : 0.101 KL: 0.957
# Step:370100 loss : 0.098 KL: 0.957
# Step:370200 loss : 0.103 KL: 0.957
# Step:370300 loss : 0.106 KL: 0.957
# int32
#  ... Validation Accuracy: 0.975
# Step:370400 loss : 0.115 KL: 0.957
# Step:370500 loss : 0.121 KL: 0.957
# Step:370600 loss : 0.113 KL: 0.957
# Step:370700 loss : 0.096 KL: 0.957
# int32
#  ... Validation Accuracy: 0.981
# Step:370800 loss : 0.100 KL: 0.957
# Step:370900 loss : 0.066 KL: 0.957
# Step:371000 loss : 0.142 KL: 0.957
# Step:371100 loss : 0.093 KL: 0.957
# int32
#  ... Validation Accuracy: 0.980
# Step:371200 loss : 0.075 KL: 0.957
# Step:371300 loss : 0.085 KL: 0.957
# Step:371400 loss : 0.090 KL: 0.957
# Step:371500 loss : 0.085 KL: 0.957
# int32
#  ... Validation Accuracy: 0.978
# Step:371600 loss : 0.111 KL: 0.957
# Step:371700 loss : 0.062 KL: 0.957
# Step:371800 loss : 0.092 KL: 0.957
# Step:371900 loss : 0.112 KL: 0.957
# int32
#  ... Validation Accuracy: 0.977
# Step:372000 loss : 0.087 KL: 0.957
# Step:372100 loss : 0.098 KL: 0.957
# Step:372200 loss : 0.077 KL: 0.957
# Step:372300 loss : 0.136 KL: 0.957
# int32
#  ... Validation Accuracy: 0.979
# Step:372400 loss : 0.080 KL: 0.957
# Step:372500 loss : 0.140 KL: 0.957
# Step:372600 loss : 0.094 KL: 0.957
# Step:372700 loss : 0.094 KL: 0.957
# int32
#  ... Validation Accuracy: 0.977
# Step:372800 loss : 0.077 KL: 0.957
# Step:372900 loss : 0.110 KL: 0.957
# Step:373000 loss : 0.041 KL: 0.957
# Step:373100 loss : 0.078 KL: 0.957
# int32
#  ... Validation Accuracy: 0.981
# Step:373200 loss : 0.053 KL: 0.957
# Step:373300 loss : 0.113 KL: 0.957
# Step:373400 loss : 0.082 KL: 0.957
# Step:373500 loss : 0.097 KL: 0.957
# int32
#  ... Validation Accuracy: 0.980
# Step:373600 loss : 0.088 KL: 0.957
# Step:373700 loss : 0.061 KL: 0.957
# Step:373800 loss : 0.073 KL: 0.957
# Step:373900 loss : 0.098 KL: 0.957
# int32
#  ... Validation Accuracy: 0.978
# Step:374000 loss : 0.091 KL: 0.957
# Step:374100 loss : 0.128 KL: 0.957
# Step:374200 loss : 0.090 KL: 0.957
# Step:374300 loss : 0.098 KL: 0.957
# int32
#  ... Validation Accuracy: 0.979
# Step:374400 loss : 0.117 KL: 0.957
# Step:374500 loss : 0.060 KL: 0.957
# Step:374600 loss : 0.091 KL: 0.957
# Step:374700 loss : 0.073 KL: 0.957
# int32
#  ... Validation Accuracy: 0.980
# Step:374800 loss : 0.057 KL: 0.957
# Step:374900 loss : 0.112 KL: 0.957
# Step:375000 loss : 0.101 KL: 0.957
# Step:375100 loss : 0.050 KL: 0.957
# int32
#  ... Validation Accuracy: 0.979
# Step:375200 loss : 0.116 KL: 0.957
# Step:375300 loss : 0.048 KL: 0.957
# Step:375400 loss : 0.084 KL: 0.957
# Step:375500 loss : 0.088 KL: 0.957
# int32
#  ... Validation Accuracy: 0.980
# Step:375600 loss : 0.082 KL: 0.957
# Step:375700 loss : 0.132 KL: 0.957
# Step:375800 loss : 0.095 KL: 0.957
# Step:375900 loss : 0.167 KL: 0.957
# int32
#  ... Validation Accuracy: 0.979
# Step:376000 loss : 0.069 KL: 0.957
# Step:376100 loss : 0.062 KL: 0.957
# Step:376200 loss : 0.096 KL: 0.957
# Step:376300 loss : 0.074 KL: 0.957
# int32
#  ... Validation Accuracy: 0.978
# Step:376400 loss : 0.094 KL: 0.957
# Step:376500 loss : 0.109 KL: 0.957
# Step:376600 loss : 0.097 KL: 0.957
# Step:376700 loss : 0.104 KL: 0.957
# int32
#  ... Validation Accuracy: 0.980
# Step:376800 loss : 0.083 KL: 0.957
# Step:376900 loss : 0.096 KL: 0.957
# Step:377000 loss : 0.089 KL: 0.957
# Step:377100 loss : 0.071 KL: 0.957
# int32
#  ... Validation Accuracy: 0.978
# Step:377200 loss : 0.105 KL: 0.957
# Step:377300 loss : 0.065 KL: 0.957
# Step:377400 loss : 0.112 KL: 0.957
# Step:377500 loss : 0.128 KL: 0.957
# int32
#  ... Validation Accuracy: 0.981
# Step:377600 loss : 0.061 KL: 0.957
# Step:377700 loss : 0.065 KL: 0.957
# Step:377800 loss : 0.099 KL: 0.957
# Step:377900 loss : 0.097 KL: 0.957
# int32
#  ... Validation Accuracy: 0.980
# Step:378000 loss : 0.097 KL: 0.957
# Step:378100 loss : 0.075 KL: 0.957
# Step:378200 loss : 0.089 KL: 0.957
# Step:378300 loss : 0.085 KL: 0.957
# int32
#  ... Validation Accuracy: 0.977
# Step:378400 loss : 0.101 KL: 0.957
# Step:378500 loss : 0.110 KL: 0.957
# Step:378600 loss : 0.120 KL: 0.957
# Step:378700 loss : 0.096 KL: 0.957
# int32
#  ... Validation Accuracy: 0.976
# Step:378800 loss : 0.084 KL: 0.957
# Step:378900 loss : 0.109 KL: 0.957
# Step:379000 loss : 0.081 KL: 0.957
# Step:379100 loss : 0.104 KL: 0.957
# int32
#  ... Validation Accuracy: 0.980
# Step:379200 loss : 0.110 KL: 0.957
# Step:379300 loss : 0.088 KL: 0.957
# Step:379400 loss : 0.094 KL: 0.957
# Step:379500 loss : 0.083 KL: 0.957
# int32
#  ... Validation Accuracy: 0.978
# Step:379600 loss : 0.083 KL: 0.957
# Step:379700 loss : 0.130 KL: 0.957
# Step:379800 loss : 0.052 KL: 0.957
# Step:379900 loss : 0.077 KL: 0.957
# int32
#  ... Validation Accuracy: 0.981
# Step:380000 loss : 0.110 KL: 0.957
# Step:380100 loss : 0.097 KL: 0.957
# Step:380200 loss : 0.063 KL: 0.957
# Step:380300 loss : 0.095 KL: 0.957
# int32
#  ... Validation Accuracy: 0.979
# Step:380400 loss : 0.091 KL: 0.957
# Step:380500 loss : 0.091 KL: 0.957
# Step:380600 loss : 0.113 KL: 0.957
# Step:380700 loss : 0.064 KL: 0.957
# int32
#  ... Validation Accuracy: 0.980
# Step:380800 loss : 0.115 KL: 0.957
# Step:380900 loss : 0.103 KL: 0.957
# Step:381000 loss : 0.094 KL: 0.957
# Step:381100 loss : 0.113 KL: 0.957
# int32
#  ... Validation Accuracy: 0.977
# Step:381200 loss : 0.090 KL: 0.957
# Step:381300 loss : 0.095 KL: 0.957
# Step:381400 loss : 0.046 KL: 0.957
# Step:381500 loss : 0.087 KL: 0.957
# int32
#  ... Validation Accuracy: 0.978
# Step:381600 loss : 0.103 KL: 0.957
# Step:381700 loss : 0.079 KL: 0.957
# Step:381800 loss : 0.077 KL: 0.957
# Step:381900 loss : 0.050 KL: 0.957
# int32
#  ... Validation Accuracy: 0.977
# Step:382000 loss : 0.075 KL: 0.957
# Step:382100 loss : 0.082 KL: 0.957
# Step:382200 loss : 0.063 KL: 0.957
# Step:382300 loss : 0.100 KL: 0.957
# int32
#  ... Validation Accuracy: 0.981
# Step:382400 loss : 0.128 KL: 0.957
# Step:382500 loss : 0.099 KL: 0.957
# Step:382600 loss : 0.109 KL: 0.957
# Step:382700 loss : 0.086 KL: 0.957
# int32
#  ... Validation Accuracy: 0.978
# Step:382800 loss : 0.106 KL: 0.957
# Step:382900 loss : 0.113 KL: 0.957
# Step:383000 loss : 0.115 KL: 0.957
# Step:383100 loss : 0.082 KL: 0.957
# int32
#  ... Validation Accuracy: 0.980
# Step:383200 loss : 0.072 KL: 0.957
# Step:383300 loss : 0.095 KL: 0.957
# Step:383400 loss : 0.123 KL: 0.957
# Step:383500 loss : 0.095 KL: 0.957
# int32
#  ... Validation Accuracy: 0.978
# Step:383600 loss : 0.123 KL: 0.957
# Step:383700 loss : 0.063 KL: 0.957
# Step:383800 loss : 0.087 KL: 0.957
# Step:383900 loss : 0.084 KL: 0.957
# int32
#  ... Validation Accuracy: 0.976
# Step:384000 loss : 0.090 KL: 0.957
# Step:384100 loss : 0.099 KL: 0.957
# Step:384200 loss : 0.076 KL: 0.957
# Step:384300 loss : 0.071 KL: 0.957
# int32
#  ... Validation Accuracy: 0.978
# Step:384400 loss : 0.049 KL: 0.957
# Step:384500 loss : 0.064 KL: 0.957
# Step:384600 loss : 0.086 KL: 0.957
# Step:384700 loss : 0.067 KL: 0.957
# int32
#  ... Validation Accuracy: 0.981
# Step:384800 loss : 0.126 KL: 0.958
# Step:384900 loss : 0.077 KL: 0.958
# Step:385000 loss : 0.067 KL: 0.958
# Step:385100 loss : 0.074 KL: 0.958
# int32
#  ... Validation Accuracy: 0.976
# Step:385200 loss : 0.053 KL: 0.958
# Step:385300 loss : 0.106 KL: 0.958
# Step:385400 loss : 0.097 KL: 0.958
# Step:385500 loss : 0.100 KL: 0.958
# int32
#  ... Validation Accuracy: 0.981
# Step:385600 loss : 0.070 KL: 0.958
# Step:385700 loss : 0.086 KL: 0.958
# Step:385800 loss : 0.076 KL: 0.958
# Step:385900 loss : 0.100 KL: 0.958
# int32
#  ... Validation Accuracy: 0.980
# Step:386000 loss : 0.088 KL: 0.958
# Step:386100 loss : 0.102 KL: 0.958
# Step:386200 loss : 0.077 KL: 0.958
# Step:386300 loss : 0.096 KL: 0.958
# int32
#  ... Validation Accuracy: 0.977
# Step:386400 loss : 0.078 KL: 0.958
# Step:386500 loss : 0.114 KL: 0.958
# Step:386600 loss : 0.067 KL: 0.958
# Step:386700 loss : 0.105 KL: 0.958
# int32
#  ... Validation Accuracy: 0.979
# Step:386800 loss : 0.136 KL: 0.958
# Step:386900 loss : 0.055 KL: 0.958
# Step:387000 loss : 0.089 KL: 0.958
# Step:387100 loss : 0.099 KL: 0.958
# int32
#  ... Validation Accuracy: 0.979
# Step:387200 loss : 0.110 KL: 0.958
# Step:387300 loss : 0.070 KL: 0.958
# Step:387400 loss : 0.103 KL: 0.958
# Step:387500 loss : 0.100 KL: 0.958
# int32
#  ... Validation Accuracy: 0.977
# Step:387600 loss : 0.099 KL: 0.958
# Step:387700 loss : 0.116 KL: 0.958
# Step:387800 loss : 0.085 KL: 0.958
# Step:387900 loss : 0.058 KL: 0.958
# int32
#  ... Validation Accuracy: 0.981
# Step:388000 loss : 0.113 KL: 0.958
# Step:388100 loss : 0.074 KL: 0.958
# Step:388200 loss : 0.091 KL: 0.958
# Step:388300 loss : 0.080 KL: 0.958
# int32
#  ... Validation Accuracy: 0.980
# Step:388400 loss : 0.084 KL: 0.958
# Step:388500 loss : 0.107 KL: 0.958
# Step:388600 loss : 0.105 KL: 0.958
# Step:388700 loss : 0.128 KL: 0.958
# int32
#  ... Validation Accuracy: 0.980
# Step:388800 loss : 0.102 KL: 0.958
# Step:388900 loss : 0.115 KL: 0.958
# Step:389000 loss : 0.069 KL: 0.958
# Step:389100 loss : 0.085 KL: 0.958
# int32
#  ... Validation Accuracy: 0.979
# Step:389200 loss : 0.113 KL: 0.958
# Step:389300 loss : 0.101 KL: 0.958
# Step:389400 loss : 0.157 KL: 0.958
# Step:389500 loss : 0.156 KL: 0.958
# int32
#  ... Validation Accuracy: 0.978
# Step:389600 loss : 0.092 KL: 0.958
# Step:389700 loss : 0.094 KL: 0.958
# Step:389800 loss : 0.081 KL: 0.958
# Step:389900 loss : 0.092 KL: 0.958
# int32
#  ... Validation Accuracy: 0.979
# Step:390000 loss : 0.097 KL: 0.958
# Step:390100 loss : 0.073 KL: 0.958
# Step:390200 loss : 0.108 KL: 0.958
# Step:390300 loss : 0.068 KL: 0.958
# int32
#  ... Validation Accuracy: 0.979
# Step:390400 loss : 0.058 KL: 0.958
# Step:390500 loss : 0.091 KL: 0.958
# Step:390600 loss : 0.078 KL: 0.958
# Step:390700 loss : 0.099 KL: 0.958
# int32
#  ... Validation Accuracy: 0.978
# Step:390800 loss : 0.131 KL: 0.958
# Step:390900 loss : 0.065 KL: 0.958
# Step:391000 loss : 0.097 KL: 0.958
# Step:391100 loss : 0.115 KL: 0.958
# int32
#  ... Validation Accuracy: 0.980
# Step:391200 loss : 0.109 KL: 0.958
# Step:391300 loss : 0.094 KL: 0.958
# Step:391400 loss : 0.115 KL: 0.958
# Step:391500 loss : 0.057 KL: 0.958
# int32
#  ... Validation Accuracy: 0.978
# Step:391600 loss : 0.116 KL: 0.958
# Step:391700 loss : 0.064 KL: 0.958
# Step:391800 loss : 0.089 KL: 0.958
# Step:391900 loss : 0.095 KL: 0.958
# int32
#  ... Validation Accuracy: 0.979
# Step:392000 loss : 0.060 KL: 0.958
# Step:392100 loss : 0.098 KL: 0.958
# Step:392200 loss : 0.101 KL: 0.958
# Step:392300 loss : 0.122 KL: 0.958
# int32
#  ... Validation Accuracy: 0.979
# Step:392400 loss : 0.063 KL: 0.958
# Step:392500 loss : 0.081 KL: 0.958
# Step:392600 loss : 0.083 KL: 0.958
# Step:392700 loss : 0.102 KL: 0.958
# int32
#  ... Validation Accuracy: 0.978
# Step:392800 loss : 0.070 KL: 0.958
# Step:392900 loss : 0.107 KL: 0.958
# Step:393000 loss : 0.084 KL: 0.958
# Step:393100 loss : 0.114 KL: 0.958
# int32
#  ... Validation Accuracy: 0.977
# Step:393200 loss : 0.108 KL: 0.958
# Step:393300 loss : 0.118 KL: 0.958
# Step:393400 loss : 0.082 KL: 0.958
# Step:393500 loss : 0.108 KL: 0.958
# int32
#  ... Validation Accuracy: 0.980
# Step:393600 loss : 0.117 KL: 0.958
# Step:393700 loss : 0.083 KL: 0.958
# Step:393800 loss : 0.079 KL: 0.958
# Step:393900 loss : 0.151 KL: 0.958
# int32
#  ... Validation Accuracy: 0.976
# Step:394000 loss : 0.133 KL: 0.958
# Step:394100 loss : 0.088 KL: 0.958
# Step:394200 loss : 0.075 KL: 0.958
# Step:394300 loss : 0.085 KL: 0.958
# int32
#  ... Validation Accuracy: 0.980
# Step:394400 loss : 0.102 KL: 0.958
# Step:394500 loss : 0.079 KL: 0.958
# Step:394600 loss : 0.081 KL: 0.958
# Step:394700 loss : 0.119 KL: 0.958
# int32
#  ... Validation Accuracy: 0.982
# Step:394800 loss : 0.122 KL: 0.958
# Step:394900 loss : 0.104 KL: 0.958
# Step:395000 loss : 0.063 KL: 0.958
# Step:395100 loss : 0.122 KL: 0.958
# int32
#  ... Validation Accuracy: 0.977
# Step:395200 loss : 0.084 KL: 0.958
# Step:395300 loss : 0.048 KL: 0.958
# Step:395400 loss : 0.091 KL: 0.958
# Step:395500 loss : 0.083 KL: 0.958
# int32
#  ... Validation Accuracy: 0.977
# Step:395600 loss : 0.117 KL: 0.958
# Step:395700 loss : 0.077 KL: 0.958
# Step:395800 loss : 0.067 KL: 0.958
# Step:395900 loss : 0.104 KL: 0.958
# int32
#  ... Validation Accuracy: 0.980
# Step:396000 loss : 0.115 KL: 0.958
# Step:396100 loss : 0.091 KL: 0.958
# Step:396200 loss : 0.172 KL: 0.958
# Step:396300 loss : 0.121 KL: 0.958
# int32
#  ... Validation Accuracy: 0.976
# Step:396400 loss : 0.109 KL: 0.958
# Step:396500 loss : 0.111 KL: 0.958
# Step:396600 loss : 0.100 KL: 0.958
# Step:396700 loss : 0.087 KL: 0.958
# int32
#  ... Validation Accuracy: 0.981
# Step:396800 loss : 0.105 KL: 0.958
# Step:396900 loss : 0.083 KL: 0.958
# Step:397000 loss : 0.078 KL: 0.958
# Step:397100 loss : 0.110 KL: 0.958
# int32
#  ... Validation Accuracy: 0.979
# Step:397200 loss : 0.064 KL: 0.958
# Step:397300 loss : 0.107 KL: 0.958
# Step:397400 loss : 0.052 KL: 0.958
# Step:397500 loss : 0.063 KL: 0.958
# int32
#  ... Validation Accuracy: 0.979
# Step:397600 loss : 0.103 KL: 0.958
# Step:397700 loss : 0.094 KL: 0.958
# Step:397800 loss : 0.128 KL: 0.958
# Step:397900 loss : 0.112 KL: 0.958
# int32
#  ... Validation Accuracy: 0.978
# Step:398000 loss : 0.076 KL: 0.958
# Step:398100 loss : 0.100 KL: 0.958
# Step:398200 loss : 0.099 KL: 0.958
# Step:398300 loss : 0.111 KL: 0.958
# int32
#  ... Validation Accuracy: 0.980
# Step:398400 loss : 0.115 KL: 0.958
# Step:398500 loss : 0.088 KL: 0.958
# Step:398600 loss : 0.075 KL: 0.958
# Step:398700 loss : 0.074 KL: 0.958
# int32
#  ... Validation Accuracy: 0.979
# Step:398800 loss : 0.153 KL: 0.958
# Step:398900 loss : 0.113 KL: 0.958
# Step:399000 loss : 0.089 KL: 0.958
# Step:399100 loss : 0.140 KL: 0.958
# int32
#  ... Validation Accuracy: 0.981
# Step:399200 loss : 0.082 KL: 0.958
# Step:399300 loss : 0.104 KL: 0.958
# Step:399400 loss : 0.096 KL: 0.958
# Step:399500 loss : 0.117 KL: 0.958
# int32
#  ... Validation Accuracy: 0.980
# Step:399600 loss : 0.086 KL: 0.958
# Step:399700 loss : 0.088 KL: 0.958
# Step:399800 loss : 0.072 KL: 0.958
# Step:399900 loss : 0.087 KL: 0.958
# int32
#  ... Validation Accuracy: 0.977
# Step:400000 loss : 0.113 KL: 0.958
# Step:400100 loss : 0.106 KL: 0.958
# Step:400200 loss : 0.095 KL: 0.958
# Step:400300 loss : 0.049 KL: 0.958
# int32
#  ... Validation Accuracy: 0.979
# Step:400400 loss : 0.080 KL: 0.958
# Step:400500 loss : 0.124 KL: 0.958
# Step:400600 loss : 0.074 KL: 0.958
# Step:400700 loss : 0.087 KL: 0.958
# int32
#  ... Validation Accuracy: 0.980
# Step:400800 loss : 0.075 KL: 0.958
# Step:400900 loss : 0.113 KL: 0.958
# Step:401000 loss : 0.097 KL: 0.958
# Step:401100 loss : 0.082 KL: 0.958
# int32
#  ... Validation Accuracy: 0.981
# Step:401200 loss : 0.078 KL: 0.958
# Step:401300 loss : 0.130 KL: 0.958
# Step:401400 loss : 0.076 KL: 0.958
# Step:401500 loss : 0.079 KL: 0.958
# int32
#  ... Validation Accuracy: 0.980
# Step:401600 loss : 0.131 KL: 0.958
# Step:401700 loss : 0.158 KL: 0.958
# Step:401800 loss : 0.081 KL: 0.958
# Step:401900 loss : 0.096 KL: 0.958
# int32
#  ... Validation Accuracy: 0.979
# Step:402000 loss : 0.074 KL: 0.958
# Step:402100 loss : 0.101 KL: 0.958
# Step:402200 loss : 0.126 KL: 0.958
# Step:402300 loss : 0.075 KL: 0.958
# int32
#  ... Validation Accuracy: 0.978
# Step:402400 loss : 0.097 KL: 0.958
# Step:402500 loss : 0.122 KL: 0.958
# Step:402600 loss : 0.129 KL: 0.958
# Step:402700 loss : 0.102 KL: 0.958
# int32
#  ... Validation Accuracy: 0.980
# Step:402800 loss : 0.073 KL: 0.958
# Step:402900 loss : 0.104 KL: 0.958
# Step:403000 loss : 0.120 KL: 0.959
# Step:403100 loss : 0.089 KL: 0.959
# int32
#  ... Validation Accuracy: 0.978
# Step:403200 loss : 0.123 KL: 0.959
# Step:403300 loss : 0.113 KL: 0.959
# Step:403400 loss : 0.127 KL: 0.959
# Step:403500 loss : 0.068 KL: 0.959
# int32
#  ... Validation Accuracy: 0.982
# Step:403600 loss : 0.086 KL: 0.959
# Step:403700 loss : 0.098 KL: 0.959
# Step:403800 loss : 0.074 KL: 0.959
# Step:403900 loss : 0.077 KL: 0.959
# int32
#  ... Validation Accuracy: 0.980
# Step:404000 loss : 0.070 KL: 0.959
# Step:404100 loss : 0.096 KL: 0.959
# Step:404200 loss : 0.100 KL: 0.959
# Step:404300 loss : 0.084 KL: 0.959
# int32
#  ... Validation Accuracy: 0.979
# Step:404400 loss : 0.085 KL: 0.959
# Step:404500 loss : 0.114 KL: 0.959
# Step:404600 loss : 0.050 KL: 0.959
# Step:404700 loss : 0.088 KL: 0.959
